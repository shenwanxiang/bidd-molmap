# %%
from molmap.model import RegressionEstimator, MultiClassEstimator, MultiLabelEstimator
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from chembench import dataset
from sklearn.utils import shuffle 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from molmap import MolMap
import molmap

def Rdsplit(df, random_state = 888, split_size = [0.8, 0.1, 0.1]):
    base_indices = np.arange(len(df)) 
    base_indices = shuffle(base_indices, random_state = random_state) 
    nb_test = int(len(base_indices) * split_size[2]) 
    nb_val = int(len(base_indices) * split_size[1]) 
    test_idx = base_indices[0:nb_test] 
    valid_idx = base_indices[(nb_test):(nb_test+nb_val)] 
    train_idx = base_indices[(nb_test+nb_val):len(base_indices)] 
    print(len(train_idx), len(valid_idx), len(test_idx)) 
    return train_idx, valid_idx, test_idx

# %%
data = dataset.load_BACE()
# Out:
# total samples: 1513

# %%
bitsinfo = molmap.feature.fingerprint.Extraction().bitsinfo

# %%
bitsinfo.Subtypes.unique()
# Out:
# array(['MorganFP', 'RDkitFP', 'AtomPairFP', 'TorsionFP', 'AvalonFP',
#        'EstateFP', 'MACCSFP', 'PharmacoErGFP', 'PharmacoPFP', 'PubChemFP',
#        'MHFP6', 'MAP4'], dtype=object)

# %%
flist = bitsinfo[bitsinfo.Subtypes.isin(['PubChemFP'])].IDs.tolist()
# flist= [] means using all of the types of fingerprint

mp = MolMap(ftype = 'fingerprint', fmap_type = 'scatter', flist = flist) #

# %%
mp.fit(method = 'umap',  min_dist = 0.1, n_neighbors = 15, verbose = 0)
# Out:
# 2021-03-31 10:53:51,323 - INFO - [bidd-molmap] - Applying naive scatter feature map...
# 2021-03-31 10:53:51,332 - INFO - [bidd-molmap] - Finished

# %%
X = mp.batch_transform(data.x)
# Out:
# 100%|##########| 1513/1513 [00:56<00:00, 26.82it/s]

# %%
Y = pd.get_dummies(data.df['Class']).values
Y.shape
# Out:
# (1513, 2)

# %%
train_idx, valid_idx, test_idx  = Rdsplit(data.df, random_state = 888)
trainX = X[train_idx]
trainY = Y[train_idx]
validX = X[valid_idx]
validY = Y[valid_idx]
testX = X[test_idx]
testY = Y[test_idx]
# Out:
# 1211 151 151

# %%
# define your model
clf = MultiClassEstimator(n_outputs=trainY.shape[1], metric='ROC', 
                          fmap_shape1 = trainX.shape[1:], dense_layers = [128, 64],  gpuid = 0)
# Out:
# MultiClassEstimator(gpuid='0')

# %%
# fit your model
clf.fit(trainX, trainY, validX, validY )
# Out:
# epoch: 0001, loss: 0.6911 - val_loss: 0.6806; auc: 0.7934 - val_auc: 0.7162
# epoch: 0002, loss: 0.6756 - val_loss: 0.6698; auc: 0.8256 - val_auc: 0.7584
# epoch: 0003, loss: 0.6617 - val_loss: 0.6588; auc: 0.8383 - val_auc: 0.7675
# epoch: 0004, loss: 0.6472 - val_loss: 0.6461; auc: 0.8424 - val_auc: 0.7741
# epoch: 0005, loss: 0.6346 - val_loss: 0.6325; auc: 0.8471 - val_auc: 0.7826
# epoch: 0006, loss: 0.6170 - val_loss: 0.6224; auc: 0.8508 - val_auc: 0.7867
# epoch: 0007, loss: 0.5962 - val_loss: 0.6031; auc: 0.8523 - val_auc: 0.7929
# epoch: 0008, loss: 0.5754 - val_loss: 0.5865; auc: 0.8548 - val_auc: 0.7947
# epoch: 0009, loss: 0.5551 - val_loss: 0.5708; auc: 0.8572 - val_auc: 0.8041
# epoch: 0010, loss: 0.5434 - val_loss: 0.5607; auc: 0.8599 - val_auc: 0.8068
# epoch: 0011, loss: 0.5226 - val_loss: 0.5590; auc: 0.8631 - val_auc: 0.8137
# epoch: 0012, loss: 0.5100 - val_loss: 0.5472; auc: 0.8666 - val_auc: 0.8128
# epoch: 0013, loss: 0.5050 - val_loss: 0.5405; auc: 0.8695 - val_auc: 0.8181
# epoch: 0014, loss: 0.4874 - val_loss: 0.5250; auc: 0.8732 - val_auc: 0.8217
# epoch: 0015, loss: 0.4758 - val_loss: 0.5208; auc: 0.8755 - val_auc: 0.8226
# epoch: 0016, loss: 0.4658 - val_loss: 0.5150; auc: 0.8798 - val_auc: 0.8265
# epoch: 0017, loss: 0.4586 - val_loss: 0.5140; auc: 0.8818 - val_auc: 0.8302
# epoch: 0018, loss: 0.4550 - val_loss: 0.5139; auc: 0.8849 - val_auc: 0.8336
# epoch: 0019, loss: 0.4513 - val_loss: 0.5191; auc: 0.8888 - val_auc: 0.8311
# epoch: 0020, loss: 0.4511 - val_loss: 0.5204; auc: 0.8913 - val_auc: 0.8343
# epoch: 0021, loss: 0.4539 - val_loss: 0.4959; auc: 0.8938 - val_auc: 0.8377
# epoch: 0022, loss: 0.4294 - val_loss: 0.4980; auc: 0.8958 - val_auc: 0.8391
# epoch: 0023, loss: 0.4240 - val_loss: 0.4996; auc: 0.8977 - val_auc: 0.8391
# epoch: 0024, loss: 0.4187 - val_loss: 0.5066; auc: 0.8998 - val_auc: 0.8411
# epoch: 0025, loss: 0.4213 - val_loss: 0.4972; auc: 0.9029 - val_auc: 0.8411
# epoch: 0026, loss: 0.4081 - val_loss: 0.4938; auc: 0.9047 - val_auc: 0.8416
# epoch: 0027, loss: 0.4117 - val_loss: 0.4903; auc: 0.9067 - val_auc: 0.8436
# epoch: 0028, loss: 0.4076 - val_loss: 0.4873; auc: 0.9086 - val_auc: 0.8432
# epoch: 0029, loss: 0.4026 - val_loss: 0.4954; auc: 0.9112 - val_auc: 0.8464
# epoch: 0030, loss: 0.3999 - val_loss: 0.5012; auc: 0.9123 - val_auc: 0.8467
# epoch: 0031, loss: 0.3975 - val_loss: 0.4908; auc: 0.9145 - val_auc: 0.8469
# epoch: 0032, loss: 0.3910 - val_loss: 0.4829; auc: 0.9162 - val_auc: 0.8466
# epoch: 0033, loss: 0.3811 - val_loss: 0.4922; auc: 0.9183 - val_auc: 0.8503
# epoch: 0034, loss: 0.3897 - val_loss: 0.4959; auc: 0.9194 - val_auc: 0.8515
# epoch: 0035, loss: 0.3827 - val_loss: 0.4799; auc: 0.9212 - val_auc: 0.8494
# epoch: 0036, loss: 0.3709 - val_loss: 0.4826; auc: 0.9227 - val_auc: 0.8526
# epoch: 0037, loss: 0.3739 - val_loss: 0.4832; auc: 0.9239 - val_auc: 0.8523
# epoch: 0038, loss: 0.3709 - val_loss: 0.5039; auc: 0.9249 - val_auc: 0.8530
# epoch: 0039, loss: 0.3822 - val_loss: 0.4755; auc: 0.9267 - val_auc: 0.8540
# epoch: 0040, loss: 0.3628 - val_loss: 0.4759; auc: 0.9281 - val_auc: 0.8542
# epoch: 0041, loss: 0.3577 - val_loss: 0.4961; auc: 0.9295 - val_auc: 0.8540
# epoch: 0042, loss: 0.3563 - val_loss: 0.4910; auc: 0.9308 - val_auc: 0.8544
# epoch: 0043, loss: 0.3548 - val_loss: 0.4787; auc: 0.9320 - val_auc: 0.8560
# epoch: 0044, loss: 0.3495 - val_loss: 0.4757; auc: 0.9333 - val_auc: 0.8588
# epoch: 0045, loss: 0.3416 - val_loss: 0.4912; auc: 0.9343 - val_auc: 0.8604
# epoch: 0046, loss: 0.3526 - val_loss: 0.4785; auc: 0.9359 - val_auc: 0.8585
# epoch: 0047, loss: 0.3424 - val_loss: 0.4746; auc: 0.9365 - val_auc: 0.8590
# epoch: 0048, loss: 0.3404 - val_loss: 0.4815; auc: 0.9382 - val_auc: 0.8592
# epoch: 0049, loss: 0.3343 - val_loss: 0.4929; auc: 0.9387 - val_auc: 0.8579
# epoch: 0050, loss: 0.3407 - val_loss: 0.4780; auc: 0.9398 - val_auc: 0.8599
# epoch: 0051, loss: 0.3268 - val_loss: 0.4886; auc: 0.9414 - val_auc: 0.8583
# epoch: 0052, loss: 0.3328 - val_loss: 0.4775; auc: 0.9424 - val_auc: 0.8583
# epoch: 0053, loss: 0.3206 - val_loss: 0.4893; auc: 0.9438 - val_auc: 0.8597
# epoch: 0054, loss: 0.3318 - val_loss: 0.4884; auc: 0.9450 - val_auc: 0.8606
# epoch: 0055, loss: 0.3337 - val_loss: 0.4887; auc: 0.9446 - val_auc: 0.8620
# epoch: 0056, loss: 0.3193 - val_loss: 0.4779; auc: 0.9453 - val_auc: 0.8615
# epoch: 0057, loss: 0.3277 - val_loss: 0.4885; auc: 0.9471 - val_auc: 0.8590
# epoch: 0058, loss: 0.3232 - val_loss: 0.4817; auc: 0.9483 - val_auc: 0.8613
# epoch: 0059, loss: 0.3233 - val_loss: 0.5365; auc: 0.9480 - val_auc: 0.8588
# epoch: 0060, loss: 0.3261 - val_loss: 0.4820; auc: 0.9494 - val_auc: 0.8610
# epoch: 0061, loss: 0.3219 - val_loss: 0.5040; auc: 0.9507 - val_auc: 0.8627
# epoch: 0062, loss: 0.3096 - val_loss: 0.4881; auc: 0.9519 - val_auc: 0.8633
# epoch: 0063, loss: 0.3221 - val_loss: 0.5127; auc: 0.9524 - val_auc: 0.8631
# epoch: 0064, loss: 0.3058 - val_loss: 0.4987; auc: 0.9536 - val_auc: 0.8627
# epoch: 0065, loss: 0.3164 - val_loss: 0.4836; auc: 0.9537 - val_auc: 0.8627
# epoch: 0066, loss: 0.2941 - val_loss: 0.4877; auc: 0.9551 - val_auc: 0.8668
# epoch: 0067, loss: 0.2961 - val_loss: 0.4810; auc: 0.9560 - val_auc: 0.8643
# epoch: 0068, loss: 0.2871 - val_loss: 0.4809; auc: 0.9561 - val_auc: 0.8661
# epoch: 0069, loss: 0.2894 - val_loss: 0.4852; auc: 0.9569 - val_auc: 0.8663
# epoch: 0070, loss: 0.2883 - val_loss: 0.4899; auc: 0.9579 - val_auc: 0.8650
# epoch: 0071, loss: 0.2874 - val_loss: 0.4899; auc: 0.9581 - val_auc: 0.8654
# epoch: 0072, loss: 0.2793 - val_loss: 0.4817; auc: 0.9592 - val_auc: 0.8659
# epoch: 0073, loss: 0.2799 - val_loss: 0.4891; auc: 0.9597 - val_auc: 0.8652
# epoch: 0074, loss: 0.2744 - val_loss: 0.4890; auc: 0.9607 - val_auc: 0.8665
# epoch: 0075, loss: 0.2733 - val_loss: 0.4871; auc: 0.9617 - val_auc: 0.8674
# epoch: 0076, loss: 0.2736 - val_loss: 0.5093; auc: 0.9618 - val_auc: 0.8656
# epoch: 0077, loss: 0.2725 - val_loss: 0.5017; auc: 0.9627 - val_auc: 0.8679
# epoch: 0078, loss: 0.2719 - val_loss: 0.4898; auc: 0.9632 - val_auc: 0.8677
# epoch: 0079, loss: 0.2678 - val_loss: 0.5028; auc: 0.9633 - val_auc: 0.8663
# epoch: 0080, loss: 0.2624 - val_loss: 0.4945; auc: 0.9648 - val_auc: 0.8672
# epoch: 0081, loss: 0.2590 - val_loss: 0.5025; auc: 0.9655 - val_auc: 0.8688
# epoch: 0082, loss: 0.2608 - val_loss: 0.4946; auc: 0.9659 - val_auc: 0.8691
# epoch: 0083, loss: 0.2687 - val_loss: 0.4941; auc: 0.9668 - val_auc: 0.8695
# epoch: 0084, loss: 0.2571 - val_loss: 0.5077; auc: 0.9675 - val_auc: 0.8675
# epoch: 0085, loss: 0.2620 - val_loss: 0.5003; auc: 0.9681 - val_auc: 0.8679
# epoch: 0086, loss: 0.2696 - val_loss: 0.5048; auc: 0.9675 - val_auc: 0.8677
# epoch: 0087, loss: 0.2647 - val_loss: 0.5103; auc: 0.9682 - val_auc: 0.8706
# epoch: 0088, loss: 0.2705 - val_loss: 0.6203; auc: 0.9683 - val_auc: 0.8686
# epoch: 0089, loss: 0.3074 - val_loss: 0.5377; auc: 0.9680 - val_auc: 0.8668
# epoch: 0090, loss: 0.2730 - val_loss: 0.5049; auc: 0.9692 - val_auc: 0.8688
# epoch: 0091, loss: 0.2514 - val_loss: 0.5359; auc: 0.9704 - val_auc: 0.8691
# epoch: 0092, loss: 0.2491 - val_loss: 0.5074; auc: 0.9714 - val_auc: 0.8674
# epoch: 0093, loss: 0.2401 - val_loss: 0.5072; auc: 0.9716 - val_auc: 0.8691
# epoch: 0094, loss: 0.2403 - val_loss: 0.5124; auc: 0.9721 - val_auc: 0.8693
# epoch: 0095, loss: 0.2447 - val_loss: 0.5030; auc: 0.9732 - val_auc: 0.8691
# epoch: 0096, loss: 0.2443 - val_loss: 0.5142; auc: 0.9720 - val_auc: 0.8695
# epoch: 0097, loss: 0.2456 - val_loss: 0.5145; auc: 0.9730 - val_auc: 0.8666
#
# Restoring model weights from the end of the best epoch.
#
# Epoch 00097: early stopping
# MultiClassEstimator(gpuid='0')

# %% [markdown]
# ## plot training history

# %%
pd.DataFrame(clf.history.history)[['accuracy', 'val_accuracy']].rename(columns={'accuracy':'auc', 'val_accuracy':'val_auc'}).plot()
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(clf.history.history)[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
print('Best epochs: %.2f, Best loss: %.2f' % (clf._performance.best_epoch, clf._performance.best))
# Out:
# Best epochs: 46.00, Best loss: 0.47

# %% [markdown]
# # performance on  test set

# %%
auc = clf.score(testX, testY)

# %%
auc
# Out:
# 0.8935828877005347

# %%
df_pred = pd.DataFrame([testY[:, 0], clf.predict_proba(testX)[:,0]]).T
df_pred.columns=['y_true', 'y_pred_prob']

# %%
df_pred.head(5)
# Out:
#    y_true  y_pred_prob
# 0     1.0     0.961530
# 1     0.0     0.479526
# 2     1.0     0.977022
# 3     1.0     0.839713
# 4     0.0     0.187806

# %%
df_pred.plot(figsize=(16, 4))
# Out:
# <AxesSubplot:>

# %%
df_pred.corr()
# Out:
#                y_true  y_pred_prob
# y_true       1.000000     0.679407
# y_pred_prob  0.679407     1.000000
