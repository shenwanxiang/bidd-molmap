# %%
from molmap.model import RegressionEstimator, MultiClassEstimator, MultiLabelEstimator
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from chembench import dataset
from sklearn.utils import shuffle 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from molmap import MolMap
from molmap import feature

def Rdsplit(df, random_state = 888, split_size = [0.8, 0.1, 0.1]):
    base_indices = np.arange(len(df)) 
    base_indices = shuffle(base_indices, random_state = random_state) 
    nb_test = int(len(base_indices) * split_size[2]) 
    nb_val = int(len(base_indices) * split_size[1]) 
    test_idx = base_indices[0:nb_test] 
    valid_idx = base_indices[(nb_test):(nb_test+nb_val)] 
    train_idx = base_indices[(nb_test+nb_val):len(base_indices)] 
    print(len(train_idx), len(valid_idx), len(test_idx)) 
    return train_idx, valid_idx, test_idx

# %%
data = dataset.load_BACE()
# Out:
# total samples: 1513

# %% [markdown]
# ## Pre-fit your molmap object

# %%
mp1 = MolMap(ftype='descriptor',metric='cosine',)
mp1.fit(verbose=0, method='umap', min_dist=0.1, n_neighbors=15,)
# Out:
# 2021-04-24 09:16:45,881 - INFO - [bidd-molmap] - Applying grid feature map(assignment), this may take several minutes(1~30 min)
# 2021-04-24 09:16:48,708 - INFO - [bidd-molmap] - Finished

# %%
bitsinfo = feature.fingerprint.Extraction().bitsinfo
flist = bitsinfo[bitsinfo.Subtypes.isin(['PubChemFP'])].IDs.tolist()
mp2 = MolMap(ftype = 'fingerprint', fmap_type = 'scatter', flist = flist) # 
mp2.fit(method = 'umap',  min_dist = 0.1, n_neighbors = 15, verbose = 0)
# Out:
# 2021-04-24 09:16:53,896 - INFO - [bidd-molmap] - Applying naive scatter feature map...
# 2021-04-24 09:16:53,904 - INFO - [bidd-molmap] - Finished

# %% [markdown]
# ## Extract Fmaps

# %%
X1 = mp1.batch_transform(data.x)
X2 = mp2.batch_transform(data.x)
# Out:
# 100%|##########| 1513/1513 [01:30<00:00, 16.68it/s]
# 100%|##########| 1513/1513 [00:49<00:00, 30.60it/s]

# %%
Y = pd.get_dummies(data.df['Class']).values
Y.shape
# Out:
# (1513, 2)

# %%
train_idx, valid_idx, test_idx  = Rdsplit(data.df, random_state = 888)
trainX = (X1[train_idx], X2[train_idx])
validX = (X1[valid_idx], X2[valid_idx])
testX = (X1[test_idx], X2[test_idx])

trainY = Y[train_idx]
validY = Y[valid_idx]
testY = Y[test_idx]
# Out:
# 1211 151 151

# %%
# define your model, note that if your task is a multi-label problem, you should use MultiLabelEstimator
clf = MultiClassEstimator(n_outputs=trainY.shape[1], 
                          fmap_shape1 = X1.shape[1:],
                          fmap_shape2 = X2.shape[1:],
                          metric='ROC', 
                          dense_layers = [128, 64],  gpuid = 0)
# Out:
# MultiClassEstimator(gpuid='0')

# %%
# fit your model
clf.fit(trainX, trainY, validX, validY )
# Out:
# epoch: 0001, loss: 0.6898 - val_loss: 0.6794; auc: 0.7948 - val_auc: 0.7536
# epoch: 0002, loss: 0.6759 - val_loss: 0.6679; auc: 0.8105 - val_auc: 0.7770
# epoch: 0003, loss: 0.6627 - val_loss: 0.6561; auc: 0.8193 - val_auc: 0.7896
# epoch: 0004, loss: 0.6497 - val_loss: 0.6459; auc: 0.8232 - val_auc: 0.7969
# epoch: 0005, loss: 0.6418 - val_loss: 0.6328; auc: 0.8292 - val_auc: 0.8012
# epoch: 0006, loss: 0.6276 - val_loss: 0.6213; auc: 0.8391 - val_auc: 0.8125
# epoch: 0007, loss: 0.6071 - val_loss: 0.6040; auc: 0.8414 - val_auc: 0.8154
# epoch: 0008, loss: 0.5869 - val_loss: 0.5844; auc: 0.8478 - val_auc: 0.8205
# epoch: 0009, loss: 0.5658 - val_loss: 0.5686; auc: 0.8523 - val_auc: 0.8266
# epoch: 0010, loss: 0.5520 - val_loss: 0.5640; auc: 0.8548 - val_auc: 0.8260
# epoch: 0011, loss: 0.5339 - val_loss: 0.5502; auc: 0.8596 - val_auc: 0.8317
# epoch: 0012, loss: 0.5144 - val_loss: 0.5314; auc: 0.8646 - val_auc: 0.8335
# epoch: 0013, loss: 0.5047 - val_loss: 0.5201; auc: 0.8686 - val_auc: 0.8378
# epoch: 0014, loss: 0.4945 - val_loss: 0.5211; auc: 0.8724 - val_auc: 0.8381
# epoch: 0015, loss: 0.4858 - val_loss: 0.5123; auc: 0.8753 - val_auc: 0.8410
# epoch: 0016, loss: 0.4709 - val_loss: 0.5024; auc: 0.8795 - val_auc: 0.8422
# epoch: 0017, loss: 0.4692 - val_loss: 0.5098; auc: 0.8812 - val_auc: 0.8429
# epoch: 0018, loss: 0.4623 - val_loss: 0.5035; auc: 0.8848 - val_auc: 0.8463
# epoch: 0019, loss: 0.4575 - val_loss: 0.5092; auc: 0.8875 - val_auc: 0.8468
# epoch: 0020, loss: 0.4575 - val_loss: 0.5199; auc: 0.8903 - val_auc: 0.8484
# epoch: 0021, loss: 0.4655 - val_loss: 0.4843; auc: 0.8923 - val_auc: 0.8513
# epoch: 0022, loss: 0.4339 - val_loss: 0.4853; auc: 0.8945 - val_auc: 0.8507
# epoch: 0023, loss: 0.4277 - val_loss: 0.4833; auc: 0.8965 - val_auc: 0.8500
# epoch: 0024, loss: 0.4199 - val_loss: 0.4879; auc: 0.8986 - val_auc: 0.8513
# epoch: 0025, loss: 0.4228 - val_loss: 0.4774; auc: 0.9019 - val_auc: 0.8511
# epoch: 0026, loss: 0.4090 - val_loss: 0.4763; auc: 0.9038 - val_auc: 0.8515
# epoch: 0027, loss: 0.4126 - val_loss: 0.4766; auc: 0.9055 - val_auc: 0.8522
# epoch: 0028, loss: 0.4083 - val_loss: 0.4742; auc: 0.9073 - val_auc: 0.8518
# epoch: 0029, loss: 0.4071 - val_loss: 0.4967; auc: 0.9094 - val_auc: 0.8539
# epoch: 0030, loss: 0.4039 - val_loss: 0.4930; auc: 0.9111 - val_auc: 0.8543
# epoch: 0031, loss: 0.4027 - val_loss: 0.4749; auc: 0.9122 - val_auc: 0.8548
# epoch: 0032, loss: 0.3928 - val_loss: 0.4736; auc: 0.9142 - val_auc: 0.8548
# epoch: 0033, loss: 0.3846 - val_loss: 0.4748; auc: 0.9164 - val_auc: 0.8573
# epoch: 0034, loss: 0.3906 - val_loss: 0.4801; auc: 0.9173 - val_auc: 0.8575
# epoch: 0035, loss: 0.3836 - val_loss: 0.4688; auc: 0.9192 - val_auc: 0.8564
# epoch: 0036, loss: 0.3734 - val_loss: 0.4740; auc: 0.9210 - val_auc: 0.8584
# epoch: 0037, loss: 0.3757 - val_loss: 0.4779; auc: 0.9218 - val_auc: 0.8591
# epoch: 0038, loss: 0.3738 - val_loss: 0.4891; auc: 0.9223 - val_auc: 0.8579
# epoch: 0039, loss: 0.3828 - val_loss: 0.4664; auc: 0.9246 - val_auc: 0.8595
# epoch: 0040, loss: 0.3668 - val_loss: 0.4642; auc: 0.9258 - val_auc: 0.8579
# epoch: 0041, loss: 0.3580 - val_loss: 0.4766; auc: 0.9273 - val_auc: 0.8603
# epoch: 0042, loss: 0.3563 - val_loss: 0.4670; auc: 0.9289 - val_auc: 0.8605
# epoch: 0043, loss: 0.3523 - val_loss: 0.4618; auc: 0.9303 - val_auc: 0.8618
# epoch: 0044, loss: 0.3501 - val_loss: 0.4609; auc: 0.9317 - val_auc: 0.8632
# epoch: 0045, loss: 0.3433 - val_loss: 0.4731; auc: 0.9326 - val_auc: 0.8651
# epoch: 0046, loss: 0.3505 - val_loss: 0.4637; auc: 0.9340 - val_auc: 0.8634
# epoch: 0047, loss: 0.3407 - val_loss: 0.4622; auc: 0.9355 - val_auc: 0.8643
# epoch: 0048, loss: 0.3407 - val_loss: 0.4601; auc: 0.9370 - val_auc: 0.8658
# epoch: 0049, loss: 0.3341 - val_loss: 0.4782; auc: 0.9378 - val_auc: 0.8658
# epoch: 0050, loss: 0.3417 - val_loss: 0.4606; auc: 0.9389 - val_auc: 0.8673
# epoch: 0051, loss: 0.3276 - val_loss: 0.4704; auc: 0.9406 - val_auc: 0.8682
# epoch: 0052, loss: 0.3323 - val_loss: 0.4664; auc: 0.9415 - val_auc: 0.8683
# epoch: 0053, loss: 0.3210 - val_loss: 0.4892; auc: 0.9429 - val_auc: 0.8676
# epoch: 0054, loss: 0.3435 - val_loss: 0.4928; auc: 0.9437 - val_auc: 0.8682
# epoch: 0055, loss: 0.3376 - val_loss: 0.4731; auc: 0.9437 - val_auc: 0.8701
# epoch: 0056, loss: 0.3151 - val_loss: 0.4705; auc: 0.9447 - val_auc: 0.8701
# epoch: 0057, loss: 0.3388 - val_loss: 0.4658; auc: 0.9463 - val_auc: 0.8676
# epoch: 0058, loss: 0.3201 - val_loss: 0.4737; auc: 0.9475 - val_auc: 0.8712
# epoch: 0059, loss: 0.3241 - val_loss: 0.4959; auc: 0.9468 - val_auc: 0.8671
# epoch: 0060, loss: 0.3189 - val_loss: 0.4713; auc: 0.9482 - val_auc: 0.8710
# epoch: 0061, loss: 0.3271 - val_loss: 0.4902; auc: 0.9499 - val_auc: 0.8710
# epoch: 0062, loss: 0.3172 - val_loss: 0.4627; auc: 0.9510 - val_auc: 0.8728
# epoch: 0063, loss: 0.3127 - val_loss: 0.4847; auc: 0.9519 - val_auc: 0.8706
# epoch: 0064, loss: 0.3016 - val_loss: 0.4688; auc: 0.9534 - val_auc: 0.8719
# epoch: 0065, loss: 0.3167 - val_loss: 0.4666; auc: 0.9534 - val_auc: 0.8694
# epoch: 0066, loss: 0.3013 - val_loss: 0.4854; auc: 0.9554 - val_auc: 0.8728
# epoch: 0067, loss: 0.3041 - val_loss: 0.4623; auc: 0.9557 - val_auc: 0.8703
# epoch: 0068, loss: 0.2875 - val_loss: 0.4611; auc: 0.9558 - val_auc: 0.8737
# epoch: 0069, loss: 0.2905 - val_loss: 0.4632; auc: 0.9570 - val_auc: 0.8733
# epoch: 0070, loss: 0.2860 - val_loss: 0.4739; auc: 0.9583 - val_auc: 0.8735
# epoch: 0071, loss: 0.2859 - val_loss: 0.4662; auc: 0.9580 - val_auc: 0.8717
# epoch: 0072, loss: 0.2767 - val_loss: 0.4613; auc: 0.9598 - val_auc: 0.8742
# epoch: 0073, loss: 0.2772 - val_loss: 0.4681; auc: 0.9603 - val_auc: 0.8722
# epoch: 0074, loss: 0.2705 - val_loss: 0.4667; auc: 0.9613 - val_auc: 0.8740
# epoch: 0075, loss: 0.2707 - val_loss: 0.4665; auc: 0.9625 - val_auc: 0.8730
# epoch: 0076, loss: 0.2694 - val_loss: 0.4903; auc: 0.9626 - val_auc: 0.8728
# epoch: 0077, loss: 0.2702 - val_loss: 0.4811; auc: 0.9635 - val_auc: 0.8738
# epoch: 0078, loss: 0.2701 - val_loss: 0.4692; auc: 0.9642 - val_auc: 0.8742
# epoch: 0079, loss: 0.2667 - val_loss: 0.4818; auc: 0.9638 - val_auc: 0.8715
# epoch: 0080, loss: 0.2604 - val_loss: 0.4701; auc: 0.9659 - val_auc: 0.8753
# epoch: 0081, loss: 0.2569 - val_loss: 0.4905; auc: 0.9664 - val_auc: 0.8749
# epoch: 0082, loss: 0.2569 - val_loss: 0.4717; auc: 0.9672 - val_auc: 0.8751
# epoch: 0083, loss: 0.2701 - val_loss: 0.4768; auc: 0.9680 - val_auc: 0.8754
# epoch: 0084, loss: 0.2519 - val_loss: 0.4756; auc: 0.9689 - val_auc: 0.8740
# epoch: 0085, loss: 0.2485 - val_loss: 0.4793; auc: 0.9694 - val_auc: 0.8730
# epoch: 0086, loss: 0.2590 - val_loss: 0.4872; auc: 0.9694 - val_auc: 0.8735
# epoch: 0087, loss: 0.2526 - val_loss: 0.4749; auc: 0.9705 - val_auc: 0.8772
# epoch: 0088, loss: 0.2567 - val_loss: 0.5360; auc: 0.9704 - val_auc: 0.8753
# epoch: 0089, loss: 0.2800 - val_loss: 0.5434; auc: 0.9703 - val_auc: 0.8738
# epoch: 0090, loss: 0.2855 - val_loss: 0.5142; auc: 0.9700 - val_auc: 0.8749
# epoch: 0091, loss: 0.2591 - val_loss: 0.4916; auc: 0.9710 - val_auc: 0.8744
# epoch: 0092, loss: 0.2561 - val_loss: 0.4809; auc: 0.9725 - val_auc: 0.8746
# epoch: 0093, loss: 0.2392 - val_loss: 0.4918; auc: 0.9729 - val_auc: 0.8765
# epoch: 0094, loss: 0.2411 - val_loss: 0.4984; auc: 0.9733 - val_auc: 0.8758
# epoch: 0095, loss: 0.2442 - val_loss: 0.4775; auc: 0.9750 - val_auc: 0.8774
# epoch: 0096, loss: 0.2415 - val_loss: 0.4857; auc: 0.9732 - val_auc: 0.8735
# epoch: 0097, loss: 0.2418 - val_loss: 0.4931; auc: 0.9740 - val_auc: 0.8742
# epoch: 0098, loss: 0.2260 - val_loss: 0.5066; auc: 0.9753 - val_auc: 0.8747
#
# Restoring model weights from the end of the best epoch.
#
# Epoch 00098: early stopping
# MultiClassEstimator(gpuid='0')

# %% [markdown]
# ## plot training history

# %%
pd.DataFrame(clf.history.history)[['accuracy', 'val_accuracy']].rename(columns={'accuracy':'auc', 'val_accuracy':'val_auc'}).plot()
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(clf.history.history)[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
print('Best epochs: %.2f, Best loss: %.2f' % (clf._performance.best_epoch, clf._performance.best))
# Out:
# Best epochs: 47.00, Best loss: 0.46

# %% [markdown]
# # performance on  test set

# %%
auc = clf.score(testX, testY)

# %%
auc
# Out:
# 0.8942959001782531

# %%
df_pred = pd.DataFrame([testY[:, 0], clf.predict_proba(testX)[:,0]]).T
df_pred.columns=['y_true', 'y_pred_prob']

# %%
df_pred.head(5)
# Out:
#    y_true  y_pred_prob
# 0     1.0     0.959249
# 1     0.0     0.421290
# 2     1.0     0.967951
# 3     1.0     0.875520
# 4     0.0     0.137767

# %%
df_pred.plot(figsize=(16, 4))
# Out:
# <AxesSubplot:>

# %%
df_pred.corr()
# Out:
#                y_true  y_pred_prob
# y_true       1.000000     0.689067
# y_pred_prob  0.689067     1.000000
