# %%
# %config Completer.use_jedi = False

# %%
from molmap import LocalAASeqMolMap

# %%
lamp = LocalAASeqMolMap()

# %%
lamp.df_index1

# %%
lamp.df_index2

# %%
lamp.df_index3
# Out:
#       accession_number animo_acid_key   value                         group
# 48920       BASU010101            A,A -0.0479  pair-wise contact potentials
# 48921       BASU010101            A,C -0.0150  pair-wise contact potentials
# 48922       BASU010101            A,D  0.1049  pair-wise contact potentials
# 48923       BASU010101            A,E  0.1018  pair-wise contact potentials
# 48924       BASU010101            A,F  0.1169  pair-wise contact potentials
# ...                ...            ...     ...                           ...
# 67715       ZHAC000106            Y,S  0.0900  pair-wise contact potentials
# 67716       ZHAC000106            Y,T -0.3100  pair-wise contact potentials
# 67717       ZHAC000106            Y,V -0.3800  pair-wise contact potentials
# 67718       ZHAC000106            Y,W  0.2000  pair-wise contact potentials
# 67719       ZHAC000106            Y,Y -0.5700  pair-wise contact potentials
#
# [18800 rows x 4 columns]

# %%
lamp.fit('MLMPKKNRIAIHELLFKEGVMVAKKDVHMPKHPELAD')

# %%
import  seaborn as sns

# %%
sns.heatmap(lamp.get_matrices_aas_orders())

# %%
sns.heatmap(lamp.get_matrices_contact_potentials())

# %%
sns.heatmap(lamp.get_matrices_index_dist())

# %%
sns.heatmap(lamp.get_matrices_mutation())

# %%
sns.heatmap(lamp.expand_aaindex())
