# %%
from molmap import model as molmodel
import molmap

import matplotlib.pyplot as plt

import pandas as pd
from tqdm import tqdm
from joblib import load, dump
tqdm.pandas(ascii=True)
import numpy as np

import tensorflow as tf
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
np.random.seed(123)
tf.compat.v1.set_random_seed(123)
# Out:
# RDKit WARNING: [22:00:19] Enabling RDKit 2019.09.2 jupyter extensions

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
tmp_feature_dir = './tmpignore'
if not os.path.exists(tmp_feature_dir):
    os.makedirs(tmp_feature_dir)

# %%
#load dataset
from molmap import dataset
data = dataset.load_CYP450()
df = data.data
X_smiles = df.smiles.tolist()
task_name = 'CYP450'
# Out:
# total samples: 16896

# %%
MASK = -1
tasks = ['label_1a2', 'label_2c19', 'label_2c9', 'label_2d6', 'label_3a4']
Y = df[tasks].astype('float').fillna(MASK).values
if Y.shape[1] == 0:
    Y = Y.reshape(-1, 1)

# %% [markdown]
# # featurizer

# %%
mp1 = molmap.loadmap('../descriptor.mp')
mp2 = molmap.loadmap('../fingerprint.mp')

X1_name = os.path.join(tmp_feature_dir, 'X1_%s.data' % task_name)
X2_name = os.path.join(tmp_feature_dir, 'X2_%s.data' % task_name)
if not os.path.exists(X1_name):
    X1 = mp1.batch_transform(df.smiles, n_jobs = 8)
    dump(X1, X1_name)
else:
    X1 = load(X1_name)

if not os.path.exists(X2_name): 
    X2 = mp2.batch_transform(df.smiles, n_jobs = 8)
    dump(X2, X2_name)
else:
    X2 = load(X2_name)

molmap1_size = X1.shape[1:]
molmap2_size = X2.shape[1:]

# %% [markdown]
# # Perfor a 10 fold Cross-validation to find best epochs

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = 10, shuffle=True, random_state=123)

train_valid_idx = df[df.group != 'test set'].index.tolist()
test_idx = df[df.group == 'test set'].index.tolist()
testX = (X1[test_idx], X2[test_idx])
testY = Y[test_idx]

def get_pos_weights(trainY):
    """pos_weights: neg_n / pos_n """
    dfY = pd.DataFrame(trainY)
    pos = dfY == 1
    pos_n = pos.sum(axis=0)
    neg = dfY == 0
    neg_n = neg.sum(axis=0)
    pos_weights = (neg_n / pos_n).values
    neg_weights = (pos_n / neg_n).values
    return pos_weights, neg_weights

pos_weights, neg_weights = get_pos_weights(Y[train_valid_idx])

epochs = 800
patience = 50 #early stopping

dense_layers = [256, 128, 32]
batch_size = 128
lr = 1e-4
weight_decay = 0
monitor = 'val_auc'
metric = 'ROC'
dense_avf = 'relu'
last_avf = None #sigmoid in loss

# %% [markdown]
# ## 10 fold-cv

# %%
import tensorflow_addons as tfa
    
model_performance_10fcv = []
model_performance_history = []
i = 0
for train_idx, valid_idx in kf.split(train_valid_idx):
    
    trainX = (X1[train_idx], X2[train_idx])
    trainY = Y[train_idx]

    validX = (X1[valid_idx], X2[valid_idx])
    validY = Y[valid_idx]

    loss = lambda y_true, y_pred: molmodel.loss.weighted_cross_entropy(y_true,y_pred, pos_weights, MASK = -1)
    opt = tfa.optimizers.AdamW(weight_decay = 0.0,learning_rate=lr,beta_1=0.9,beta_2=0.999, epsilon=1e-08)

    model = molmodel.net.DoublePathNet(molmap1_size, molmap2_size, 
                                       n_outputs=Y.shape[-1], 
                                       dense_layers=dense_layers, 
                                       dense_avf = dense_avf, 
                                       last_avf=last_avf)
    model.compile(optimizer = opt, loss = loss)
    performance = molmodel.cbks.CLA_EarlyStoppingAndPerformance((trainX, trainY), 
                                                                (validX, validY), 
                                                                patience = patience,
                                                                metric = metric,
                                                                criteria = monitor)

    model.fit(trainX, trainY, batch_size=batch_size, 
              epochs=epochs, verbose= 0, shuffle = True, 
              validation_data = (validX, validY), 
              callbacks=[performance]) 
    model.save('model-fold-%s.h5' % str(i).zfill(2))

    best_epoch = performance.best_epoch
    train_pfs = performance.evaluate(trainX, trainY)            
    valid_pfs = performance.evaluate(validX, validY)            
    final_res = {    'fold':i,
                     'task_name':task_name,            
                     'train_pfs':train_pfs, 
                     'metric': metric,
                     'valid_pfs':valid_pfs,                      
                     'best_epoch': best_epoch,
                     'batch_size':batch_size,
                     'lr': lr,
                     'weight_decay':weight_decay
                    }
    model_performance_10fcv.append(final_res)
    model_performance_history.append(performance.history)
    i += 1
# Out:
# epoch: 0001, loss: 0.8410 - val_loss: 0.7799; auc: 0.7870 - val_auc: 0.7860
# epoch: 0002, loss: 0.7438 - val_loss: 0.7191; auc: 0.8362 - val_auc: 0.8326
# epoch: 0003, loss: 0.6937 - val_loss: 0.6767; auc: 0.8600 - val_auc: 0.8534
# epoch: 0004, loss: 0.6667 - val_loss: 0.6614; auc: 0.8727 - val_auc: 0.8638
# epoch: 0005, loss: 0.6490 - val_loss: 0.6519; auc: 0.8790 - val_auc: 0.8692
# epoch: 0006, loss: 0.6406 - val_loss: 0.6487; auc: 0.8835 - val_auc: 0.8720
# epoch: 0007, loss: 0.6305 - val_loss: 0.6358; auc: 0.8882 - val_auc: 0.8760
# epoch: 0008, loss: 0.6242 - val_loss: 0.6450; auc: 0.8924 - val_auc: 0.8782
# epoch: 0009, loss: 0.6145 - val_loss: 0.6335; auc: 0.8961 - val_auc: 0.8807
# epoch: 0010, loss: 0.6082 - val_loss: 0.6276; auc: 0.8995 - val_auc: 0.8830
# epoch: 0011, loss: 0.6016 - val_loss: 0.6215; auc: 0.9029 - val_auc: 0.8847
# epoch: 0012, loss: 0.5948 - val_loss: 0.6197; auc: 0.9064 - val_auc: 0.8869
# epoch: 0013, loss: 0.5916 - val_loss: 0.6154; auc: 0.9094 - val_auc: 0.8888
# epoch: 0014, loss: 0.5877 - val_loss: 0.6245; auc: 0.9108 - val_auc: 0.8893
# epoch: 0015, loss: 0.5809 - val_loss: 0.6079; auc: 0.9151 - val_auc: 0.8916
# epoch: 0016, loss: 0.5714 - val_loss: 0.6091; auc: 0.9176 - val_auc: 0.8930
# epoch: 0017, loss: 0.5653 - val_loss: 0.6109; auc: 0.9205 - val_auc: 0.8943
# epoch: 0018, loss: 0.5625 - val_loss: 0.6182; auc: 0.9223 - val_auc: 0.8944
# epoch: 0070, loss: 0.3279 - val_loss: 0.7244; auc: 0.9900 - val_auc: 0.9139
# epoch: 0071, loss: 0.3206 - val_loss: 0.7778; auc: 0.9901 - val_auc: 0.9127
# epoch: 0072, loss: 0.3226 - val_loss: 0.6971; auc: 0.9905 - val_auc: 0.9150
# epoch: 0073, loss: 0.3195 - val_loss: 0.7810; auc: 0.9903 - val_auc: 0.9156
# epoch: 0074, loss: 0.3276 - val_loss: 0.7046; auc: 0.9910 - val_auc: 0.9159
# epoch: 0075, loss: 0.3138 - val_loss: 0.8301; auc: 0.9921 - val_auc: 0.9134
# epoch: 0076, loss: 0.3133 - val_loss: 0.7405; auc: 0.9922 - val_auc: 0.9152
# epoch: 0077, loss: 0.3077 - val_loss: 0.7349; auc: 0.9925 - val_auc: 0.9154
# epoch: 0078, loss: 0.3084 - val_loss: 0.7684; auc: 0.9928 - val_auc: 0.9139
# epoch: 0079, loss: 0.3031 - val_loss: 0.7737; auc: 0.9928 - val_auc: 0.9142
# epoch: 0080, loss: 0.3003 - val_loss: 0.8985; auc: 0.9938 - val_auc: 0.9120
# epoch: 0081, loss: 0.3018 - val_loss: 0.7467; auc: 0.9941 - val_auc: 0.9139
# epoch: 0082, loss: 0.2948 - val_loss: 0.7962; auc: 0.9942 - val_auc: 0.9127
# epoch: 0083, loss: 0.2922 - val_loss: 0.8097; auc: 0.9948 - val_auc: 0.9114
# epoch: 0084, loss: 0.2938 - val_loss: 0.7926; auc: 0.9950 - val_auc: 0.9115
# epoch: 0085, loss: 0.2922 - val_loss: 0.7815; auc: 0.9953 - val_auc: 0.9123
# epoch: 0086, loss: 0.2921 - val_loss: 0.9826; auc: 0.9952 - val_auc: 0.9097
# epoch: 0087, loss: 0.2887 - val_loss: 0.7637; auc: 0.9956 - val_auc: 0.9125
# epoch: 0088, loss: 0.2870 - val_loss: 0.7513; auc: 0.9957 - val_auc: 0.9129
# epoch: 0089, loss: 0.2812 - val_loss: 0.8990; auc: 0.9960 - val_auc: 0.9115
# epoch: 0090, loss: 0.2800 - val_loss: 0.8021; auc: 0.9964 - val_auc: 0.9116
# epoch: 0091, loss: 0.2796 - val_loss: 0.8431; auc: 0.9964 - val_auc: 0.9119
# epoch: 0092, loss: 0.2786 - val_loss: 0.8751; auc: 0.9967 - val_auc: 0.9121
# epoch: 0093, loss: 0.2768 - val_loss: 0.9537; auc: 0.9965 - val_auc: 0.9108
# epoch: 0094, loss: 0.2755 - val_loss: 0.9990; auc: 0.9968 - val_auc: 0.9097
# epoch: 0095, loss: 0.2735 - val_loss: 0.8648; auc: 0.9970 - val_auc: 0.9115
# epoch: 0096, loss: 0.2731 - val_loss: 1.1139; auc: 0.9971 - val_auc: 0.9096
# epoch: 0097, loss: 0.2721 - val_loss: 0.9910; auc: 0.9974 - val_auc: 0.9101
#
# Restoring model weights from the end of the best epoch.
#
# Epoch 00097: early stopping
# epoch: 0001, loss: 0.8374 - val_loss: 0.7694; auc: 0.7800 - val_auc: 0.7874
# epoch: 0089, loss: 0.2778 - val_loss: 0.8131; auc: 0.9969 - val_auc: 0.9125
# epoch: 0090, loss: 0.2731 - val_loss: 0.9144; auc: 0.9971 - val_auc: 0.9100
# epoch: 0091, loss: 0.2823 - val_loss: 0.9231; auc: 0.9968 - val_auc: 0.9116
# epoch: 0092, loss: 0.2715 - val_loss: 0.9755; auc: 0.9973 - val_auc: 0.9104
# epoch: 0093, loss: 0.2768 - val_loss: 0.8539; auc: 0.9972 - val_auc: 0.9103
# epoch: 0094, loss: 0.2678 - val_loss: 0.9473; auc: 0.9974 - val_auc: 0.9101
# epoch: 0095, loss: 0.2750 - val_loss: 0.9733; auc: 0.9974 - val_auc: 0.9114
# epoch: 0096, loss: 0.2730 - val_loss: 0.9349; auc: 0.9976 - val_auc: 0.9109
# epoch: 0097, loss: 0.2669 - val_loss: 0.8843; auc: 0.9979 - val_auc: 0.9112
# epoch: 0098, loss: 0.2668 - val_loss: 0.9351; auc: 0.9979 - val_auc: 0.9097
# epoch: 0099, loss: 0.2629 - val_loss: 0.8809; auc: 0.9981 - val_auc: 0.9129
# epoch: 0100, loss: 0.2598 - val_loss: 0.8467; auc: 0.9983 - val_auc: 0.9105
# epoch: 0101, loss: 0.2614 - val_loss: 1.0252; auc: 0.9981 - val_auc: 0.9087
# epoch: 0102, loss: 0.2851 - val_loss: 0.9798; auc: 0.9981 - val_auc: 0.9111
# epoch: 0103, loss: 0.2641 - val_loss: 0.9110; auc: 0.9984 - val_auc: 0.9106
# epoch: 0104, loss: 0.2573 - val_loss: 0.9220; auc: 0.9985 - val_auc: 0.9104
#
# Restoring model weights from the end of the best epoch.
#
# Epoch 00104: early stopping
# epoch: 0001, loss: 0.8393 - val_loss: 0.7851; auc: 0.7759 - val_auc: 0.7784
# epoch: 0002, loss: 0.7440 - val_loss: 0.7203; auc: 0.8394 - val_auc: 0.8341
# epoch: 0003, loss: 0.6930 - val_loss: 0.6846; auc: 0.8606 - val_auc: 0.8525
# epoch: 0004, loss: 0.6680 - val_loss: 0.6694; auc: 0.8714 - val_auc: 0.8619
# epoch: 0005, loss: 0.6478 - val_loss: 0.6588; auc: 0.8790 - val_auc: 0.8673
# epoch: 0006, loss: 0.6383 - val_loss: 0.6557; auc: 0.8842 - val_auc: 0.8709
# epoch: 0007, loss: 0.6273 - val_loss: 0.6488; auc: 0.8898 - val_auc: 0.8744
# epoch: 0008, loss: 0.6200 - val_loss: 0.6476; auc: 0.8941 - val_auc: 0.8775
# epoch: 0009, loss: 0.6171 - val_loss: 0.6464; auc: 0.8972 - val_auc: 0.8799
# epoch: 0010, loss: 0.6087 - val_loss: 0.6428; auc: 0.9004 - val_auc: 0.8824
# epoch: 0011, loss: 0.6013 - val_loss: 0.6287; auc: 0.9042 - val_auc: 0.8847
# epoch: 0012, loss: 0.5929 - val_loss: 0.6226; auc: 0.9070 - val_auc: 0.8868
# epoch: 0013, loss: 0.5944 - val_loss: 0.6615; auc: 0.9093 - val_auc: 0.8877
# epoch: 0014, loss: 0.5856 - val_loss: 0.6208; auc: 0.9131 - val_auc: 0.8903
# epoch: 0015, loss: 0.5760 - val_loss: 0.6390; auc: 0.9145 - val_auc: 0.8908
# epoch: 0016, loss: 0.5747 - val_loss: 0.6372; auc: 0.9158 - val_auc: 0.8926
# epoch: 0017, loss: 0.5695 - val_loss: 0.6380; auc: 0.9202 - val_auc: 0.8948
# epoch: 0018, loss: 0.5599 - val_loss: 0.6147; auc: 0.9240 - val_auc: 0.8961
# epoch: 0019, loss: 0.5570 - val_loss: 0.6098; auc: 0.9260 - val_auc: 0.8978
# epoch: 0020, loss: 0.5503 - val_loss: 0.6161; auc: 0.9269 - val_auc: 0.8980
# epoch: 0021, loss: 0.5471 - val_loss: 0.6090; auc: 0.9314 - val_auc: 0.9001
# epoch: 0022, loss: 0.5410 - val_loss: 0.6016; auc: 0.9335 - val_auc: 0.9009
# epoch: 0023, loss: 0.5313 - val_loss: 0.6063; auc: 0.9362 - val_auc: 0.9017
# epoch: 0024, loss: 0.5224 - val_loss: 0.6071; auc: 0.9392 - val_auc: 0.9024
# epoch: 0025, loss: 0.5177 - val_loss: 0.6095; auc: 0.9412 - val_auc: 0.9046
# epoch: 0026, loss: 0.5146 - val_loss: 0.6033; auc: 0.9438 - val_auc: 0.9030
# epoch: 0027, loss: 0.5097 - val_loss: 0.5951; auc: 0.9461 - val_auc: 0.9057
# epoch: 0028, loss: 0.5038 - val_loss: 0.5911; auc: 0.9482 - val_auc: 0.9064
# epoch: 0029, loss: 0.5027 - val_loss: 0.6015; auc: 0.9499 - val_auc: 0.9072
# epoch: 0030, loss: 0.4885 - val_loss: 0.6054; auc: 0.9514 - val_auc: 0.9086
# epoch: 0031, loss: 0.4897 - val_loss: 0.6401; auc: 0.9535 - val_auc: 0.9076
# epoch: 0032, loss: 0.4747 - val_loss: 0.5934; auc: 0.9554 - val_auc: 0.9097
# epoch: 0033, loss: 0.4686 - val_loss: 0.5967; auc: 0.9574 - val_auc: 0.9086

# %%
pd.DataFrame(pd.DataFrame(model_performance_history)['val_auc'].tolist()).T.iloc[:90].plot()

# %% [markdown]
# # training the final model, and test on the external dataset

# %%
avg_best_epoch = int(round(pd.DataFrame(model_performance_10fcv).best_epoch.mean()))
avg_best_epoch

# %%
trainX = (X1[train_valid_idx], X2[train_valid_idx])
trainY = Y[train_valid_idx]

loss = lambda y_true, y_pred: molmodel.loss.weighted_cross_entropy(y_true,y_pred, pos_weights, MASK = -1)
opt = tf.keras.optimizers.Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0) #
performance = molmodel.cbks.CLA_EarlyStoppingAndPerformance((trainX, trainY), 
                                                            (testX, testY), 
                                                            patience = patience,
                                                            metric = 'ROC',
                                                            criteria = 'val_auc')


model.compile(optimizer = opt, loss = loss)

model.fit(trainX, trainY, batch_size=batch_size, 
          epochs=epochs, verbose= 0, shuffle = True, 
          validation_data = (testX, testY), 
          callbacks=[performance])

# %%
performance.evaluate(testX, testY) # roc_auc
