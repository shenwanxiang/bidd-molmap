# %%
from molmap import model as molmodel
import molmap

import matplotlib.pyplot as plt

import pandas as pd
from tqdm import tqdm
from joblib import load, dump
tqdm.pandas(ascii=True)
import numpy as np

import tensorflow as tf
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
np.random.seed(123)
tf.compat.v1.set_random_seed(123)


tmp_feature_dir = './tmpignore'
if not os.path.exists(tmp_feature_dir):
    os.makedirs(tmp_feature_dir)

# %%
mp1 = molmap.loadmap('../descriptor.mp')
mp2 = molmap.loadmap('../fingerprint.mp')

# %%
task_name = 'PDBbind-core'

from chembench import load_data

df, induces = load_data(task_name)
# Out:
# loading dataset: PDBbind-core number of split times: 1

# %%
induces = induces*3

# %%
smiles_col = df.columns[0]
values_col = df.columns[1:]
Y = df[values_col].astype('float').values
Y = Y.reshape(-1, 1)


X1_name = os.path.join(tmp_feature_dir, 'X1_%s.data' % task_name)
X2_name = os.path.join(tmp_feature_dir, 'X2_%s.data' % task_name)
if not os.path.exists(X1_name):
    X1 = mp1.batch_transform(df.smiles, n_jobs = 8)
    dump(X1, X1_name)
else:
    X1 = load(X1_name)

if not os.path.exists(X2_name): 
    X2 = mp2.batch_transform(df.smiles, n_jobs = 8)
    dump(X2, X2_name)
else:
    X2 = load(X2_name)

molmap1_size = X1.shape[1:]
molmap2_size = X2.shape[1:]
# Out:
# 100%|##########| 168/168 [00:44<00:00,  3.59it/s]
# 100%|##########| 168/168 [00:03<00:00, 46.55it/s]

# %%
epochs = 800
patience = 50 #early stopping

dense_layers = [256, 128, 32]
batch_size = 128
lr = 1e-4
weight_decay = 0

loss = 'mse'
monitor = 'val_loss'
dense_avf = 'relu'
last_avf = 'linear'

# %%
results = []

for i, split_idxs in enumerate(induces):

    train_idx, valid_idx, test_idx = split_idxs
    
    train_idx = [i for i in train_idx if i < len(df)]
    valid_idx = [i for i in valid_idx if i < len(df)]    
    test_idx = [i for i in test_idx if i < len(df)]
    
    print(len(train_idx), len(valid_idx), len(test_idx))

    trainX = (X1[train_idx], X2[train_idx])
    trainY = Y[train_idx]

    validX = (X1[valid_idx], X2[valid_idx])
    validY = Y[valid_idx]

    testX = (X1[test_idx], X2[test_idx])
    testY = Y[test_idx]            


    model = molmodel.net.DoublePathNet(molmap1_size, molmap2_size, 
                                       n_outputs=Y.shape[-1], 
                                       dense_layers=dense_layers, 
                                       dense_avf = dense_avf, 
                                       last_avf=last_avf)

    opt = tf.keras.optimizers.Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0) #
    #import tensorflow_addons as tfa
    #opt = tfa.optimizers.AdamW(weight_decay = 0.1,learning_rate=0.001,beta1=0.9,beta2=0.999, epsilon=1e-08)
    model.compile(optimizer = opt, loss = loss)
    

    if i == 0:
        performance = molmodel.cbks.Reg_EarlyStoppingAndPerformance((trainX, trainY), 
                                                                   (validX, validY), 
                                                                   patience = patience, 
                                                                   criteria = monitor)
        model.fit(trainX, trainY, batch_size=batch_size, 
              epochs=epochs, verbose= 0, shuffle = True, 
              validation_data = (validX, validY), 
              callbacks=[performance]) 
    else:
        model.fit(trainX, trainY, batch_size=batch_size, 
              epochs = performance.best_epoch + 1, verbose = 1, shuffle = True, 
              validation_data = (validX, validY)) 
            
    performance.model.set_weights(model.get_weights())
    
    best_epoch = performance.best_epoch
    trainable_params = model.count_params()

    train_rmses, train_r2s = performance.evaluate(trainX, trainY)            
    valid_rmses, valid_r2s = performance.evaluate(validX, validY)            
    test_rmses, test_r2s = performance.evaluate(testX, testY)


    final_res = {
                 'task_name':task_name,            
                 'train_rmse':np.nanmean(train_rmses), 
                 'valid_rmse':np.nanmean(valid_rmses),                      
                 'test_rmse':np.nanmean(test_rmses), 

                 'train_r2':np.nanmean(train_r2s), 
                 'valid_r2':np.nanmean(valid_r2s),                      
                 'test_r2':np.nanmean(test_r2s), 

                 '# trainable params': trainable_params,
                 'best_epoch': best_epoch,
                 'batch_size':batch_size,
                 'lr': lr,
                 'weight_decay':weight_decay
                }
    results.append(final_res)
# Out:
# 134 17 17
# WARNING:tensorflow:From /home/shenwanxiang/anaconda3/envs/deepchem23/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# epoch: 0001, loss: 0.9989 - val_loss: 1.0336; rmse: 0.9870 - rmse_val: 1.0167;  r2: 0.2896 - r2_val: 0.1286
# epoch: 0002, loss: 0.9725 - val_loss: 1.0811; rmse: 0.9952 - rmse_val: 1.0397;  r2: 0.3014 - r2_val: 0.1267
# epoch: 0003, loss: 0.9903 - val_loss: 1.0440; rmse: 0.9787 - rmse_val: 1.0217;  r2: 0.3240 - r2_val: 0.1457
# epoch: 0004, loss: 0.9606 - val_loss: 1.0088; rmse: 0.9647 - rmse_val: 1.0044;  r2: 0.3437 - r2_val: 0.1561
# epoch: 0005, loss: 0.9309 - val_loss: 0.9824; rmse: 0.9537 - rmse_val: 0.9911;  r2: 0.3605 - r2_val: 0.1752
# epoch: 0006, loss: 0.9083 - val_loss: 0.9561; rmse: 0.9526 - rmse_val: 0.9778;  r2: 0.3656 - r2_val: 0.1849
# epoch: 0007, loss: 0.9079 - val_loss: 0.9410; rmse: 0.9517 - rmse_val: 0.9701;  r2: 0.3738 - r2_val: 0.2084
# epoch: 0008, loss: 0.9053 - val_loss: 0.9280; rmse: 0.9376 - rmse_val: 0.9633;  r2: 0.3758 - r2_val: 0.2132
# epoch: 0009, loss: 0.8753 - val_loss: 0.9571; rmse: 0.9330 - rmse_val: 0.9783;  r2: 0.3603 - r2_val: 0.1849
# epoch: 0010, loss: 0.8689 - val_loss: 1.0395; rmse: 0.9556 - rmse_val: 1.0195;  r2: 0.3502 - r2_val: 0.1734
# epoch: 0011, loss: 0.9144 - val_loss: 1.0886; rmse: 0.9693 - rmse_val: 1.0433;  r2: 0.3508 - r2_val: 0.1679
# epoch: 0012, loss: 0.9390 - val_loss: 1.0537; rmse: 0.9501 - rmse_val: 1.0265;  r2: 0.3629 - r2_val: 0.1721
# epoch: 0013, loss: 0.9014 - val_loss: 0.9788; rmse: 0.9184 - rmse_val: 0.9893;  r2: 0.3782 - r2_val: 0.1824
# epoch: 0014, loss: 0.8433 - val_loss: 0.9168; rmse: 0.9020 - rmse_val: 0.9575;  r2: 0.3912 - r2_val: 0.1996
# epoch: 0015, loss: 0.8134 - val_loss: 0.8908; rmse: 0.8990 - rmse_val: 0.9438;  r2: 0.3989 - r2_val: 0.2066
# epoch: 0016, loss: 0.8079 - val_loss: 0.8791; rmse: 0.8928 - rmse_val: 0.9376;  r2: 0.4028 - r2_val: 0.2056
# epoch: 0017, loss: 0.7965 - val_loss: 0.8650; rmse: 0.8810 - rmse_val: 0.9301;  r2: 0.4055 - r2_val: 0.2107
# epoch: 0018, loss: 0.7751 - val_loss: 0.8799; rmse: 0.8657 - rmse_val: 0.9380;  r2: 0.3994 - r2_val: 0.1966
# epoch: 0019, loss: 0.7462 - val_loss: 0.9819; rmse: 0.8834 - rmse_val: 0.9909;  r2: 0.3836 - r2_val: 0.1770
# epoch: 0020, loss: 0.7818 - val_loss: 1.0770; rmse: 0.9137 - rmse_val: 1.0378;  r2: 0.3782 - r2_val: 0.1681
# epoch: 0021, loss: 0.8340 - val_loss: 0.9800; rmse: 0.8708 - rmse_val: 0.9900;  r2: 0.4000 - r2_val: 0.1783
# epoch: 0022, loss: 0.7581 - val_loss: 0.8588; rmse: 0.8467 - rmse_val: 0.9267;  r2: 0.4225 - r2_val: 0.1987
# epoch: 0023, loss: 0.7178 - val_loss: 0.8314; rmse: 0.8642 - rmse_val: 0.9118;  r2: 0.4367 - r2_val: 0.2137
# epoch: 0024, loss: 0.7463 - val_loss: 0.8334; rmse: 0.8790 - rmse_val: 0.9129;  r2: 0.4473 - r2_val: 0.2177
# epoch: 0025, loss: 0.7727 - val_loss: 0.8248; rmse: 0.8599 - rmse_val: 0.9082;  r2: 0.4503 - r2_val: 0.2159
# epoch: 0026, loss: 0.7356 - val_loss: 0.8719; rmse: 0.8254 - rmse_val: 0.9338;  r2: 0.4347 - r2_val: 0.1927
# epoch: 0027, loss: 0.6820 - val_loss: 1.0129; rmse: 0.8535 - rmse_val: 1.0064;  r2: 0.4163 - r2_val: 0.1742
# epoch: 0028, loss: 0.7288 - val_loss: 1.0482; rmse: 0.8567 - rmse_val: 1.0238;  r2: 0.4136 - r2_val: 0.1731
# epoch: 0029, loss: 0.7357 - val_loss: 1.0099; rmse: 0.8335 - rmse_val: 1.0049;  r2: 0.4196 - r2_val: 0.1781
# epoch: 0030, loss: 0.6928 - val_loss: 0.9016; rmse: 0.7993 - rmse_val: 0.9495;  r2: 0.4321 - r2_val: 0.1942
# epoch: 0031, loss: 0.6396 - val_loss: 0.8112; rmse: 0.8044 - rmse_val: 0.9007;  r2: 0.4457 - r2_val: 0.2116
# epoch: 0032, loss: 0.6475 - val_loss: 0.8019; rmse: 0.8144 - rmse_val: 0.8955;  r2: 0.4536 - r2_val: 0.2126
# epoch: 0033, loss: 0.6633 - val_loss: 0.8079; rmse: 0.8003 - rmse_val: 0.8989;  r2: 0.4578 - r2_val: 0.2073
# epoch: 0034, loss: 0.6391 - val_loss: 0.8597; rmse: 0.7714 - rmse_val: 0.9272;  r2: 0.4573 - r2_val: 0.1943
# epoch: 0035, loss: 0.5953 - val_loss: 0.9895; rmse: 0.7775 - rmse_val: 0.9947;  r2: 0.4522 - r2_val: 0.1772
# epoch: 0036, loss: 0.6032 - val_loss: 1.1422; rmse: 0.8148 - rmse_val: 1.0687;  r2: 0.4457 - r2_val: 0.1655
# epoch: 0037, loss: 0.6650 - val_loss: 1.1599; rmse: 0.8117 - rmse_val: 1.0770;  r2: 0.4494 - r2_val: 0.1647
# epoch: 0038, loss: 0.6577 - val_loss: 0.9741; rmse: 0.7530 - rmse_val: 0.9870;  r2: 0.4673 - r2_val: 0.1760
# epoch: 0039, loss: 0.5627 - val_loss: 0.8278; rmse: 0.7711 - rmse_val: 0.9099;  r2: 0.4843 - r2_val: 0.1915
# epoch: 0040, loss: 0.5992 - val_loss: 0.8169; rmse: 0.8007 - rmse_val: 0.9038;  r2: 0.4916 - r2_val: 0.1969
# epoch: 0041, loss: 0.6355 - val_loss: 0.9180; rmse: 0.7337 - rmse_val: 0.9581;  r2: 0.4861 - r2_val: 0.1799
# epoch: 0042, loss: 0.5362 - val_loss: 1.2642; rmse: 0.8203 - rmse_val: 1.1244;  r2: 0.4662 - r2_val: 0.1620
# epoch: 0043, loss: 0.6766 - val_loss: 1.2944; rmse: 0.8272 - rmse_val: 1.1377;  r2: 0.4684 - r2_val: 0.1643
# epoch: 0044, loss: 0.6824 - val_loss: 1.0063; rmse: 0.7331 - rmse_val: 1.0032;  r2: 0.4905 - r2_val: 0.1822
# epoch: 0045, loss: 0.5377 - val_loss: 0.8363; rmse: 0.7366 - rmse_val: 0.9145;  r2: 0.5048 - r2_val: 0.2027
# epoch: 0046, loss: 0.5463 - val_loss: 0.8324; rmse: 0.7344 - rmse_val: 0.9123;  r2: 0.5094 - r2_val: 0.2054
# epoch: 0047, loss: 0.5371 - val_loss: 0.9568; rmse: 0.7141 - rmse_val: 0.9782;  r2: 0.5079 - r2_val: 0.1923
# epoch: 0048, loss: 0.5077 - val_loss: 1.1728; rmse: 0.7648 - rmse_val: 1.0829;  r2: 0.5008 - r2_val: 0.1792
# epoch: 0049, loss: 0.5902 - val_loss: 1.0787; rmse: 0.7304 - rmse_val: 1.0386;  r2: 0.5132 - r2_val: 0.1829
# epoch: 0050, loss: 0.5312 - val_loss: 0.8437; rmse: 0.7161 - rmse_val: 0.9185;  r2: 0.5349 - r2_val: 0.1997
# epoch: 0051, loss: 0.5119 - val_loss: 0.8220; rmse: 0.7936 - rmse_val: 0.9066;  r2: 0.5416 - r2_val: 0.2031
# epoch: 0052, loss: 0.6304 - val_loss: 0.8245; rmse: 0.7775 - rmse_val: 0.9080;  r2: 0.5498 - r2_val: 0.1983
# epoch: 0053, loss: 0.5973 - val_loss: 0.9203; rmse: 0.6912 - rmse_val: 0.9593;  r2: 0.5502 - r2_val: 0.1801
# epoch: 0054, loss: 0.4819 - val_loss: 1.2036; rmse: 0.7565 - rmse_val: 1.0971;  r2: 0.5366 - r2_val: 0.1640
# epoch: 0055, loss: 0.5730 - val_loss: 1.2817; rmse: 0.7811 - rmse_val: 1.1321;  r2: 0.5376 - r2_val: 0.1601
# epoch: 0056, loss: 0.6096 - val_loss: 1.1549; rmse: 0.7265 - rmse_val: 1.0747;  r2: 0.5488 - r2_val: 0.1611
# epoch: 0057, loss: 0.5270 - val_loss: 0.9818; rmse: 0.6799 - rmse_val: 0.9909;  r2: 0.5627 - r2_val: 0.1669
# epoch: 0058, loss: 0.4610 - val_loss: 0.8805; rmse: 0.6960 - rmse_val: 0.9383;  r2: 0.5758 - r2_val: 0.1739
# epoch: 0059, loss: 0.4872 - val_loss: 0.8738; rmse: 0.6971 - rmse_val: 0.9347;  r2: 0.5820 - r2_val: 0.1761
# epoch: 0060, loss: 0.4843 - val_loss: 0.9634; rmse: 0.6661 - rmse_val: 0.9815;  r2: 0.5799 - r2_val: 0.1693
# epoch: 0061, loss: 0.4445 - val_loss: 1.0988; rmse: 0.6835 - rmse_val: 1.0483;  r2: 0.5766 - r2_val: 0.1620
# epoch: 0062, loss: 0.4667 - val_loss: 1.1840; rmse: 0.7061 - rmse_val: 1.0881;  r2: 0.5792 - r2_val: 0.1573
# epoch: 0063, loss: 0.4983 - val_loss: 1.1498; rmse: 0.6926 - rmse_val: 1.0723;  r2: 0.5907 - r2_val: 0.1549
# epoch: 0064, loss: 0.4808 - val_loss: 1.0381; rmse: 0.6605 - rmse_val: 1.0189;  r2: 0.6061 - r2_val: 0.1550
# epoch: 0065, loss: 0.4362 - val_loss: 0.9664; rmse: 0.6506 - rmse_val: 0.9831;  r2: 0.6180 - r2_val: 0.1556
# epoch: 0066, loss: 0.4239 - val_loss: 0.9507; rmse: 0.6486 - rmse_val: 0.9751;  r2: 0.6254 - r2_val: 0.1545
# epoch: 0067, loss: 0.4201 - val_loss: 1.0019; rmse: 0.6448 - rmse_val: 1.0010;  r2: 0.6268 - r2_val: 0.1507
# epoch: 0068, loss: 0.4149 - val_loss: 1.1050; rmse: 0.6598 - rmse_val: 1.0512;  r2: 0.6239 - r2_val: 0.1462
# epoch: 0069, loss: 0.4357 - val_loss: 1.1321; rmse: 0.6614 - rmse_val: 1.0640;  r2: 0.6247 - r2_val: 0.1449
# epoch: 0070, loss: 0.4366 - val_loss: 1.0361; rmse: 0.6342 - rmse_val: 1.0179;  r2: 0.6315 - r2_val: 0.1489
# epoch: 0071, loss: 0.4030 - val_loss: 0.9745; rmse: 0.6293 - rmse_val: 0.9871;  r2: 0.6352 - r2_val: 0.1537
# epoch: 0072, loss: 0.3963 - val_loss: 1.0064; rmse: 0.6234 - rmse_val: 1.0032;  r2: 0.6350 - r2_val: 0.1538
# epoch: 0073, loss: 0.3905 - val_loss: 1.0125; rmse: 0.6194 - rmse_val: 1.0062;  r2: 0.6368 - r2_val: 0.1545
# epoch: 0074, loss: 0.3824 - val_loss: 0.9484; rmse: 0.6304 - rmse_val: 0.9739;  r2: 0.6430 - r2_val: 0.1590
# epoch: 0075, loss: 0.3978 - val_loss: 0.9464; rmse: 0.6310 - rmse_val: 0.9728;  r2: 0.6463 - r2_val: 0.1600
# epoch: 0076, loss: 0.3986 - val_loss: 0.9982; rmse: 0.6096 - rmse_val: 0.9991;  r2: 0.6468 - r2_val: 0.1579
# epoch: 0077, loss: 0.3734 - val_loss: 0.9941; rmse: 0.6060 - rmse_val: 0.9971;  r2: 0.6523 - r2_val: 0.1585
# epoch: 0078, loss: 0.3673 - val_loss: 0.9813; rmse: 0.6040 - rmse_val: 0.9906;  r2: 0.6594 - r2_val: 0.1595
# epoch: 0079, loss: 0.3656 - val_loss: 0.9854; rmse: 0.5978 - rmse_val: 0.9927;  r2: 0.6660 - r2_val: 0.1583
# epoch: 0080, loss: 0.3575 - val_loss: 1.0048; rmse: 0.5883 - rmse_val: 1.0024;  r2: 0.6728 - r2_val: 0.1545
# epoch: 0081, loss: 0.3470 - val_loss: 1.0333; rmse: 0.5795 - rmse_val: 1.0165;  r2: 0.6784 - r2_val: 0.1507
# epoch: 0082, loss: 0.3356 - val_loss: 1.0383; rmse: 0.5737 - rmse_val: 1.0190;  r2: 0.6846 - r2_val: 0.1491
#
# Restoring model weights from the end of the best epoch.
#
# Epoch 00082: early stopping
# 134 17 17
# Train on 134 samples, validate on 17 samples
# Epoch 1/32
# 134/134 [==============================] - 1s 8ms/sample - loss: 0.9953 - val_loss: 0.9991
# Epoch 2/32
# 134/134 [==============================] - 0s 336us/sample - loss: 0.9795 - val_loss: 0.9812
# Epoch 3/32
# 134/134 [==============================] - 0s 337us/sample - loss: 0.9676 - val_loss: 0.9773
# Epoch 4/32
# 134/134 [==============================] - 0s 344us/sample - loss: 0.9776 - val_loss: 0.9692
# Epoch 5/32
# 134/134 [==============================] - 0s 346us/sample - loss: 0.9522 - val_loss: 0.9644
# Epoch 6/32
# 134/134 [==============================] - 0s 352us/sample - loss: 0.9197 - val_loss: 0.9614
# Epoch 7/32
# 134/134 [==============================] - 0s 333us/sample - loss: 0.8987 - val_loss: 0.9706
# Epoch 8/32
# 134/134 [==============================] - 0s 332us/sample - loss: 0.8873 - val_loss: 0.9479
# Epoch 9/32
# 134/134 [==============================] - 0s 335us/sample - loss: 0.8729 - val_loss: 0.9401
# Epoch 10/32
# 134/134 [==============================] - 0s 313us/sample - loss: 0.8602 - val_loss: 0.9487
# Epoch 11/32
# 134/134 [==============================] - 0s 318us/sample - loss: 0.8503 - val_loss: 0.9429
# Epoch 12/32
# 134/134 [==============================] - 0s 328us/sample - loss: 0.8349 - val_loss: 0.9262
# Epoch 13/32
# 134/134 [==============================] - 0s 320us/sample - loss: 0.8203 - val_loss: 0.9077
# Epoch 14/32
# 134/134 [==============================] - 0s 313us/sample - loss: 0.8081 - val_loss: 0.8873
# Epoch 15/32
# 134/134 [==============================] - 0s 339us/sample - loss: 0.8077 - val_loss: 0.8766
# Epoch 16/32
# 134/134 [==============================] - 0s 323us/sample - loss: 0.7914 - val_loss: 0.8910
# Epoch 17/32
# 134/134 [==============================] - 0s 384us/sample - loss: 0.7645 - val_loss: 0.9057
# Epoch 18/32
# 134/134 [==============================] - 0s 371us/sample - loss: 0.7546 - val_loss: 0.8904
# Epoch 19/32
# 134/134 [==============================] - 0s 350us/sample - loss: 0.7393 - val_loss: 0.8524
# Epoch 20/32
# 134/134 [==============================] - 0s 324us/sample - loss: 0.7350 - val_loss: 0.8370
# Epoch 21/32
# 134/134 [==============================] - 0s 318us/sample - loss: 0.7487 - val_loss: 0.8322
# Epoch 22/32
# 134/134 [==============================] - 0s 310us/sample - loss: 0.7206 - val_loss: 0.8491
# Epoch 23/32
# 134/134 [==============================] - 0s 335us/sample - loss: 0.6893 - val_loss: 0.8911
# Epoch 24/32
# 134/134 [==============================] - 0s 335us/sample - loss: 0.6843 - val_loss: 0.9058
# Epoch 25/32
# 134/134 [==============================] - 0s 331us/sample - loss: 0.6765 - val_loss: 0.8556
# Epoch 26/32
# 134/134 [==============================] - 0s 338us/sample - loss: 0.6528 - val_loss: 0.8214
# Epoch 27/32
# 134/134 [==============================] - 0s 340us/sample - loss: 0.6444 - val_loss: 0.8526
# Epoch 28/32
# 134/134 [==============================] - 0s 398us/sample - loss: 0.6227 - val_loss: 0.9662
# Epoch 29/32
# 134/134 [==============================] - 0s 320us/sample - loss: 0.6482 - val_loss: 0.9602
# Epoch 30/32
# 134/134 [==============================] - 0s 327us/sample - loss: 0.6319 - val_loss: 0.8414
# Epoch 31/32
# 134/134 [==============================] - 0s 327us/sample - loss: 0.5862 - val_loss: 0.7725
# Epoch 32/32
# 134/134 [==============================] - 0s 326us/sample - loss: 0.6200 - val_loss: 0.7725
# 134 17 17
# Train on 134 samples, validate on 17 samples
# Epoch 1/32
# 134/134 [==============================] - 1s 10ms/sample - loss: 1.0425 - val_loss: 1.0433
# Epoch 2/32
# 134/134 [==============================] - 0s 359us/sample - loss: 0.9871 - val_loss: 1.0083
# Epoch 3/32
# 134/134 [==============================] - 0s 334us/sample - loss: 0.9736 - val_loss: 0.9884
# Epoch 4/32
# 134/134 [==============================] - 0s 316us/sample - loss: 0.9730 - val_loss: 0.9742
# Epoch 5/32
# 134/134 [==============================] - 0s 341us/sample - loss: 0.9435 - val_loss: 0.9778
# Epoch 6/32
# 134/134 [==============================] - 0s 337us/sample - loss: 0.9276 - val_loss: 0.9855
# Epoch 7/32
# 134/134 [==============================] - 0s 345us/sample - loss: 0.9147 - val_loss: 0.9708
# Epoch 8/32
# 134/134 [==============================] - 0s 361us/sample - loss: 0.8988 - val_loss: 0.9534
# Epoch 9/32
# 134/134 [==============================] - 0s 322us/sample - loss: 0.8869 - val_loss: 0.9215
# Epoch 10/32
# 134/134 [==============================] - 0s 330us/sample - loss: 0.8748 - val_loss: 0.9046
# Epoch 11/32
# 134/134 [==============================] - 0s 335us/sample - loss: 0.8622 - val_loss: 0.8937
# Epoch 12/32
# 134/134 [==============================] - 0s 352us/sample - loss: 0.8477 - val_loss: 0.8809
# Epoch 13/32
# 134/134 [==============================] - 0s 340us/sample - loss: 0.8359 - val_loss: 0.8772
# Epoch 14/32
# 134/134 [==============================] - 0s 372us/sample - loss: 0.8126 - val_loss: 0.8766
# Epoch 15/32
# 134/134 [==============================] - 0s 330us/sample - loss: 0.7913 - val_loss: 0.8596
# Epoch 16/32
# 134/134 [==============================] - 0s 355us/sample - loss: 0.7766 - val_loss: 0.8440
# Epoch 17/32
# 134/134 [==============================] - 0s 337us/sample - loss: 0.7687 - val_loss: 0.8423
# Epoch 18/32
# 134/134 [==============================] - 0s 360us/sample - loss: 0.7554 - val_loss: 0.8748
# Epoch 19/32
# 134/134 [==============================] - 0s 370us/sample - loss: 0.7427 - val_loss: 0.9255
# Epoch 20/32
# 134/134 [==============================] - 0s 337us/sample - loss: 0.7513 - val_loss: 0.9123
# Epoch 21/32
# 134/134 [==============================] - 0s 290us/sample - loss: 0.7336 - val_loss: 0.8359
# Epoch 22/32
# 134/134 [==============================] - 0s 329us/sample - loss: 0.7179 - val_loss: 0.8347
# Epoch 23/32
# 134/134 [==============================] - 0s 317us/sample - loss: 0.6992 - val_loss: 0.9450
# Epoch 24/32
# 134/134 [==============================] - 0s 319us/sample - loss: 0.7281 - val_loss: 0.9410
# Epoch 25/32
# 134/134 [==============================] - 0s 342us/sample - loss: 0.7081 - val_loss: 0.8286
# Epoch 26/32
# 134/134 [==============================] - 0s 336us/sample - loss: 0.6772 - val_loss: 0.7991
# Epoch 27/32
# 134/134 [==============================] - 0s 335us/sample - loss: 0.7160 - val_loss: 0.7977
# Epoch 28/32
# 134/134 [==============================] - 0s 331us/sample - loss: 0.7092 - val_loss: 0.8232
# Epoch 29/32
# 134/134 [==============================] - 0s 343us/sample - loss: 0.6566 - val_loss: 0.9062
# Epoch 30/32
# 134/134 [==============================] - 0s 331us/sample - loss: 0.6531 - val_loss: 1.0208
# Epoch 31/32
# 134/134 [==============================] - 0s 330us/sample - loss: 0.7076 - val_loss: 1.1197
# Epoch 32/32
# 134/134 [==============================] - 0s 350us/sample - loss: 0.7669 - val_loss: 1.0928

# %%
pd.DataFrame(performance.history)[['rmse', 'val_rmse']].plot()

# %%
pd.DataFrame(results).test_rmse.mean()
# Out:
# 0.9308629073619796

# %%
pd.DataFrame(results).test_rmse.std()
# Out:
# 0.010189837969875156

# %%
pd.DataFrame(results).to_csv('./results/%s.csv' % task_name)

# %%
pd.DataFrame(results)
# Out:
#       task_name  train_rmse  valid_rmse  test_rmse  train_r2  valid_r2  \
# 0  PDBbind-core    0.814440    0.895514   0.936704  0.453606  0.212553
# 1  PDBbind-core    0.778739    0.878904   0.919097  0.489051  0.240489
# 2  PDBbind-core    0.856180    1.045393   0.936788  0.432641  0.173947
#
#     test_r2  # trainable params  best_epoch  batch_size      lr  weight_decay
# 0  0.144106              803681          31         128  0.0001             0
# 1  0.143098              803681          31         128  0.0001             0
# 2  0.078771              803681          31         128  0.0001             0
