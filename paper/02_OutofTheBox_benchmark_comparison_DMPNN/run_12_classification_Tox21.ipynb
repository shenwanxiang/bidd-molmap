# %%
from molmap import model as molmodel
import molmap

import matplotlib.pyplot as plt

import pandas as pd
from tqdm import tqdm
from joblib import load, dump
tqdm.pandas(ascii=True)
import numpy as np

import tensorflow as tf
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
np.random.seed(123)
tf.compat.v1.set_random_seed(123)


tmp_feature_dir = './tmpignore'
if not os.path.exists(tmp_feature_dir):
    os.makedirs(tmp_feature_dir)

# %%
mp1 = molmap.loadmap('../descriptor.mp')
mp2 = molmap.loadmap('../fingerprint.mp')

# %%
task_name = 'Tox21'
from chembench import load_data
df, induces = load_data(task_name)

MASK = -1
smiles_col = df.columns[0]
values_col = df.columns[1:]
Y = df[values_col].astype('float').fillna(MASK).values
if Y.shape[1] == 0:
    Y = Y.reshape(-1, 1)
# Out:
# loading dataset: Tox21 number of split times: 3

# %%
X1_name = os.path.join(tmp_feature_dir, 'X1_%s.data' % task_name)
X2_name = os.path.join(tmp_feature_dir, 'X2_%s.data' % task_name)
if not os.path.exists(X1_name):
    X1 = mp1.batch_transform(df.smiles, n_jobs = 8)
    dump(X1, X1_name)
else:
    X1 = load(X1_name)

if not os.path.exists(X2_name): 
    X2 = mp2.batch_transform(df.smiles, n_jobs = 8)
    dump(X2, X2_name)
else:
    X2 = load(X2_name)

molmap1_size = X1.shape[1:]
molmap2_size = X2.shape[1:]

# %%
def get_pos_weights(trainY):
    """pos_weights: neg_n / pos_n """
    dfY = pd.DataFrame(trainY)
    pos = dfY == 1
    pos_n = pos.sum(axis=0)
    neg = dfY == 0
    neg_n = neg.sum(axis=0)
    pos_weights = (neg_n / pos_n).values
    neg_weights = (pos_n / neg_n).values
    return pos_weights, neg_weights


prcs_metrics = ['MUV', 'PCBA']

# %%
epochs = 800
patience = 50 #early stopping

dense_layers = [256] #12 outputs

batch_size = 128
lr = 1e-4
weight_decay = 0

monitor = 'val_auc'
dense_avf = 'relu'
last_avf = None #sigmoid in loss

if task_name in prcs_metrics:
    metric = 'PRC'
else:
    metric = 'ROC'

# %%
results = []
for i, split_idxs in enumerate(induces):

    train_idx, valid_idx, test_idx = split_idxs
    print(len(train_idx), len(valid_idx), len(test_idx))

    trainX = (X1[train_idx], X2[train_idx])
    trainY = Y[train_idx]

    validX = (X1[valid_idx], X2[valid_idx])
    validY = Y[valid_idx]

    testX = (X1[test_idx], X2[test_idx])
    testY = Y[test_idx]            

    pos_weights, neg_weights = get_pos_weights(trainY)
    loss = lambda y_true, y_pred: molmodel.loss.weighted_cross_entropy(y_true,y_pred, pos_weights, MASK = -1)

    model = molmodel.net.DoublePathNet(molmap1_size, molmap2_size, 
                                       n_outputs=Y.shape[-1], 
                                       dense_layers=dense_layers, 
                                       dense_avf = dense_avf, 
                                       last_avf=last_avf)

    opt = tf.keras.optimizers.Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0) #
    #import tensorflow_addons as tfa
    #opt = tfa.optimizers.AdamW(weight_decay = 0.1,learning_rate=0.001,beta1=0.9,beta2=0.999, epsilon=1e-08)
    model.compile(optimizer = opt, loss = loss)
    
    if i == 0:
        performance = molmodel.cbks.CLA_EarlyStoppingAndPerformance((trainX, trainY), 
                                                                       (validX, validY), 
                                                                       patience = patience, 
                                                                       criteria = monitor,
                                                                       metric = metric,
                                                                      )
        model.fit(trainX, trainY, batch_size=batch_size, 
              epochs=epochs, verbose= 0, shuffle = True, 
              validation_data = (validX, validY), 
              callbacks=[performance]) 


    else:
        model.fit(trainX, trainY, batch_size=batch_size, 
              epochs = performance.best_epoch + 1, verbose = 1, shuffle = True, 
              validation_data = (validX, validY)) 
            
        performance.model.set_weights(model.get_weights())
    
    best_epoch = performance.best_epoch
    trainable_params = model.count_params()
    
    train_aucs = performance.evaluate(trainX, trainY)            
    valid_aucs = performance.evaluate(validX, validY)            
    test_aucs = performance.evaluate(testX, testY)


    final_res = {
                     'task_name':task_name,            
                     'train_auc':np.nanmean(train_aucs), 
                     'valid_auc':np.nanmean(valid_aucs),                      
                     'test_auc':np.nanmean(test_aucs), 
                     'metric':metric,
                     '# trainable params': trainable_params,
                     'best_epoch': best_epoch,
                     'batch_size':batch_size,
                     'lr': lr,
                     'weight_decay':weight_decay
                    }
    
    results.append(final_res)
# Out:
# 6264 783 784
# epoch: 0001, loss: 1.1676 - val_loss: 1.1352; auc: 0.7202 - val_auc: 0.7286
# epoch: 0002, loss: 1.1242 - val_loss: 1.0737; auc: 0.7322 - val_auc: 0.7526
# epoch: 0003, loss: 1.0769 - val_loss: 1.0175; auc: 0.7421 - val_auc: 0.7597
# epoch: 0004, loss: 1.0456 - val_loss: 1.0051; auc: 0.7507 - val_auc: 0.7660
# epoch: 0005, loss: 1.0288 - val_loss: 0.9814; auc: 0.7651 - val_auc: 0.7799
# epoch: 0006, loss: 1.0103 - val_loss: 0.9693; auc: 0.7727 - val_auc: 0.7855
# epoch: 0007, loss: 0.9963 - val_loss: 0.9614; auc: 0.7821 - val_auc: 0.7915
# epoch: 0008, loss: 0.9879 - val_loss: 0.9494; auc: 0.7858 - val_auc: 0.7926
# epoch: 0009, loss: 0.9706 - val_loss: 0.9664; auc: 0.7923 - val_auc: 0.7969
# epoch: 0010, loss: 0.9620 - val_loss: 0.9368; auc: 0.8042 - val_auc: 0.8036
# epoch: 0011, loss: 0.9519 - val_loss: 0.9258; auc: 0.8112 - val_auc: 0.8099
# epoch: 0012, loss: 0.9386 - val_loss: 0.9245; auc: 0.8207 - val_auc: 0.8153
# epoch: 0013, loss: 0.9285 - val_loss: 0.9072; auc: 0.8264 - val_auc: 0.8183
# epoch: 0014, loss: 0.9157 - val_loss: 0.9078; auc: 0.8352 - val_auc: 0.8214
# epoch: 0015, loss: 0.9049 - val_loss: 0.9027; auc: 0.8406 - val_auc: 0.8251
# epoch: 0016, loss: 0.8949 - val_loss: 0.8918; auc: 0.8430 - val_auc: 0.8268
# epoch: 0017, loss: 0.8849 - val_loss: 0.8860; auc: 0.8519 - val_auc: 0.8301
# epoch: 0018, loss: 0.8761 - val_loss: 0.8788; auc: 0.8544 - val_auc: 0.8334
# epoch: 0106, loss: 0.4048 - val_loss: 1.0859; auc: 0.9741 - val_auc: 0.8590
# epoch: 0107, loss: 0.4067 - val_loss: 1.0388; auc: 0.9738 - val_auc: 0.8567
# epoch: 0108, loss: 0.4059 - val_loss: 1.0917; auc: 0.9757 - val_auc: 0.8553
# epoch: 0109, loss: 0.4013 - val_loss: 1.0853; auc: 0.9753 - val_auc: 0.8577
# epoch: 0110, loss: 0.4022 - val_loss: 1.1672; auc: 0.9754 - val_auc: 0.8570
# epoch: 0111, loss: 0.3907 - val_loss: 1.1926; auc: 0.9767 - val_auc: 0.8549
# epoch: 0112, loss: 0.3989 - val_loss: 0.9723; auc: 0.9750 - val_auc: 0.8599
# epoch: 0113, loss: 0.3949 - val_loss: 1.2034; auc: 0.9770 - val_auc: 0.8567
# epoch: 0114, loss: 0.3857 - val_loss: 1.1817; auc: 0.9766 - val_auc: 0.8572
# epoch: 0115, loss: 0.3831 - val_loss: 1.1197; auc: 0.9780 - val_auc: 0.8580
# epoch: 0116, loss: 0.3823 - val_loss: 1.3232; auc: 0.9781 - val_auc: 0.8548
# epoch: 0117, loss: 0.3824 - val_loss: 1.1636; auc: 0.9783 - val_auc: 0.8571
# epoch: 0118, loss: 0.3768 - val_loss: 1.2631; auc: 0.9784 - val_auc: 0.8572
# epoch: 0119, loss: 0.3794 - val_loss: 1.0872; auc: 0.9786 - val_auc: 0.8598
# epoch: 0120, loss: 0.3769 - val_loss: 1.3127; auc: 0.9796 - val_auc: 0.8527
# epoch: 0121, loss: 0.3688 - val_loss: 1.1823; auc: 0.9798 - val_auc: 0.8560
# epoch: 0122, loss: 0.3660 - val_loss: 1.1687; auc: 0.9791 - val_auc: 0.8571
# epoch: 0123, loss: 0.3703 - val_loss: 1.1534; auc: 0.9802 - val_auc: 0.8566
# epoch: 0124, loss: 0.3666 - val_loss: 1.2550; auc: 0.9803 - val_auc: 0.8544
# epoch: 0125, loss: 0.3630 - val_loss: 1.2284; auc: 0.9805 - val_auc: 0.8533
# epoch: 0126, loss: 0.3609 - val_loss: 1.2460; auc: 0.9812 - val_auc: 0.8535
# epoch: 0127, loss: 0.3584 - val_loss: 1.1257; auc: 0.9807 - val_auc: 0.8578
# epoch: 0128, loss: 0.3606 - val_loss: 1.2529; auc: 0.9817 - val_auc: 0.8550
# epoch: 0129, loss: 0.3573 - val_loss: 1.3130; auc: 0.9820 - val_auc: 0.8525
#
# Restoring model weights from the end of the best epoch.
#
# Epoch 00129: early stopping
# 6264 783 784
# Train on 6264 samples, validate on 783 samples
# Epoch 1/79
# 6264/6264 [==============================] - 4s 599us/sample - loss: 1.1655 - val_loss: 1.1625
# Epoch 2/79
# 6264/6264 [==============================] - 2s 321us/sample - loss: 1.1164 - val_loss: 1.1031
# Epoch 3/79
# 6264/6264 [==============================] - 2s 317us/sample - loss: 1.0728 - val_loss: 1.0671
# Epoch 4/79
# 6264/6264 [==============================] - 2s 314us/sample - loss: 1.0473 - val_loss: 1.0285
# Epoch 5/79
# 6264/6264 [==============================] - 2s 317us/sample - loss: 1.0226 - val_loss: 1.0130
# Epoch 6/79
# 6264/6264 [==============================] - 2s 316us/sample - loss: 1.0056 - val_loss: 1.0138
# Epoch 7/79
# 6264/6264 [==============================] - 2s 321us/sample - loss: 0.9911 - val_loss: 0.9896
# Epoch 8/79
# 6264/6264 [==============================] - 2s 323us/sample - loss: 0.9789 - val_loss: 0.9800
# Epoch 9/79
# 6264/6264 [==============================] - 2s 322us/sample - loss: 0.9624 - val_loss: 0.9771
# Epoch 10/79
# 6264/6264 [==============================] - 2s 317us/sample - loss: 0.9503 - val_loss: 0.9640
# Epoch 11/79
# 6264/6264 [==============================] - 2s 320us/sample - loss: 0.9344 - val_loss: 0.9949
# Epoch 12/79
# 6264/6264 [==============================] - 2s 322us/sample - loss: 0.9263 - val_loss: 0.9538
# Epoch 13/79
# 6264/6264 [==============================] - 2s 318us/sample - loss: 0.9102 - val_loss: 0.9535
# Epoch 14/79
# 6264/6264 [==============================] - 2s 316us/sample - loss: 0.8994 - val_loss: 0.9403
# Epoch 15/79
# 6264/6264 [==============================] - 2s 313us/sample - loss: 0.8852 - val_loss: 0.9336
# Epoch 16/79
# 6264/6264 [==============================] - 2s 316us/sample - loss: 0.8769 - val_loss: 0.9496
# Epoch 17/79
# 6264/6264 [==============================] - 2s 318us/sample - loss: 0.8651 - val_loss: 0.9343
# Epoch 18/79
# 6264/6264 [==============================] - 2s 317us/sample - loss: 0.8564 - val_loss: 0.9168
# Epoch 19/79
# 6264/6264 [==============================] - 2s 314us/sample - loss: 0.8452 - val_loss: 0.9055
# Epoch 20/79
# 6264/6264 [==============================] - 2s 318us/sample - loss: 0.8340 - val_loss: 0.9072
# Epoch 21/79
# 6264/6264 [==============================] - 2s 315us/sample - loss: 0.8299 - val_loss: 0.9185
# Epoch 22/79
# 6264/6264 [==============================] - 2s 321us/sample - loss: 0.8189 - val_loss: 0.8936
# Epoch 23/79
# 6264/6264 [==============================] - 2s 328us/sample - loss: 0.8050 - val_loss: 0.9033
# Epoch 24/79
# 6264/6264 [==============================] - 2s 320us/sample - loss: 0.7939 - val_loss: 0.9600
# Epoch 25/79
# 6264/6264 [==============================] - 2s 314us/sample - loss: 0.7908 - val_loss: 0.9120
# Epoch 26/79
# 6264/6264 [==============================] - 2s 313us/sample - loss: 0.7814 - val_loss: 0.9196
# Epoch 27/79
# 6264/6264 [==============================] - 2s 311us/sample - loss: 0.7719 - val_loss: 0.9232
# Epoch 28/79
# 6264/6264 [==============================] - 2s 315us/sample - loss: 0.7740 - val_loss: 0.8943
# Epoch 29/79
# 6264/6264 [==============================] - 2s 310us/sample - loss: 0.7750 - val_loss: 0.9040
# Epoch 30/79
# 6264/6264 [==============================] - 2s 316us/sample - loss: 0.7659 - val_loss: 0.8900
# Epoch 31/79
# 6264/6264 [==============================] - 2s 317us/sample - loss: 0.7471 - val_loss: 0.9162
# Epoch 32/79
# 6264/6264 [==============================] - 2s 320us/sample - loss: 0.7361 - val_loss: 0.8964
# Epoch 33/79
# 6264/6264 [==============================] - 2s 326us/sample - loss: 0.7282 - val_loss: 0.8846
# Epoch 34/79
# 6264/6264 [==============================] - 2s 313us/sample - loss: 0.7229 - val_loss: 0.8703
# Epoch 35/79
# 6264/6264 [==============================] - 2s 324us/sample - loss: 0.7134 - val_loss: 0.9043
# Epoch 36/79
# 6264/6264 [==============================] - 2s 308us/sample - loss: 0.7115 - val_loss: 0.9135
# Epoch 37/79
# 6264/6264 [==============================] - 2s 315us/sample - loss: 0.7051 - val_loss: 0.8719
# Epoch 38/79
# 6264/6264 [==============================] - 2s 308us/sample - loss: 0.7091 - val_loss: 0.8703
# Epoch 39/79
# 6264/6264 [==============================] - 2s 316us/sample - loss: 0.6912 - val_loss: 0.8849
# Epoch 40/79
# 6264/6264 [==============================] - 2s 313us/sample - loss: 0.6799 - val_loss: 0.8794
# Epoch 41/79
# 6264/6264 [==============================] - 2s 319us/sample - loss: 0.6725 - val_loss: 0.8880
# Epoch 42/79
# 6264/6264 [==============================] - 2s 318us/sample - loss: 0.6703 - val_loss: 0.9106
# Epoch 43/79
# 6264/6264 [==============================] - 2s 321us/sample - loss: 0.6594 - val_loss: 0.8776
# Epoch 44/79
# 6264/6264 [==============================] - 2s 313us/sample - loss: 0.6532 - val_loss: 0.8771
# Epoch 45/79
# 6264/6264 [==============================] - 2s 313us/sample - loss: 0.6514 - val_loss: 0.8936
# Epoch 46/79
# 6264/6264 [==============================] - 2s 316us/sample - loss: 0.6536 - val_loss: 0.9037
# Epoch 47/79
# 6264/6264 [==============================] - 2s 265us/sample - loss: 0.6408 - val_loss: 0.8983
# Epoch 48/79
# 6264/6264 [==============================] - 2s 253us/sample - loss: 0.6314 - val_loss: 0.8877
# Epoch 49/79
# 6264/6264 [==============================] - 2s 255us/sample - loss: 0.6254 - val_loss: 1.0064
# Epoch 50/79
# 6264/6264 [==============================] - 2s 256us/sample - loss: 0.6225 - val_loss: 0.9459
# Epoch 51/79
# 6264/6264 [==============================] - 2s 256us/sample - loss: 0.6134 - val_loss: 0.8782
# Epoch 52/79
# 6264/6264 [==============================] - 2s 256us/sample - loss: 0.6025 - val_loss: 0.8997
# Epoch 53/79
# 6264/6264 [==============================] - 2s 255us/sample - loss: 0.5995 - val_loss: 0.9078
# Epoch 54/79
# 6264/6264 [==============================] - 2s 257us/sample - loss: 0.5952 - val_loss: 0.8777
# Epoch 55/79
# 6264/6264 [==============================] - 2s 256us/sample - loss: 0.5941 - val_loss: 0.8927
# Epoch 56/79
# 6264/6264 [==============================] - 2s 257us/sample - loss: 0.5845 - val_loss: 1.0229
# Epoch 57/79
# 6264/6264 [==============================] - 2s 257us/sample - loss: 0.5854 - val_loss: 0.9567
# Epoch 58/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.5792 - val_loss: 0.9217
# Epoch 59/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.5692 - val_loss: 0.9097
# Epoch 60/79
# 6264/6264 [==============================] - 2s 257us/sample - loss: 0.5606 - val_loss: 0.9613
# Epoch 61/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.5587 - val_loss: 0.9118
# Epoch 62/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.5662 - val_loss: 0.8913
# Epoch 63/79
# 6264/6264 [==============================] - 2s 256us/sample - loss: 0.5559 - val_loss: 1.0261
# Epoch 64/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.5499 - val_loss: 0.9362
# Epoch 65/79
# 6264/6264 [==============================] - 2s 257us/sample - loss: 0.5383 - val_loss: 0.9522
# Epoch 66/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.5364 - val_loss: 0.9250
# Epoch 67/79
# 6264/6264 [==============================] - 2s 257us/sample - loss: 0.5341 - val_loss: 1.0972
# Epoch 68/79
# 6264/6264 [==============================] - 2s 256us/sample - loss: 0.5298 - val_loss: 1.0053
# Epoch 69/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.5270 - val_loss: 0.9024
# Epoch 70/79
# 6264/6264 [==============================] - 2s 257us/sample - loss: 0.5297 - val_loss: 1.1320
# Epoch 71/79
# 6264/6264 [==============================] - 2s 259us/sample - loss: 0.5187 - val_loss: 0.9642
# Epoch 72/79
# 6264/6264 [==============================] - 2s 255us/sample - loss: 0.5098 - val_loss: 1.1303
# Epoch 73/79
# 6264/6264 [==============================] - 2s 256us/sample - loss: 0.5083 - val_loss: 0.9835
# Epoch 74/79
# 6264/6264 [==============================] - 2s 257us/sample - loss: 0.5035 - val_loss: 0.9664
# Epoch 75/79
# 6264/6264 [==============================] - 2s 256us/sample - loss: 0.4982 - val_loss: 0.9833
# Epoch 76/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.4888 - val_loss: 0.9470
# Epoch 77/79
# 6264/6264 [==============================] - 2s 260us/sample - loss: 0.4934 - val_loss: 1.0172
# Epoch 78/79
# 6264/6264 [==============================] - 2s 259us/sample - loss: 0.4855 - val_loss: 0.9945
# Epoch 79/79
# 6264/6264 [==============================] - 2s 258us/sample - loss: 0.4825 - val_loss: 1.0645
# 6264 783 784
# Train on 6264 samples, validate on 783 samples
# Epoch 1/79
# 6264/6264 [==============================] - 3s 528us/sample - loss: 1.1708 - val_loss: 1.2117
# Epoch 2/79
# 6264/6264 [==============================] - 2s 289us/sample - loss: 1.1225 - val_loss: 1.1539
# Epoch 3/79
# 6264/6264 [==============================] - 2s 290us/sample - loss: 1.0701 - val_loss: 1.1055
# Epoch 4/79
# 6264/6264 [==============================] - 2s 296us/sample - loss: 1.0424 - val_loss: 1.0760
# Epoch 5/79
# 6264/6264 [==============================] - 2s 285us/sample - loss: 1.0218 - val_loss: 1.0566
# Epoch 6/79
# 6264/6264 [==============================] - 2s 287us/sample - loss: 1.0068 - val_loss: 1.0491
# Epoch 7/79
# 6264/6264 [==============================] - 2s 291us/sample - loss: 0.9918 - val_loss: 1.0265
# Epoch 8/79
# 6264/6264 [==============================] - 2s 289us/sample - loss: 0.9859 - val_loss: 1.0070
# Epoch 9/79
# 6264/6264 [==============================] - 2s 292us/sample - loss: 0.9676 - val_loss: 1.0076
# Epoch 10/79
# 6264/6264 [==============================] - 2s 283us/sample - loss: 0.9590 - val_loss: 1.0048
# Epoch 11/79
# 6264/6264 [==============================] - 2s 283us/sample - loss: 0.9428 - val_loss: 0.9919
# Epoch 12/79
# 6264/6264 [==============================] - 2s 280us/sample - loss: 0.9344 - val_loss: 0.9732
# Epoch 13/79
# 6264/6264 [==============================] - 2s 283us/sample - loss: 0.9242 - val_loss: 0.9638
# Epoch 14/79
# 6264/6264 [==============================] - 2s 283us/sample - loss: 0.9135 - val_loss: 0.9502
# Epoch 15/79
# 6264/6264 [==============================] - 2s 287us/sample - loss: 0.9049 - val_loss: 0.9605
# Epoch 16/79
# 6264/6264 [==============================] - 2s 284us/sample - loss: 0.8912 - val_loss: 0.9445
# Epoch 17/79
# 6264/6264 [==============================] - 2s 284us/sample - loss: 0.8846 - val_loss: 0.9432
# Epoch 18/79
# 6264/6264 [==============================] - 2s 290us/sample - loss: 0.8754 - val_loss: 0.9324
# Epoch 19/79
# 6264/6264 [==============================] - 2s 296us/sample - loss: 0.8623 - val_loss: 0.9190
# Epoch 20/79
# 6264/6264 [==============================] - 2s 287us/sample - loss: 0.8570 - val_loss: 0.9155
# Epoch 21/79
# 6264/6264 [==============================] - 2s 291us/sample - loss: 0.8490 - val_loss: 0.9177
# Epoch 22/79
# 6264/6264 [==============================] - 2s 316us/sample - loss: 0.8350 - val_loss: 0.8910
# Epoch 23/79
# 6264/6264 [==============================] - 2s 288us/sample - loss: 0.8257 - val_loss: 0.9042
# Epoch 24/79
# 6264/6264 [==============================] - 2s 296us/sample - loss: 0.8183 - val_loss: 0.8856
# Epoch 25/79
# 6264/6264 [==============================] - 2s 294us/sample - loss: 0.8132 - val_loss: 0.8874
# Epoch 26/79
# 6264/6264 [==============================] - 2s 291us/sample - loss: 0.8042 - val_loss: 0.8753
# Epoch 27/79
# 6264/6264 [==============================] - 2s 281us/sample - loss: 0.7991 - val_loss: 0.8866
# Epoch 28/79
# 6264/6264 [==============================] - 2s 281us/sample - loss: 0.7828 - val_loss: 0.8733
# Epoch 29/79
# 6264/6264 [==============================] - 2s 305us/sample - loss: 0.7820 - val_loss: 0.8649
# Epoch 30/79
# 6264/6264 [==============================] - 2s 363us/sample - loss: 0.7823 - val_loss: 0.9018
# Epoch 31/79
# 6264/6264 [==============================] - 2s 350us/sample - loss: 0.7726 - val_loss: 0.8822
# Epoch 32/79
# 6264/6264 [==============================] - 2s 373us/sample - loss: 0.7567 - val_loss: 0.8701
# Epoch 33/79
# 6264/6264 [==============================] - 2s 350us/sample - loss: 0.7515 - val_loss: 0.8660
# Epoch 34/79
# 6264/6264 [==============================] - 2s 382us/sample - loss: 0.7393 - val_loss: 0.8547
# Epoch 35/79
# 6264/6264 [==============================] - 2s 380us/sample - loss: 0.7376 - val_loss: 0.8560
# Epoch 36/79
# 6264/6264 [==============================] - 2s 382us/sample - loss: 0.7261 - val_loss: 0.8494
# Epoch 37/79
# 6264/6264 [==============================] - 2s 382us/sample - loss: 0.7287 - val_loss: 0.8510
# Epoch 38/79
# 6264/6264 [==============================] - 2s 375us/sample - loss: 0.7190 - val_loss: 0.8833
# Epoch 39/79
# 6264/6264 [==============================] - 2s 381us/sample - loss: 0.7061 - val_loss: 0.8754
# Epoch 40/79
# 6264/6264 [==============================] - 2s 383us/sample - loss: 0.7057 - val_loss: 0.8615
# Epoch 41/79
# 6264/6264 [==============================] - 2s 377us/sample - loss: 0.6939 - val_loss: 0.8596
# Epoch 42/79
# 6264/6264 [==============================] - 2s 276us/sample - loss: 0.6838 - val_loss: 0.9193
# Epoch 43/79
# 6264/6264 [==============================] - 2s 273us/sample - loss: 0.6796 - val_loss: 0.8502
# Epoch 44/79
# 6264/6264 [==============================] - 2s 277us/sample - loss: 0.6802 - val_loss: 0.8585
# Epoch 45/79
# 6264/6264 [==============================] - 2s 266us/sample - loss: 0.6656 - val_loss: 0.8498
# Epoch 46/79
# 6264/6264 [==============================] - 2s 273us/sample - loss: 0.6595 - val_loss: 0.8284
# Epoch 47/79
# 6264/6264 [==============================] - 2s 271us/sample - loss: 0.6622 - val_loss: 0.9024
# Epoch 48/79
# 6264/6264 [==============================] - 2s 274us/sample - loss: 0.6564 - val_loss: 0.8592
# Epoch 49/79
# 6264/6264 [==============================] - 2s 280us/sample - loss: 0.6392 - val_loss: 0.8555
# Epoch 50/79
# 6264/6264 [==============================] - 2s 273us/sample - loss: 0.6350 - val_loss: 0.8691
# Epoch 51/79
# 6264/6264 [==============================] - 2s 375us/sample - loss: 0.6291 - val_loss: 0.8888
# Epoch 52/79
# 6264/6264 [==============================] - 2s 315us/sample - loss: 0.6221 - val_loss: 0.8543
# Epoch 53/79
# 6264/6264 [==============================] - 2s 305us/sample - loss: 0.6241 - val_loss: 0.9108
# Epoch 54/79
# 6264/6264 [==============================] - 2s 334us/sample - loss: 0.6200 - val_loss: 0.9214
# Epoch 55/79
# 6264/6264 [==============================] - 2s 301us/sample - loss: 0.6045 - val_loss: 0.8719
# Epoch 56/79
# 6264/6264 [==============================] - 2s 281us/sample - loss: 0.6160 - val_loss: 0.9879
# Epoch 57/79
# 6264/6264 [==============================] - 2s 285us/sample - loss: 0.6067 - val_loss: 0.8443
# Epoch 58/79
# 6264/6264 [==============================] - 2s 292us/sample - loss: 0.5948 - val_loss: 0.9019
# Epoch 59/79
# 6264/6264 [==============================] - 2s 301us/sample - loss: 0.5850 - val_loss: 0.9047
# Epoch 60/79
# 6264/6264 [==============================] - 2s 282us/sample - loss: 0.5812 - val_loss: 0.9195
# Epoch 61/79
# 6264/6264 [==============================] - 2s 284us/sample - loss: 0.5742 - val_loss: 0.8945
# Epoch 62/79
# 6264/6264 [==============================] - 2s 287us/sample - loss: 0.5781 - val_loss: 0.8538
# Epoch 63/79
# 6264/6264 [==============================] - 2s 294us/sample - loss: 0.5631 - val_loss: 0.8729
# Epoch 64/79
# 6264/6264 [==============================] - 2s 264us/sample - loss: 0.5592 - val_loss: 0.8641
# Epoch 65/79
# 6264/6264 [==============================] - 2s 269us/sample - loss: 0.5539 - val_loss: 0.8861
# Epoch 66/79
# 6264/6264 [==============================] - 2s 260us/sample - loss: 0.5470 - val_loss: 0.9414
# Epoch 67/79
# 6264/6264 [==============================] - 2s 263us/sample - loss: 0.5465 - val_loss: 0.9271
# Epoch 68/79
# 6264/6264 [==============================] - 2s 263us/sample - loss: 0.5414 - val_loss: 0.8834
# Epoch 69/79
# 6264/6264 [==============================] - 2s 267us/sample - loss: 0.5450 - val_loss: 1.0690
# Epoch 70/79
# 6264/6264 [==============================] - 2s 267us/sample - loss: 0.5358 - val_loss: 0.9346
# Epoch 71/79
# 6264/6264 [==============================] - 2s 277us/sample - loss: 0.5228 - val_loss: 0.9815
# Epoch 72/79
# 6264/6264 [==============================] - 2s 296us/sample - loss: 0.5193 - val_loss: 0.9355
# Epoch 73/79
# 6264/6264 [==============================] - 2s 289us/sample - loss: 0.5188 - val_loss: 0.9158
# Epoch 74/79
# 6264/6264 [==============================] - 2s 276us/sample - loss: 0.5109 - val_loss: 0.9120
# Epoch 75/79
# 6264/6264 [==============================] - 2s 277us/sample - loss: 0.5069 - val_loss: 1.0277
# Epoch 76/79
# 6264/6264 [==============================] - 2s 276us/sample - loss: 0.5096 - val_loss: 1.0449
# Epoch 77/79
# 6264/6264 [==============================] - 2s 270us/sample - loss: 0.5139 - val_loss: 0.9892
# Epoch 78/79
# 6264/6264 [==============================] - 2s 277us/sample - loss: 0.4964 - val_loss: 0.9816
# Epoch 79/79
# 6264/6264 [==============================] - 2s 278us/sample - loss: 0.4929 - val_loss: 1.0733

# %%
pd.DataFrame(performance.history)[['loss', 'val_loss']].plot()

# %%
pd.DataFrame(performance.history)[['auc', 'val_auc']].plot()

# %%
pd.DataFrame(results).test_auc.mean()
# Out:
# 0.8445677180763521

# %%
pd.DataFrame(results).test_auc.std()
# Out:
# 0.0017329185855766481

# %%
pd.DataFrame(results)
# Out:
#   task_name  train_auc  valid_auc  test_auc metric  # trainable params  \
# 0     Tox21   0.959456   0.861274  0.845351    ROC              769708
# 1     Tox21   0.963828   0.844024  0.842581    ROC              769708
# 2     Tox21   0.960515   0.875618  0.845771    ROC              769708
#
#    best_epoch  batch_size      lr  weight_decay
# 0          78         128  0.0001             0
# 1          78         128  0.0001             0
# 2          78         128  0.0001             0

# %%
pd.DataFrame(results).to_csv('./results/%s.csv' % task_name)
