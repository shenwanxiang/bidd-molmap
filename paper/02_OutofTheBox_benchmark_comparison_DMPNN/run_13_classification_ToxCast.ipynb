# %%
from molmap import model as molmodel
import molmap

import matplotlib.pyplot as plt

import pandas as pd
from tqdm import tqdm
from joblib import load, dump
tqdm.pandas(ascii=True)
import numpy as np

import tensorflow as tf
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
np.random.seed(1)
tf.compat.v1.set_random_seed(1)


tmp_feature_dir = './tmpignore'
if not os.path.exists(tmp_feature_dir):
    os.makedirs(tmp_feature_dir)

# %%
mp1 = molmap.loadmap('../descriptor.mp')
mp2 = molmap.loadmap('../fingerprint.mp')

# %%
task_name = 'ToxCast'
from chembench import load_data
df, induces = load_data(task_name)

MASK = -1
smiles_col = df.columns[0]
values_col = df.columns[1:]
Y = df[values_col].astype('float').fillna(MASK).values
if Y.shape[1] == 0:
    Y = Y.reshape(-1, 1)
# Out:
# loading dataset: ToxCast number of split times: 3

# %%
X1_name = os.path.join(tmp_feature_dir, 'X1_%s.data' % task_name)
X2_name = os.path.join(tmp_feature_dir, 'X2_%s.data' % task_name)
if not os.path.exists(X1_name):
    X1 = mp1.batch_transform(df.smiles, n_jobs = 8)
    dump(X1, X1_name)
else:
    X1 = load(X1_name)

if not os.path.exists(X2_name): 
    X2 = mp2.batch_transform(df.smiles, n_jobs = 8)
    dump(X2, X2_name)
else:
    X2 = load(X2_name)

molmap1_size = X1.shape[1:]
molmap2_size = X2.shape[1:]

# %%
X1 = X1.astype('float32')

# %%
def get_pos_weights(trainY):
    """pos_weights: neg_n / pos_n """
    dfY = pd.DataFrame(trainY)
    pos = dfY == 1
    pos_n = pos.sum(axis=0)
    neg = dfY == 0
    neg_n = neg.sum(axis=0)
    pos_weights = (neg_n / pos_n).values
    neg_weights = (pos_n / neg_n).values
    return pos_weights, neg_weights


prcs_metrics = ['MUV', 'PCBA']

# %%
epochs = 800
patience = 50 #early stopping

dense_layers = [1024] # 617 outputs

batch_size = 128
lr = 1e-4
weight_decay = 0

monitor = 'val_loss'
dense_avf = 'relu'
last_avf = None #sigmoid in loss

if task_name in prcs_metrics:
    metric = 'PRC'
else:
    metric = 'ROC'

# %%
results = []
for i, split_idxs in enumerate(induces):

    train_idx, valid_idx, test_idx = split_idxs
    print(len(train_idx), len(valid_idx), len(test_idx))

    trainX = (X1[train_idx], X2[train_idx])
    trainY = Y[train_idx]

    validX = (X1[valid_idx], X2[valid_idx])
    validY = Y[valid_idx]

    testX = (X1[test_idx], X2[test_idx])
    testY = Y[test_idx]            

    pos_weights, neg_weights = get_pos_weights(trainY)
    loss = lambda y_true, y_pred: molmodel.loss.weighted_cross_entropy(y_true,y_pred, pos_weights, MASK = -1)

    model = molmodel.net.DoublePathNet(molmap1_size, molmap2_size, 
                                       n_outputs=Y.shape[-1], 
                                       dense_layers=dense_layers, 
                                       dense_avf = dense_avf, 
                                       last_avf=last_avf)

    opt = tf.keras.optimizers.Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0) #
    #import tensorflow_addons as tfa
    #opt = tfa.optimizers.AdamW(weight_decay = 0.1,learning_rate=0.001,beta1=0.9,beta2=0.999, epsilon=1e-08)
    model.compile(optimizer = opt, loss = loss)
    
    if i == 0:
        performance = molmodel.cbks.CLA_EarlyStoppingAndPerformance((trainX, trainY), 
                                                                       (validX, validY), 
                                                                       patience = patience, 
                                                                       criteria = monitor,
                                                                       metric = metric,
                                                                      )
        model.fit(trainX, trainY, batch_size=batch_size, 
              epochs=epochs, verbose= 0, shuffle = True, 
              validation_data = (validX, validY), 
              callbacks=[performance]) 


    else:
        model.fit(trainX, trainY, batch_size=batch_size, 
              epochs = performance.best_epoch + 1, verbose = 1, shuffle = True, 
              validation_data = (validX, validY)) 
            
        performance.model.set_weights(model.get_weights())
    
    best_epoch = performance.best_epoch
    trainable_params = model.count_params()
    
    train_aucs = performance.evaluate(trainX, trainY)            
    valid_aucs = performance.evaluate(validX, validY)            
    test_aucs = performance.evaluate(testX, testY)


    final_res = {
                     'task_name':task_name,            
                     'train_auc':np.nanmean(train_aucs), 
                     'valid_auc':np.nanmean(valid_aucs),                      
                     'test_auc':np.nanmean(test_aucs), 
                     'metric':metric,
                     '# trainable params': trainable_params,
                     'best_epoch': best_epoch,
                     'batch_size':batch_size,
                     'lr': lr,
                     'weight_decay':weight_decay
                    }
    
    results.append(final_res)
# Out:
# 6860 858 858
# epoch: 0001, loss: 0.8606 - val_loss: 0.8600; auc: 0.5623 - val_auc: 0.5517
# epoch: 0002, loss: 0.8584 - val_loss: 0.8566; auc: 0.6003 - val_auc: 0.5855
# epoch: 0003, loss: 0.8519 - val_loss: 0.8483; auc: 0.6340 - val_auc: 0.6289
# epoch: 0004, loss: 0.8408 - val_loss: 0.8372; auc: 0.6591 - val_auc: 0.6620
# epoch: 0005, loss: 0.8315 - val_loss: 0.8259; auc: 0.6763 - val_auc: 0.6833
# epoch: 0006, loss: 0.8222 - val_loss: 0.8182; auc: 0.6917 - val_auc: 0.6988
# epoch: 0007, loss: 0.8156 - val_loss: 0.8147; auc: 0.7010 - val_auc: 0.7036
# epoch: 0008, loss: 0.8095 - val_loss: 0.8073; auc: 0.7114 - val_auc: 0.7145
# epoch: 0009, loss: 0.8034 - val_loss: 0.8022; auc: 0.7210 - val_auc: 0.7216
# epoch: 0010, loss: 0.8009 - val_loss: 0.8043; auc: 0.7276 - val_auc: 0.7261
# epoch: 0011, loss: 0.7962 - val_loss: 0.7973; auc: 0.7358 - val_auc: 0.7339
# epoch: 0012, loss: 0.7914 - val_loss: 0.7944; auc: 0.7429 - val_auc: 0.7383
# epoch: 0013, loss: 0.7889 - val_loss: 0.7959; auc: 0.7475 - val_auc: 0.7405
# epoch: 0014, loss: 0.7862 - val_loss: 0.7940; auc: 0.7539 - val_auc: 0.7434
# epoch: 0015, loss: 0.7850 - val_loss: 0.7867; auc: 0.7595 - val_auc: 0.7459
# epoch: 0016, loss: 0.7802 - val_loss: 0.7845; auc: 0.7650 - val_auc: 0.7490
# epoch: 0073, loss: 0.6915 - val_loss: 0.7968; auc: 0.8753 - val_auc: 0.7822
# epoch: 0074, loss: 0.6911 - val_loss: 0.7804; auc: 0.8758 - val_auc: 0.7823
# epoch: 0075, loss: 0.6909 - val_loss: 0.7931; auc: 0.8776 - val_auc: 0.7821
# epoch: 0076, loss: 0.6890 - val_loss: 0.7942; auc: 0.8784 - val_auc: 0.7819
# epoch: 0077, loss: 0.6878 - val_loss: 0.7964; auc: 0.8789 - val_auc: 0.7834
# epoch: 0078, loss: 0.6884 - val_loss: 0.7876; auc: 0.8795 - val_auc: 0.7823
# epoch: 0079, loss: 0.6869 - val_loss: 0.7920; auc: 0.8807 - val_auc: 0.7818
# epoch: 0080, loss: 0.6860 - val_loss: 0.7934; auc: 0.8811 - val_auc: 0.7832
# epoch: 0081, loss: 0.6855 - val_loss: 0.7978; auc: 0.8824 - val_auc: 0.7813
# epoch: 0082, loss: 0.6852 - val_loss: 0.8123; auc: 0.8828 - val_auc: 0.7816
# epoch: 0083, loss: 0.6842 - val_loss: 0.7887; auc: 0.8833 - val_auc: 0.7781
# epoch: 0084, loss: 0.6885 - val_loss: 0.8047; auc: 0.8841 - val_auc: 0.7800
# epoch: 0085, loss: 0.6831 - val_loss: 0.7994; auc: 0.8853 - val_auc: 0.7791
# epoch: 0086, loss: 0.6829 - val_loss: 0.8060; auc: 0.8853 - val_auc: 0.7803
# epoch: 0087, loss: 0.6816 - val_loss: 0.8059; auc: 0.8864 - val_auc: 0.7802
# epoch: 0088, loss: 0.6803 - val_loss: 0.8179; auc: 0.8870 - val_auc: 0.7816
# epoch: 0089, loss: 0.6802 - val_loss: 0.8097; auc: 0.8879 - val_auc: 0.7801
# epoch: 0090, loss: 0.6805 - val_loss: 0.8008; auc: 0.8888 - val_auc: 0.7792
#
# Restoring model weights from the end of the best epoch.
#
# Epoch 00090: early stopping
# 6860 858 858
# Train on 6860 samples, validate on 858 samples
# Epoch 1/40
# 6860/6860 [==============================] - 3s 484us/sample - loss: 0.8612 - val_loss: 0.8519
# Epoch 2/40
# 6860/6860 [==============================] - 2s 311us/sample - loss: 0.8593 - val_loss: 0.8488
# Epoch 3/40
# 6860/6860 [==============================] - 2s 297us/sample - loss: 0.8528 - val_loss: 0.8374
# Epoch 4/40
# 6860/6860 [==============================] - 2s 286us/sample - loss: 0.8420 - val_loss: 0.8258
# Epoch 5/40
# 6860/6860 [==============================] - 2s 308us/sample - loss: 0.8327 - val_loss: 0.8195
# Epoch 6/40
# 6860/6860 [==============================] - 2s 337us/sample - loss: 0.8237 - val_loss: 0.8108
# Epoch 7/40
# 6860/6860 [==============================] - 2s 340us/sample - loss: 0.8166 - val_loss: 0.8104
# Epoch 8/40
# 6860/6860 [==============================] - 2s 319us/sample - loss: 0.8094 - val_loss: 0.7991
# Epoch 9/40
# 6860/6860 [==============================] - 2s 306us/sample - loss: 0.8037 - val_loss: 0.7955
# Epoch 10/40
# 6860/6860 [==============================] - 2s 298us/sample - loss: 0.7986 - val_loss: 0.7923
# Epoch 11/40
# 6860/6860 [==============================] - 2s 271us/sample - loss: 0.7951 - val_loss: 0.7896
# Epoch 12/40
# 6860/6860 [==============================] - 2s 259us/sample - loss: 0.7893 - val_loss: 0.7876
# Epoch 13/40
# 6860/6860 [==============================] - 2s 250us/sample - loss: 0.7849 - val_loss: 0.7860
# Epoch 14/40
# 6860/6860 [==============================] - 2s 290us/sample - loss: 0.7829 - val_loss: 0.7897
# Epoch 15/40
# 6860/6860 [==============================] - 2s 311us/sample - loss: 0.7798 - val_loss: 0.7919
# Epoch 16/40
# 6860/6860 [==============================] - 2s 262us/sample - loss: 0.7768 - val_loss: 0.7833
# Epoch 17/40
# 6860/6860 [==============================] - 2s 270us/sample - loss: 0.7726 - val_loss: 0.7808
# Epoch 18/40
# 6860/6860 [==============================] - 2s 324us/sample - loss: 0.7742 - val_loss: 0.7814
# Epoch 19/40
# 6860/6860 [==============================] - 2s 324us/sample - loss: 0.7701 - val_loss: 0.7805
# Epoch 20/40
# 6860/6860 [==============================] - 2s 340us/sample - loss: 0.7661 - val_loss: 0.7809
# Epoch 21/40
# 6860/6860 [==============================] - 2s 324us/sample - loss: 0.7630 - val_loss: 0.7775
# Epoch 22/40
# 6860/6860 [==============================] - 2s 343us/sample - loss: 0.7603 - val_loss: 0.7811
# Epoch 23/40
# 6860/6860 [==============================] - 2s 289us/sample - loss: 0.7569 - val_loss: 0.7781
# Epoch 24/40
# 6860/6860 [==============================] - 2s 288us/sample - loss: 0.7557 - val_loss: 0.7753
# Epoch 25/40
# 6860/6860 [==============================] - 2s 275us/sample - loss: 0.7521 - val_loss: 0.7749
# Epoch 26/40
# 6860/6860 [==============================] - 2s 306us/sample - loss: 0.7502 - val_loss: 0.7769
# Epoch 27/40
# 6860/6860 [==============================] - 2s 265us/sample - loss: 0.7481 - val_loss: 0.7741
# Epoch 28/40
# 6860/6860 [==============================] - 2s 247us/sample - loss: 0.7478 - val_loss: 0.7760
# Epoch 29/40
# 6860/6860 [==============================] - 2s 252us/sample - loss: 0.7448 - val_loss: 0.7736
# Epoch 30/40
# 6860/6860 [==============================] - 2s 271us/sample - loss: 0.7417 - val_loss: 0.7783
# Epoch 31/40
# 6860/6860 [==============================] - 2s 254us/sample - loss: 0.7426 - val_loss: 0.7734
# Epoch 32/40
# 6860/6860 [==============================] - 2s 294us/sample - loss: 0.7398 - val_loss: 0.7791
# Epoch 33/40
# 6860/6860 [==============================] - 2s 250us/sample - loss: 0.7398 - val_loss: 0.7745
# Epoch 34/40
# 6860/6860 [==============================] - 2s 284us/sample - loss: 0.7379 - val_loss: 0.7762
# Epoch 35/40
# 6860/6860 [==============================] - 2s 256us/sample - loss: 0.7347 - val_loss: 0.7833
# Epoch 36/40
# 6860/6860 [==============================] - 2s 259us/sample - loss: 0.7321 - val_loss: 0.7717
# Epoch 37/40
# 6860/6860 [==============================] - 2s 267us/sample - loss: 0.7306 - val_loss: 0.7807
# Epoch 38/40
# 6860/6860 [==============================] - 2s 254us/sample - loss: 0.7300 - val_loss: 0.7745
# Epoch 39/40
# 6860/6860 [==============================] - 2s 257us/sample - loss: 0.7271 - val_loss: 0.7932
# Epoch 40/40
# 6860/6860 [==============================] - 2s 260us/sample - loss: 0.7268 - val_loss: 0.7728
# 6860 858 858
# Train on 6860 samples, validate on 858 samples
# Epoch 1/40
# 6860/6860 [==============================] - 4s 575us/sample - loss: 0.8620 - val_loss: 0.8509
# Epoch 2/40
# 6860/6860 [==============================] - 2s 309us/sample - loss: 0.8602 - val_loss: 0.8481
# Epoch 3/40
# 6860/6860 [==============================] - 2s 318us/sample - loss: 0.8539 - val_loss: 0.8383
# Epoch 4/40
# 6860/6860 [==============================] - 2s 298us/sample - loss: 0.8418 - val_loss: 0.8303
# Epoch 5/40
# 6860/6860 [==============================] - 2s 292us/sample - loss: 0.8306 - val_loss: 0.8383
# Epoch 6/40
# 6860/6860 [==============================] - 2s 294us/sample - loss: 0.8228 - val_loss: 0.8200
# Epoch 7/40
# 6860/6860 [==============================] - 2s 306us/sample - loss: 0.8144 - val_loss: 0.8183
# Epoch 8/40
# 6860/6860 [==============================] - 2s 299us/sample - loss: 0.8085 - val_loss: 0.8132
# Epoch 9/40
# 6860/6860 [==============================] - 2s 290us/sample - loss: 0.8030 - val_loss: 0.8090
# Epoch 10/40
# 6860/6860 [==============================] - 2s 297us/sample - loss: 0.8004 - val_loss: 0.8066
# Epoch 11/40
# 6860/6860 [==============================] - 2s 322us/sample - loss: 0.7938 - val_loss: 0.8061
# Epoch 12/40
# 6860/6860 [==============================] - 2s 291us/sample - loss: 0.7902 - val_loss: 0.8052
# Epoch 13/40
# 6860/6860 [==============================] - 2s 290us/sample - loss: 0.7862 - val_loss: 0.8001
# Epoch 14/40
# 6860/6860 [==============================] - 2s 269us/sample - loss: 0.7840 - val_loss: 0.8025
# Epoch 15/40
# 6860/6860 [==============================] - 2s 286us/sample - loss: 0.7804 - val_loss: 0.7990
# Epoch 16/40
# 6860/6860 [==============================] - 2s 288us/sample - loss: 0.7760 - val_loss: 0.7956
# Epoch 17/40
# 6860/6860 [==============================] - 2s 291us/sample - loss: 0.7741 - val_loss: 0.7972
# Epoch 18/40
# 6860/6860 [==============================] - 2s 287us/sample - loss: 0.7699 - val_loss: 0.7924
# Epoch 19/40
# 6860/6860 [==============================] - 2s 301us/sample - loss: 0.7670 - val_loss: 0.7911
# Epoch 20/40
# 6860/6860 [==============================] - 2s 279us/sample - loss: 0.7647 - val_loss: 0.7933
# Epoch 21/40
# 6860/6860 [==============================] - 2s 287us/sample - loss: 0.7609 - val_loss: 0.7899
# Epoch 22/40
# 6860/6860 [==============================] - 2s 354us/sample - loss: 0.7585 - val_loss: 0.7882
# Epoch 23/40
# 6860/6860 [==============================] - 2s 329us/sample - loss: 0.7562 - val_loss: 0.7885
# Epoch 24/40
# 6860/6860 [==============================] - 2s 301us/sample - loss: 0.7539 - val_loss: 0.7910
# Epoch 25/40
# 6860/6860 [==============================] - 2s 293us/sample - loss: 0.7538 - val_loss: 0.7859
# Epoch 26/40
# 6860/6860 [==============================] - 2s 316us/sample - loss: 0.7498 - val_loss: 0.7836
# Epoch 27/40
# 6860/6860 [==============================] - 2s 314us/sample - loss: 0.7468 - val_loss: 0.7843
# Epoch 28/40
# 6860/6860 [==============================] - 2s 310us/sample - loss: 0.7441 - val_loss: 0.7868
# Epoch 29/40
# 6860/6860 [==============================] - 2s 296us/sample - loss: 0.7436 - val_loss: 0.7867
# Epoch 30/40
# 6860/6860 [==============================] - 2s 330us/sample - loss: 0.7416 - val_loss: 0.7852
# Epoch 31/40
# 6860/6860 [==============================] - 2s 314us/sample - loss: 0.7391 - val_loss: 0.7822
# Epoch 32/40
# 6860/6860 [==============================] - 2s 285us/sample - loss: 0.7375 - val_loss: 0.7827
# Epoch 33/40
# 6860/6860 [==============================] - 2s 294us/sample - loss: 0.7364 - val_loss: 0.7985
# Epoch 34/40
# 6860/6860 [==============================] - 2s 269us/sample - loss: 0.7336 - val_loss: 0.7827
# Epoch 35/40
# 6860/6860 [==============================] - 2s 244us/sample - loss: 0.7336 - val_loss: 0.7853
# Epoch 36/40
# 6860/6860 [==============================] - 2s 336us/sample - loss: 0.7304 - val_loss: 0.7836
# Epoch 37/40
# 6860/6860 [==============================] - 2s 287us/sample - loss: 0.7283 - val_loss: 0.7962
# Epoch 38/40
# 6860/6860 [==============================] - 2s 267us/sample - loss: 0.7273 - val_loss: 0.8159
# Epoch 39/40
# 6860/6860 [==============================] - 2s 240us/sample - loss: 0.7262 - val_loss: 0.7858
# Epoch 40/40
# 6860/6860 [==============================] - 2s 240us/sample - loss: 0.7242 - val_loss: 0.7875

# %%
pd.DataFrame(performance.history)[['loss', 'val_loss']].plot()

# %%
pd.DataFrame(performance.history)[['auc', 'val_auc']].plot()

# %%
pd.DataFrame(results).test_auc.mean()
# Out:
# 0.7463785030338611

# %%
pd.DataFrame(results).test_auc.std()
# Out:
# 0.0020975049917676307

# %%
pd.DataFrame(results)
# Out:
#   task_name  train_auc  valid_auc  test_auc metric  # trainable params  \
# 0   ToxCast   0.837592   0.780423  0.746813    ROC             1694729
# 1   ToxCast   0.838543   0.750626  0.748224    ROC             1694729
# 2   ToxCast   0.839554   0.722809  0.744098    ROC             1694729
#
#    best_epoch  batch_size      lr  weight_decay
# 0          39         128  0.0001             0
# 1          39         128  0.0001             0
# 2          39         128  0.0001             0

# %%
pd.DataFrame(results).to_csv('./results/%s.csv' % task_name)
