# %%
import pandas as pd

# %%
df = pd.read_csv('./result.csv', index_col = 0)

def _apply_statics(g):
    
    res = {'trainable_paras': int(g.trainable_paras.mean()), 
            'best_epoch': g.best_epoch.tolist(),
            'lr': g.lr.mean(),
            'batch_size': int(g.batch_size.mean()),
            'random_seed': g.random_seed.tolist(),
            'train_samples': int(g.train_samples.mean()),
            'valid_samples': int(g.valid_samples.mean()),
            'test_samples': int(g.test_samples.mean()),
            'train_rmse': '%.3f ± %.3f' % (g.train_rmse.mean(), g.train_rmse.std()),     
            'valid_rmse': '%.3f ± %.3f' % (g.valid_rmse.mean(), g.valid_rmse.std()),     
            'test_rmse':  '%.3f ± %.3f' % (g.test_rmse.mean(), g.test_rmse.std()),            
             }

    return pd.Series(res)

# %%
df1 = df.groupby(['dataset', 'model']).apply(_apply_statics)

# %%
df1.to_csv('./result.anlysis.csv')

# %%
df1
# Out:
#                                     trainable_paras       best_epoch      lr  \
# dataset     model
# attentiveFP DoublePath_both                  803681  [303, 255, 297]  0.0001
#             SinglePath_descriptor            407617  [446, 346, 439]  0.0001
#             SinglePath_fingerprint           326497  [168, 317, 296]  0.0001
# deepchem    DoublePath_both                  803681  [420, 494, 340]  0.0001
#             SinglePath_descriptor            407617  [375, 371, 340]  0.0001
#             SinglePath_fingerprint           326497  [264, 238, 183]  0.0001
#
#                                     batch_size   random_seed  train_samples  \
# dataset     model
# attentiveFP DoublePath_both                128  [7, 77, 777]            901
#             SinglePath_descriptor          128  [7, 77, 777]            901
#             SinglePath_fingerprint         128  [7, 77, 777]            901
# deepchem    DoublePath_both                128  [7, 77, 777]            902
#             SinglePath_descriptor          128  [7, 77, 777]            902
#             SinglePath_fingerprint         128  [7, 77, 777]            902
#
#                                     valid_samples  test_samples  \
# dataset     model
# attentiveFP DoublePath_both                   113           113
#             SinglePath_descriptor             113           113
#             SinglePath_fingerprint            113           113
# deepchem    DoublePath_both                   113           113
#             SinglePath_descriptor             113           113
#             SinglePath_fingerprint            113           113
#
#                                        train_rmse     valid_rmse  \
# dataset     model
# attentiveFP DoublePath_both         0.180 ± 0.016  0.555 ± 0.021
#             SinglePath_descriptor   0.326 ± 0.026  0.541 ± 0.010
#             SinglePath_fingerprint  0.191 ± 0.073  0.633 ± 0.015
# deepchem    DoublePath_both         0.166 ± 0.085  0.635 ± 0.019
#             SinglePath_descriptor   0.340 ± 0.013  0.575 ± 0.009
#             SinglePath_fingerprint  0.220 ± 0.015  0.741 ± 0.007
#
#                                         test_rmse
# dataset     model
# attentiveFP DoublePath_both         0.558 ± 0.031
#             SinglePath_descriptor   0.464 ± 0.004
#             SinglePath_fingerprint  0.728 ± 0.044
# deepchem    DoublePath_both         0.635 ± 0.032
#             SinglePath_descriptor   0.537 ± 0.011
#             SinglePath_fingerprint  0.744 ± 0.022
