# %%
from __future__ import print_function
from __future__ import division
from __future__ import unicode_literals

import numpy as np
import tensorflow as tf
from joblib import load,dump
from rdkit import Chem
import pandas as pd

from deepchem.models import GraphConvModel, MPNNModel
import deepchem as dc
from deepchem.molnet.preset_hyper_parameters import hps
from copy import deepcopy
import os
os.environ["CUDA_VISIBLE_DEVICES"]="5"
# %matplotlib inline
#os.environ.setdefault('DEEPCHEM_DATA_DIR', os.popen('pwd').read().strip())

# %%
dc.__version__
# Out:
# '2.1.1'

# %%
seed = 777
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
def featurize_data(tasks, smiles_col, featurizer, dataset_file, normalize = True):
    loader = dc.data.CSVLoader(tasks=tasks, smiles_field=smiles_col, featurizer=featurizer)
    dataset = loader.featurize(dataset_file, shard_size=8192)
    move_mean = True
    if normalize:
        transformers = [dc.trans.NormalizationTransformer(
            transform_y=True, dataset=dataset, move_mean=move_mean)]
    else:
        transformers = []
    for transformer in transformers:
        dataset = transformer.transform(dataset)
    return dataset, transformers

# %%
featurizer = dc.feat.graph_features.WeaveFeaturizer()
metric = dc.metrics.Metric(dc.metrics.rms_score, np.mean)

# %% [markdown]
# # use the same dataset as MolMapNet and attentivFP

# %%
tasks = ['measured log solubility in mols per litre']
smiles_col = 'smiles'

# tasks, delaney_datasets, transformers = dc.molnet.load_delaney(featurizer='Weave', split='random')
# train_dataset, valid_dataset, test_dataset = delaney_datasets
train_dataset, transformers =  featurize_data(tasks = tasks, smiles_col = smiles_col, 
                                           featurizer =featurizer, dataset_file='../train.csv')

valid_dataset, _ =  featurize_data(tasks = tasks, smiles_col = smiles_col, 
                                           featurizer =featurizer, dataset_file='../valid.csv')

test_dataset, _ =  featurize_data(tasks = tasks, smiles_col = smiles_col, 
                                           featurizer =featurizer, dataset_file='../test.csv')

etc_dataset, _ =  featurize_data(tasks = ['Exp_LogS'], smiles_col = smiles_col, 
                                           featurizer =featurizer, dataset_file='../etc.csv')
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../train.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 1.148 s
# TIMING: dataset construction took 1.368 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.265 s
# Loading dataset from disk.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../valid.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.156 s
# TIMING: dataset construction took 0.183 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.030 s
# Loading dataset from disk.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../test.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.130 s
# TIMING: dataset construction took 0.149 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.024 s
# Loading dataset from disk.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../etc.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.331 s
# TIMING: dataset construction took 0.410 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.097 s
# Loading dataset from disk.

# %%
# Fit trained model use best parameters
n_atom_feat = 75
n_pair_feat = 14

# Batch size of models
batch_size = 64
patience = 30

lr = 1e-5

model = dc.models.MPNNModel(
                            len(tasks),
                            n_atom_feat=n_atom_feat,
                            n_pair_feat=n_pair_feat,
                            T=3,
                            M=5,
                            batch_size=batch_size,
                            learning_rate=lr,
                            use_queue=False,
                            mode="regression")



def count_params(model):
    trainable_paras = 0
    for layer in model.layers.values():
        x = model.get_layer_variable_values(layer)
        for  i in x:
            if type(i) == np.ndarray:
                if len(i.shape) == 1:
                    trainable_paras += i.shape[0]
                else:
                    a, b = i.shape
                    trainable_paras += a*b
    return trainable_paras

# %%
#count_params(model)

# %%
## perform an early stopping strategy
best_rmse = np.inf
patience = 30
epochs = 500
model_performace = {}
wait = 0

for i in range(epochs):
    model.fit(train_dataset, nb_epoch=1, verbos = 0)
    valid_scores = model.evaluate(valid_dataset, [metric], transformers)
    valid_rmse = valid_scores.get('mean-rms_score')
    model_performace[i] = valid_rmse
    
    
    if  valid_rmse < best_rmse:
        best_rmse = valid_rmse
        print(best_rmse)
        wait = 0        
        best_train_rmse = model.evaluate(train_dataset, [metric], transformers).get('mean-rms_score')
        best_valid_rmse = model.evaluate(valid_dataset, [metric], transformers).get('mean-rms_score')        
        best_test_rmse = model.evaluate(test_dataset, [metric], transformers).get('mean-rms_score')
        best_etc_rmse = model.evaluate(etc_dataset, [metric], transformers).get('mean-rms_score')

        best_train_pred_y = list(model.predict(train_dataset, transformers).reshape(-1,))
        best_valid_pred_y = list(model.predict(valid_dataset, transformers).reshape(-1,))           
        best_test_pred_y = list(model.predict(test_dataset, transformers).reshape(-1,))                 
        best_etc_pred_y = list(model.predict(etc_dataset, transformers).reshape(-1,))             
        
        
        best_epoch = i
    else:
        wait += 1
        if wait >= patience:
            print('early stopping at best_rmse : %s...' % best_rmse)
            break
# Out:
# WARNING:tensorflow:Entity <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f6dd03762e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f6dd03762e8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f6dd03762e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f6dd03762e8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f6dd03762e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f6dd03762e8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f6dd053d860>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f6dd053d780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f6dd036a7b8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f6dd036a7b8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f6dd036a7b8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f6dd036a7b8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f6dd036a7b8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f6dd036a7b8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# computed_metrics: [2.0330416384636907]
# 2.0330416384636907
# computed_metrics: [1.9917421993686013]
# computed_metrics: [2.0330416381951335]
# computed_metrics: [2.0199252241849046]
# computed_metrics: [2.268804359002615]
# computed_metrics: [1.9887151806774832]
# 1.9887151806774832
# computed_metrics: [1.9211863053447849]
# computed_metrics: [1.988715176957381]
# computed_metrics: [1.958631084777008]
# computed_metrics: [2.556575771606248]
# computed_metrics: [1.9477059343286223]
# 1.9477059343286223
# computed_metrics: [1.8603324880550232]
# computed_metrics: [1.9477059298581263]
# computed_metrics: [1.907776653578172]
# computed_metrics: [2.851387951338282]
# computed_metrics: [1.9034209198329102]
# 1.9034209198329102
# computed_metrics: [1.8025551758582876]
# computed_metrics: [1.9034209195736427]
# computed_metrics: [1.8639723173619784]
# computed_metrics: [3.0971591961433433]
# computed_metrics: [1.8495659688959827]
# 1.8495659688959827
# computed_metrics: [1.7447030240981594]
# computed_metrics: [1.8495659663515884]
# computed_metrics: [1.8320489345409345]
# computed_metrics: [3.2299248911866365]
# computed_metrics: [1.8146177737174058]
# 1.8146177737174058
# computed_metrics: [1.6867833338715663]
# computed_metrics: [1.8146177696883583]
# computed_metrics: [1.791111663408466]
# computed_metrics: [3.515957943595952]
# computed_metrics: [1.759644213751142]
# 1.759644213751142
# computed_metrics: [1.6320540548488252]
# computed_metrics: [1.7596441986681695]
# computed_metrics: [1.7704427196770172]
# computed_metrics: [3.6769176599511266]
# computed_metrics: [1.7083169989109026]
# 1.7083169989109026
# computed_metrics: [1.581581269692967]
# computed_metrics: [1.708316985566595]
# computed_metrics: [1.7514140278001267]
# computed_metrics: [3.8220294565229276]
# computed_metrics: [1.6484785248815588]
# 1.6484785248815588
# computed_metrics: [1.5310157902700623]
# computed_metrics: [1.6484785271740265]
# computed_metrics: [1.7250008294001966]
# computed_metrics: [3.9048905337523276]
# computed_metrics: [1.594782549866348]
# 1.594782549866348
# computed_metrics: [1.4811016242902277]
# computed_metrics: [1.5947825362788568]
# computed_metrics: [1.6873368039818284]
# computed_metrics: [3.982897579801751]
# computed_metrics: [1.5178140787786372]
# 1.5178140787786372
# computed_metrics: [1.4356980725758448]
# computed_metrics: [1.5178140791223143]
# computed_metrics: [1.6746652638612158]
# computed_metrics: [3.955379783637952]
# computed_metrics: [1.484480936320692]
# 1.484480936320692
# computed_metrics: [1.3868498964911675]
# computed_metrics: [1.484480946012735]
# computed_metrics: [1.6089710746397723]
# computed_metrics: [4.061708859517783]
# computed_metrics: [1.4097708665009818]
# 1.4097708665009818
# computed_metrics: [1.350438512208691]
# computed_metrics: [1.4097708916265896]
# computed_metrics: [1.6207284384919496]
# computed_metrics: [3.864007478830055]
# computed_metrics: [1.4029785051403318]
# 1.4029785051403318
# computed_metrics: [1.3110324954684311]
# computed_metrics: [1.4029785283662661]
# computed_metrics: [1.5406339961616782]
# computed_metrics: [4.069216310375959]
# computed_metrics: [1.3353352456772287]
# 1.3353352456772287
# computed_metrics: [1.2762142030823111]
# computed_metrics: [1.3353352457246708]
# computed_metrics: [1.5472978164464481]
# computed_metrics: [3.917326177516228]
# computed_metrics: [1.3296492080009619]
# 1.3296492080009619
# computed_metrics: [1.2487191827924513]
# computed_metrics: [1.329649216368425]
# computed_metrics: [1.5029094689281388]
# computed_metrics: [3.941143433082803]
# computed_metrics: [1.3056283493698588]
# 1.3056283493698588
# computed_metrics: [1.2256314391480112]
# computed_metrics: [1.3056283591488458]
# computed_metrics: [1.4819274660517896]
# computed_metrics: [3.917808945383657]
# computed_metrics: [1.282539302546245]
# 1.282539302546245
# computed_metrics: [1.2061264342928182]
# computed_metrics: [1.2825393115171166]
# computed_metrics: [1.459385039423897]
# computed_metrics: [3.8511690704095414]
# computed_metrics: [1.2377195374512269]
# 1.2377195374512269
# computed_metrics: [1.1968812132136337]
# computed_metrics: [1.2377195446244602]
# computed_metrics: [1.48846721829214]
# computed_metrics: [3.5288108972152714]
# computed_metrics: [1.2427950384401503]
# computed_metrics: [1.3448303232283394]
# computed_metrics: [1.2631904548200859]
# computed_metrics: [1.20104614995917]
# 1.20104614995917
# computed_metrics: [1.127086783016936]
# computed_metrics: [1.2010461546219844]
# computed_metrics: [1.3784021705069158]
# computed_metrics: [3.6641411501369467]
# computed_metrics: [1.1783587094038661]
# 1.1783587094038661
# computed_metrics: [1.1163426107871524]
# computed_metrics: [1.1783587056825007]
# computed_metrics: [1.3720411741287433]
# computed_metrics: [3.495067406879395]
# computed_metrics: [1.2089473740474947]
# computed_metrics: [1.2029219979715398]
# computed_metrics: [1.1424733340521775]
# 1.1424733340521775
# computed_metrics: [1.0792737495353304]
# computed_metrics: [1.1424733284071444]
# computed_metrics: [1.3341654511930987]
# computed_metrics: [3.431686571157476]
# computed_metrics: [1.1288684997372158]
# 1.1288684997372158
# computed_metrics: [1.0707536256978984]
# computed_metrics: [1.128868502353508]
# computed_metrics: [1.32957737275284]
# computed_metrics: [3.3844228984021516]
# computed_metrics: [1.1544445308156315]
# computed_metrics: [1.137166209834825]
# computed_metrics: [1.128397661914074]
# 1.128397661914074
# computed_metrics: [1.0375891035475155]
# computed_metrics: [1.1283976610151503]
# computed_metrics: [1.2641784779362337]
# computed_metrics: [3.6107973877005577]
# computed_metrics: [1.1040264161442441]
# 1.1040264161442441
# computed_metrics: [1.0277696290873861]
# computed_metrics: [1.1040264278012415]
# computed_metrics: [1.2634697063582667]
# computed_metrics: [3.4565000234766017]
# computed_metrics: [1.1578236127522765]
# computed_metrics: [1.1059189245695378]
# computed_metrics: [1.0747351833762722]
# 1.0747351833762722
# computed_metrics: [1.0020992949890475]
# computed_metrics: [1.074735186764434]
# computed_metrics: [1.2399403595486433]
# computed_metrics: [3.487886738903487]
# computed_metrics: [1.0450862163514074]
# 1.0450862163514074
# computed_metrics: [1.0057924628948427]
# computed_metrics: [1.0450862330642283]
# computed_metrics: [1.2692074526864259]
# computed_metrics: [3.2673041114463586]
# computed_metrics: [1.073653442859659]
# computed_metrics: [1.0290716406219236]
# 1.0290716406219236
# computed_metrics: [0.9904446395111911]
# computed_metrics: [1.029071626140558]
# computed_metrics: [1.2547492097596247]
# computed_metrics: [3.2154863926283266]
# computed_metrics: [1.0256389608757763]
# 1.0256389608757763
# computed_metrics: [0.97772704217154]
# computed_metrics: [1.025638973811533]
# computed_metrics: [1.2365310867717842]
# computed_metrics: [3.320380576155862]
# computed_metrics: [1.0338609414631152]
# computed_metrics: [1.0522442970292432]
# computed_metrics: [1.0080266938892077]
# 1.0080266938892077
# computed_metrics: [0.9557339407576183]
# computed_metrics: [1.0080267173455613]
# computed_metrics: [1.207530689399361]
# computed_metrics: [3.319078506972389]
# computed_metrics: [1.0303379590442618]
# computed_metrics: [1.0017298088915756]
# 1.0017298088915756
# computed_metrics: [0.9387469808135978]
# computed_metrics: [1.0017298160532326]
# computed_metrics: [1.1866757345974959]
# computed_metrics: [3.3458210171468505]
# computed_metrics: [1.0582799955691147]
# computed_metrics: [1.1271315823770744]
# computed_metrics: [1.0508058796735775]
# computed_metrics: [0.9881390421060685]
# 0.9881390421060685
# computed_metrics: [0.9105631956674629]
# computed_metrics: [0.988139030148238]
# computed_metrics: [1.1438388141896623]
# computed_metrics: [3.3695059736507074]
# computed_metrics: [0.9932690226404458]
# computed_metrics: [0.9914540590584313]
# computed_metrics: [0.9936769480921567]
# computed_metrics: [0.9319130248716923]
# 0.9319130248716923
# computed_metrics: [0.9017458159414036]
# computed_metrics: [0.9319130119642637]
# computed_metrics: [1.1771734049674851]
# computed_metrics: [3.10499337269121]
# computed_metrics: [0.9237048525940175]
# 0.9237048525940175
# computed_metrics: [0.9306765831653049]
# computed_metrics: [0.9237048525426197]
# computed_metrics: [1.2259909044849844]
# computed_metrics: [2.89206164821741]
# computed_metrics: [0.9215161853734635]
# 0.9215161853734635
# computed_metrics: [0.908023998763041]
# computed_metrics: [0.9215161795616206]
# computed_metrics: [1.1912585802169895]
# computed_metrics: [2.901095697358702]
# computed_metrics: [0.9626131667673201]
# computed_metrics: [0.9323160510813712]
# computed_metrics: [0.9748570634856727]
# computed_metrics: [0.9516988782162547]
# computed_metrics: [0.9471327317304887]
# computed_metrics: [0.8997295476888048]
# 0.8997295476888048
# computed_metrics: [0.8540513487375596]
# computed_metrics: [0.8997295403316495]
# computed_metrics: [1.1155858581492712]
# computed_metrics: [2.9841359304047503]
# computed_metrics: [0.8935391209138743]
# 0.8935391209138743
# computed_metrics: [0.8401358029531862]
# computed_metrics: [0.8935391227893525]
# computed_metrics: [1.1004456671361071]
# computed_metrics: [3.1756912250896026]
# computed_metrics: [0.8964790066851287]
# computed_metrics: [0.9102335314768287]
# computed_metrics: [0.9031777564713849]
# computed_metrics: [0.9446544037054161]
# computed_metrics: [0.8708083234362275]
# 0.8708083234362275
# computed_metrics: [0.8198298773384047]
# computed_metrics: [0.8708083295278437]
# computed_metrics: [1.0841952450331933]
# computed_metrics: [3.0063421637148173]
# computed_metrics: [0.886498370723437]
# computed_metrics: [0.8969717268995177]
# computed_metrics: [0.8967262549366978]
# computed_metrics: [0.8700147191301917]
# 0.8700147191301917
# computed_metrics: [0.7904987930353184]
# computed_metrics: [0.8700146841429062]
# computed_metrics: [1.029603536813687]
# computed_metrics: [3.192617153887756]
# computed_metrics: [0.8980436081529186]
# computed_metrics: [0.8883718456305673]
# computed_metrics: [0.874420288895585]
# computed_metrics: [0.834723196588575]
# 0.834723196588575
# computed_metrics: [0.8227851709245179]
# computed_metrics: [0.8347231992530751]
# computed_metrics: [1.1055948586541609]
# computed_metrics: [2.7787517380916618]
# computed_metrics: [0.8269730536031876]
# 0.8269730536031876
# computed_metrics: [0.7804464533130319]
# computed_metrics: [0.8269730427369313]
# computed_metrics: [1.060348109110731]
# computed_metrics: [2.911935250808514]
# computed_metrics: [0.8291685331539115]
# computed_metrics: [0.8512367510330813]
# computed_metrics: [0.8333987480575002]
# computed_metrics: [0.8405576835981489]
# computed_metrics: [0.8460222057845433]
# computed_metrics: [0.8000820785076667]
# 0.8000820785076667
# computed_metrics: [0.7651924541979576]
# computed_metrics: [0.8000820298287037]
# computed_metrics: [1.0613345699313077]
# computed_metrics: [2.831872243246737]
# computed_metrics: [0.8477726582266415]
# computed_metrics: [0.7967440094089937]
# 0.7967440094089937
# computed_metrics: [0.7563150082323006]
# computed_metrics: [0.7967440002793953]
# computed_metrics: [1.0503832819571788]
# computed_metrics: [2.851226169649573]
# computed_metrics: [0.8200730342898642]
# computed_metrics: [0.8462586624796585]
# computed_metrics: [0.9263154570319158]
# computed_metrics: [0.8093777702999058]
# computed_metrics: [0.8261844140194905]
# computed_metrics: [0.8328907316095134]
# computed_metrics: [0.7783096096960536]
# 0.7783096096960536
# computed_metrics: [0.738234000147397]
# computed_metrics: [0.7783096028327547]
# computed_metrics: [1.042502197870557]
# computed_metrics: [2.7199893928548153]
# computed_metrics: [0.8106824333203436]
# computed_metrics: [0.8494390018048421]
# computed_metrics: [0.7906629217717412]
# computed_metrics: [0.8798828113478343]
# computed_metrics: [0.8710312735319705]
# computed_metrics: [0.853428189436119]
# computed_metrics: [0.7635756850155012]
# 0.7635756850155012
# computed_metrics: [0.7236853175090704]
# computed_metrics: [0.7635756907095189]
# computed_metrics: [1.0418588032885785]
# computed_metrics: [2.6122430659656652]
# computed_metrics: [0.8625862030327347]
# computed_metrics: [0.7618066967658793]
# 0.7618066967658793
# computed_metrics: [0.7572576931554187]
# computed_metrics: [0.7618067041046916]
# computed_metrics: [1.0865543633013244]
# computed_metrics: [2.486468302010307]
# computed_metrics: [0.7753749138444663]
# computed_metrics: [0.7929466005182401]
# computed_metrics: [0.7548721995700217]
# 0.7548721995700217
# computed_metrics: [0.7050023114743502]
# computed_metrics: [0.7548721919354892]
# computed_metrics: [1.0255876466321696]
# computed_metrics: [2.5968692013954215]
# computed_metrics: [0.8103415338492037]
# computed_metrics: [0.7788174330536316]
# computed_metrics: [0.7908282678183277]
# computed_metrics: [0.7714668286960953]
# computed_metrics: [0.8181483450164967]
# computed_metrics: [0.8027343560296737]
# computed_metrics: [0.769942153308133]
# computed_metrics: [0.8309202296105354]
# computed_metrics: [0.7665847230289154]
# computed_metrics: [0.7665065012633236]
# computed_metrics: [0.7608292766151492]
# computed_metrics: [0.7983548798907838]
# computed_metrics: [0.7860377862370774]
# computed_metrics: [0.7870004618037565]
# computed_metrics: [0.7386122186008063]
# 0.7386122186008063
# computed_metrics: [0.6602191093875236]
# computed_metrics: [0.7386122109473224]
# computed_metrics: [0.9824059699133262]
# computed_metrics: [2.5576081155855634]
# computed_metrics: [0.7973078150442987]
# computed_metrics: [0.7796261120168081]
# computed_metrics: [0.792265431964355]
# computed_metrics: [0.7307887988914626]
# 0.7307887988914626
# computed_metrics: [0.6675821747612322]
# computed_metrics: [0.7307888096106988]
# computed_metrics: [1.0021441490767384]
# computed_metrics: [2.4201313688026334]
# computed_metrics: [0.8349416878448299]
# computed_metrics: [0.7801998541382843]
# computed_metrics: [0.7365650394874732]
# computed_metrics: [0.7778463425996657]
# computed_metrics: [0.7554667706352571]
# computed_metrics: [0.7173892744426299]
# 0.7173892744426299
# computed_metrics: [0.6574225040581637]
# computed_metrics: [0.7173892509595966]
# computed_metrics: [1.0159965616074222]
# computed_metrics: [2.395585127100579]
# computed_metrics: [0.7925306094638302]
# computed_metrics: [0.7968705311089518]
# computed_metrics: [0.7668545603940622]
# computed_metrics: [0.7400896180996892]
# computed_metrics: [0.7300633988295162]
# computed_metrics: [0.8422111259466466]
# computed_metrics: [0.8307548140559422]
# computed_metrics: [0.7460028378495767]
# computed_metrics: [0.79433739525626]
# computed_metrics: [0.7637810616814691]
# computed_metrics: [0.7353550595393187]
# computed_metrics: [0.8151008477264994]
# computed_metrics: [0.7295847401174814]
# computed_metrics: [0.8268861098613602]
# computed_metrics: [0.798211551784901]
# computed_metrics: [0.7681447783212427]
# computed_metrics: [0.7468356817053292]
# computed_metrics: [0.7390351308582582]
# computed_metrics: [0.7130292037183048]
# 0.7130292037183048
# computed_metrics: [0.5936728179764974]
# computed_metrics: [0.7130291797362025]
# computed_metrics: [0.93550103863002]
# computed_metrics: [2.4122935591992616]
# computed_metrics: [0.7803365570449216]
# computed_metrics: [0.7574064875619925]
# computed_metrics: [0.7407318007995597]
# computed_metrics: [0.7440311001057099]
# computed_metrics: [0.7508478318423416]
# computed_metrics: [0.7362676544643992]
# computed_metrics: [0.6971826000314075]
# 0.6971826000314075
# computed_metrics: [0.610099292189373]
# computed_metrics: [0.6971825999323179]
# computed_metrics: [0.983344115930913]
# computed_metrics: [2.257781274429901]
# computed_metrics: [0.7287032282686186]
# computed_metrics: [0.74921319989208]
# computed_metrics: [0.76341361108081]
# computed_metrics: [0.7107281902157064]
# computed_metrics: [0.8399174540738237]
# computed_metrics: [0.7040276211083754]
# computed_metrics: [0.821291124981805]
# computed_metrics: [0.6913096309829971]
# 0.6913096309829971
# computed_metrics: [0.6049936472688641]
# computed_metrics: [0.6913096072408291]
# computed_metrics: [0.9863485859937577]
# computed_metrics: [2.2180454382490757]
# computed_metrics: [0.7681211016241533]
# computed_metrics: [0.7149204467241369]
# computed_metrics: [0.7460036302920144]
# computed_metrics: [0.7227830777671411]
# computed_metrics: [0.7549954758989259]
# computed_metrics: [0.7158847162728488]
# computed_metrics: [0.6916260643467446]
# computed_metrics: [0.7738232676157341]
# computed_metrics: [0.728000589665815]
# computed_metrics: [0.6970562619149467]
# computed_metrics: [0.701590000111537]
# computed_metrics: [0.7694951776728187]
# computed_metrics: [0.7253053009283023]
# computed_metrics: [0.7289906040447885]
# computed_metrics: [0.7420354831624469]
# computed_metrics: [0.7444362706955817]
# computed_metrics: [0.7590352198073008]
# computed_metrics: [0.684321953933524]
# 0.684321953933524
# computed_metrics: [0.6223182133488906]
# computed_metrics: [0.6843219485058286]
# computed_metrics: [1.019253557680617]
# computed_metrics: [2.140711170765345]
# computed_metrics: [0.7449408188112875]
# computed_metrics: [0.6909690310301072]
# computed_metrics: [0.7459296465109035]
# computed_metrics: [0.6792849098345967]
# 0.6792849098345967
# computed_metrics: [0.5613430704509795]
# computed_metrics: [0.6792849099140721]
# computed_metrics: [0.9580042622312644]
# computed_metrics: [2.209552557262494]
# computed_metrics: [0.7849257007586448]
# computed_metrics: [0.7368439768266414]
# computed_metrics: [0.7021990102604724]
# computed_metrics: [0.7066614439067638]
# computed_metrics: [0.7731361884593005]
# computed_metrics: [0.6941298460089275]
# computed_metrics: [0.7146849811639489]
# computed_metrics: [0.7123693354834014]
# computed_metrics: [0.7391069745806955]
# computed_metrics: [0.7278758358479698]
# computed_metrics: [0.6946922758696774]
# computed_metrics: [0.7865549204698591]
# computed_metrics: [0.7098858384109368]
# computed_metrics: [0.7736859533966496]
# computed_metrics: [0.7046320450062769]
# computed_metrics: [0.7477252458073463]
# computed_metrics: [0.6788894642930134]
# 0.6788894642930134
# computed_metrics: [0.5365522716698252]
# computed_metrics: [0.6788894513974723]
# computed_metrics: [0.9416854197348243]
# computed_metrics: [2.188234110915378]
# computed_metrics: [0.7511029630046158]
# computed_metrics: [0.7458953543312777]
# computed_metrics: [0.7536522681651354]
# computed_metrics: [0.7188927506151848]
# computed_metrics: [0.8034732128622981]
# computed_metrics: [0.7044182641979443]
# computed_metrics: [0.6818928450038109]
# computed_metrics: [0.744253536016158]
# computed_metrics: [0.6750558571128291]
# 0.6750558571128291
# computed_metrics: [0.5224984060171756]
# computed_metrics: [0.6750558368536107]
# computed_metrics: [0.9179055544852621]
# computed_metrics: [2.2138539611019907]
# computed_metrics: [0.7316911132781034]
# computed_metrics: [0.6808485156192479]
# computed_metrics: [0.7082112715481748]
# computed_metrics: [0.6938112001417263]
# computed_metrics: [0.7845753621773007]
# computed_metrics: [0.6722027821289236]
# 0.6722027821289236
# computed_metrics: [0.5155082676193583]
# computed_metrics: [0.6722028064382707]
# computed_metrics: [0.9173702051430161]
# computed_metrics: [2.2052340924495777]
# computed_metrics: [0.7110834075146879]
# computed_metrics: [0.7051682464778196]
# computed_metrics: [0.7931365496762036]
# computed_metrics: [0.7026475357826916]
# computed_metrics: [0.7114062601161945]
# computed_metrics: [0.6986967171378639]
# computed_metrics: [0.7715718666026989]
# computed_metrics: [0.7125967364907693]
# computed_metrics: [0.6771715422913358]
# computed_metrics: [0.7208568419082352]
# computed_metrics: [0.6793771163735597]
# computed_metrics: [0.7862622755704082]
# computed_metrics: [0.7453168201879111]
# computed_metrics: [0.7422465896114833]
# computed_metrics: [0.6985651325670117]
# computed_metrics: [0.6707320341571704]
# 0.6707320341571704
# computed_metrics: [0.505939162490824]
# computed_metrics: [0.6707320051083512]
# computed_metrics: [0.9220052924891047]
# computed_metrics: [2.1397538402564003]
# computed_metrics: [0.7184668744381052]
# computed_metrics: [0.6882953159121618]
# computed_metrics: [0.7483564046448654]
# computed_metrics: [0.6948133690990574]
# computed_metrics: [0.7483822647957126]
# computed_metrics: [0.666056435311493]
# 0.666056435311493
# computed_metrics: [0.5183907322514382]
# computed_metrics: [0.6660564362360547]
# computed_metrics: [0.9619565654866143]
# computed_metrics: [2.108032862182899]
# computed_metrics: [0.6965587151443965]
# computed_metrics: [0.7258513546226779]
# computed_metrics: [0.7179643870176897]
# computed_metrics: [0.7383549101267893]
# computed_metrics: [0.6826533838179694]
# computed_metrics: [0.7516299404044574]
# computed_metrics: [0.669381709666082]
# computed_metrics: [0.8068451535909915]
# computed_metrics: [0.6731286427216231]
# computed_metrics: [0.8179740028120192]
# computed_metrics: [0.6562366877631921]
# 0.6562366877631921
# computed_metrics: [0.5363568965440676]
# computed_metrics: [0.6562366942365659]
# computed_metrics: [0.9987498364386391]
# computed_metrics: [2.1081353458052465]
# computed_metrics: [0.7192865440085939]
# computed_metrics: [0.6940796651069887]
# computed_metrics: [0.6595444302362787]
# computed_metrics: [0.697913742735989]
# computed_metrics: [0.7009237828254226]
# computed_metrics: [0.7883148461719723]
# computed_metrics: [0.6717537651982417]
# computed_metrics: [0.7435556744240879]
# computed_metrics: [0.7075226782681563]
# computed_metrics: [0.7732190675299924]
# computed_metrics: [0.6610778762582954]
# computed_metrics: [0.8311649383327059]
# computed_metrics: [0.6593734599948412]
# computed_metrics: [0.7125715163451996]
# computed_metrics: [0.6819904245534895]
# computed_metrics: [0.6994745759745845]
# computed_metrics: [0.6719345996608376]
# computed_metrics: [0.7559632526104686]
# computed_metrics: [0.6830490609785655]
# computed_metrics: [0.7696554958970422]
# computed_metrics: [0.6705269778794944]
# computed_metrics: [0.7236764639889987]
# computed_metrics: [0.6886819654079939]
# computed_metrics: [0.682938069131236]
# computed_metrics: [0.6759004040295583]
# computed_metrics: [0.6557150020843455]
# 0.6557150020843455
# computed_metrics: [0.486020917414859]
# computed_metrics: [0.6557149946085453]
# computed_metrics: [0.9460644136907048]
# computed_metrics: [2.104746742308026]
# computed_metrics: [0.7714750446525535]
# computed_metrics: [0.6589879022829594]
# computed_metrics: [0.7260907796261291]
# computed_metrics: [0.6643296450968924]
# computed_metrics: [0.7675393955505119]
# computed_metrics: [0.6553943503129539]
# 0.6553943503129539
# computed_metrics: [0.49195800911472715]
# computed_metrics: [0.6553943397888546]
# computed_metrics: [0.9579009855621449]
# computed_metrics: [2.078742400482586]
# computed_metrics: [0.6881419952243361]
# computed_metrics: [0.6816097655769421]
# computed_metrics: [0.7338801861506985]
# computed_metrics: [0.6554444213955981]
# computed_metrics: [0.9063090054564897]
# computed_metrics: [0.6610917594106258]
# computed_metrics: [0.7464088432915866]
# computed_metrics: [0.6662552514816427]
# computed_metrics: [0.7017354883968908]
# computed_metrics: [0.7169677075236942]
# computed_metrics: [0.6699143668625687]
# computed_metrics: [0.6923048331501461]
# computed_metrics: [0.6765965716649549]
# computed_metrics: [0.6837776223937232]
# computed_metrics: [0.6751293843858993]
# computed_metrics: [0.6640560527051871]
# computed_metrics: [0.7019704271588841]
# computed_metrics: [0.6735428990216024]
# computed_metrics: [0.6741760382917827]
# computed_metrics: [0.7040336938952871]
# computed_metrics: [0.7227202029083925]
# computed_metrics: [0.6572850108103468]
# computed_metrics: [0.8025254697458537]
# computed_metrics: [0.6833652311980432]
# computed_metrics: [0.7819791573387015]
# computed_metrics: [0.6644050330010066]
# computed_metrics: [0.7787517196063005]
# computed_metrics: [0.6639288113675819]
# computed_metrics: [0.6967331576369725]
# computed_metrics: [0.6525444520060825]
# 0.6525444520060825
# computed_metrics: [0.4861395110246844]
# computed_metrics: [0.6525444331957864]
# computed_metrics: [0.9757681226973582]
# computed_metrics: [2.0872342833428874]
# computed_metrics: [0.7033621316896034]
# computed_metrics: [0.6554871748812795]
# computed_metrics: [0.7911385311702518]
# computed_metrics: [0.6531246157068068]
# computed_metrics: [0.7058385723645407]
# computed_metrics: [0.6531658927904319]
# computed_metrics: [0.7725210885482425]
# computed_metrics: [0.6739796196283131]
# computed_metrics: [0.6840149364936374]
# computed_metrics: [0.6589153511141521]
# computed_metrics: [0.7491292668866624]
# computed_metrics: [0.654983899905465]
# computed_metrics: [0.7906111624989693]
# computed_metrics: [0.6521968471934115]
# 0.6521968471934115
# computed_metrics: [0.4634238380008247]
# computed_metrics: [0.6521968717781882]
# computed_metrics: [0.9402529007588152]
# computed_metrics: [2.064877212198057]
# computed_metrics: [0.7245368200529223]
# computed_metrics: [0.6670633987458238]
# computed_metrics: [0.6632798706837032]
# computed_metrics: [0.7176410393741123]
# computed_metrics: [0.6853172525719675]
# computed_metrics: [0.6889239870220137]
# computed_metrics: [0.6649981543156835]
# computed_metrics: [0.6849032993966225]
# computed_metrics: [0.6537541417215043]
# computed_metrics: [0.7359447379540449]
# computed_metrics: [0.6569194317163917]
# computed_metrics: [0.7890809756323337]
# computed_metrics: [0.6916362046546409]
# computed_metrics: [0.6691100812617808]
# computed_metrics: [0.6829194370812863]
# computed_metrics: [0.6631586707861431]
# computed_metrics: [0.8227591485020916]
# computed_metrics: [0.6801339084670751]
# computed_metrics: [0.6582542547052426]
# computed_metrics: [0.6798326418580011]
# computed_metrics: [0.7174264257577906]
# computed_metrics: [0.682840533864671]
# computed_metrics: [0.7221652116966065]
# computed_metrics: [0.6629695056273355]
# computed_metrics: [0.7086189026968525]
# computed_metrics: [0.7069231837430713]
# computed_metrics: [0.709714336072482]
# computed_metrics: [0.666807150709774]
# computed_metrics: [0.6786008641318996]
# computed_metrics: [0.6711234399220064]
# early stopping at best_rmse : 0.6521968471934115...

# %%
pd.Series(model_performace).plot()

# %%
final_res = {'train_rmse':best_train_rmse, 
             'valid_rmse':best_valid_rmse, 
             'test_rmse':best_test_rmse,              
             'etc_rmse':best_etc_rmse,

#              'train_pred_y':best_train_pred_y,
#              'test_pred_y':best_test_pred_y,
             'etc_pred_y':best_etc_pred_y, 


             '# trainable params': count_params(model),
             'random_seed':seed, 
             'best_epoch': best_epoch,

             'batch_size':batch_size,
             #'lr': lr,

            }

final_res
# Out:
# {'train_rmse': 0.4634238380008247,
#  'valid_rmse': 0.6521968717781882,
#  'test_rmse': 0.9402529007588152,
#  'etc_rmse': 2.064877212198057,
#  'etc_pred_y': [-3.3531737626161924,
#   -3.2720778497986474,
#   -3.1849853545287803,
#   -3.2996156596381234,
#   -3.4899412048019087,
#   -3.196074089349315,
#   -4.128616129219969,
#   -4.95663064948694,
#   -4.326198689024575,
#   -3.4915043684760128,
#   -3.3439298551215724,
#   -3.8755001514020657,
#   -3.524510451620362,
#   -3.7818531240515476,
#   -3.4600952334599606,
#   -3.462854740086426,
#   -3.4944666767277877,
#   -3.3666449024916254,
#   -3.471926720138594,
#   -3.58708504969493,
#   -3.775737694975253,
#   -3.4218886536069397,
#   -3.648070354920148,
#   -3.4984290111503498,
#   -3.375311753793935,
#   -3.4308731040853706,
#   -3.287641775281073,
#   -3.3508375423020453,
#   -3.2809838178511863,
#   -3.6004963392076914,
#   -3.5429119391044592,
#   -3.073846712697422,
#   -2.975833825591639,
#   -3.5827673142022767,
#   -4.4830470034215875,
#   -2.993054082972617,
#   -3.756326248437768,
#   -3.3749365818587966,
#   -3.1864412968475593,
#   -3.171337858537125,
#   -3.9907518943415776,
#   -3.4159802017626526,
#   -2.3921649036825254,
#   -3.2235537886622434,
#   -3.5434238937923412,
#   -3.2119403983501202,
#   -3.495434626647122,
#   -3.4035878868177396,
#   -3.4647970298686777,
#   -3.2937629299998856,
#   -3.411135928592058,
#   -3.6226975971535857,
#   -3.2412516231509594,
#   -3.6661590198691205,
#   -3.6673428676347717,
#   -3.263036775562721,
#   -3.0909455532419714,
#   -2.530628844256225,
#   -3.027174151553886,
#   -2.5902164600394393,
#   -3.339257635926966,
#   -4.213719612199304,
#   -3.2638755980082585,
#   -3.0281446954107145,
#   -3.435064780542482,
#   -2.926118807086512,
#   -5.400453607813814,
#   -2.8088679608069484,
#   -3.3375417462745443,
#   -3.6242430777659913,
#   -3.5212171316376177,
#   -3.480885705742844,
#   -3.2597685092201654,
#   -3.6956781550867976,
#   -3.1360072752474286,
#   -3.609491102169331,
#   -3.434944194082385,
#   -3.4925172378007345,
#   -4.074007038689366,
#   -3.384171758539412,
#   -3.218749152121896,
#   -3.0755540138860673,
#   -3.620475162121959,
#   -3.2798946171706893,
#   -3.5316896165029723,
#   -3.74615200311748,
#   -3.493523211047728,
#   -3.669843360112425,
#   -3.208134206311356,
#   -3.69830530763429,
#   -3.830549618764549,
#   -3.2928927905041134,
#   -3.4425187762659433,
#   -3.1825440006626566,
#   -3.3052831283625217,
#   -3.1794859381572844,
#   -3.6228846137202417,
#   -4.682073121075107,
#   -4.0571868091750645,
#   -3.2446263200142385,
#   -3.294119770388952,
#   -3.5598937835780045,
#   -3.5120072616642632,
#   -3.5356026661131446,
#   -4.597535559336887,
#   -3.2441236813579666,
#   -3.369191579710029,
#   -3.2720415504904206,
#   -3.2299471644677205,
#   -3.2329050124123406,
#   -3.333386922709881,
#   -3.693301792008258,
#   -3.337061045370129,
#   -3.3700406830053904,
#   -3.442344571219838,
#   -3.505135604908253,
#   -2.757706308106307,
#   -3.5284311881428643,
#   -3.3923636662132086,
#   -3.535443866525084],
#  '# trainable params': 341201,
#  'random_seed': 777,
#  'best_epoch': 323,
#  'batch_size': 64}
