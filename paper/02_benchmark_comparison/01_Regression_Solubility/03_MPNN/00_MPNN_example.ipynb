# %%
from __future__ import print_function
from __future__ import division
from __future__ import unicode_literals

import numpy as np
import tensorflow as tf
from joblib import load,dump
from rdkit import Chem
import pandas as pd

from deepchem.models import GraphConvModel, MPNNModel
import deepchem as dc
from deepchem.molnet.preset_hyper_parameters import hps
from copy import deepcopy
import os
os.environ["CUDA_VISIBLE_DEVICES"]="5"
# %matplotlib inline
#os.environ.setdefault('DEEPCHEM_DATA_DIR', os.popen('pwd').read().strip())
# Out:
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/sxh/.local/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
dc.__version__
# Out:
# '2.1.1'

# %%
seed = 777
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
def featurize_data(tasks, smiles_col, featurizer, dataset_file, normalize = True):
    loader = dc.data.CSVLoader(tasks=tasks, smiles_field=smiles_col, featurizer=featurizer)
    dataset = loader.featurize(dataset_file, shard_size=8192)
    move_mean = True
    if normalize:
        transformers = [dc.trans.NormalizationTransformer(
            transform_y=True, dataset=dataset, move_mean=move_mean)]
    else:
        transformers = []
    for transformer in transformers:
        dataset = transformer.transform(dataset)
    return dataset, transformers

# %%
featurizer = dc.feat.graph_features.WeaveFeaturizer()
metric = dc.metrics.Metric(dc.metrics.rms_score, np.mean)

# %% [markdown]
# # use the same dataset as MolMapNet and attentivFP

# %%
tasks = ['measured log solubility in mols per litre']
smiles_col = 'smiles'

# tasks, delaney_datasets, transformers = dc.molnet.load_delaney(featurizer='Weave', split='random')
# train_dataset, valid_dataset, test_dataset = delaney_datasets
train_dataset, transformers =  featurize_data(tasks = tasks, smiles_col = smiles_col, 
                                           featurizer =featurizer, dataset_file='../train.csv')

valid_dataset, _ =  featurize_data(tasks = tasks, smiles_col = smiles_col, 
                                           featurizer =featurizer, dataset_file='../valid.csv')

test_dataset, _ =  featurize_data(tasks = tasks, smiles_col = smiles_col, 
                                           featurizer =featurizer, dataset_file='../test.csv')

etc_dataset, _ =  featurize_data(tasks = ['Exp_LogS'], smiles_col = smiles_col, 
                                           featurizer =featurizer, dataset_file='../etc.csv')
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../train.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 1.168 s
# TIMING: dataset construction took 1.369 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.269 s
# Loading dataset from disk.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../valid.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.155 s
# TIMING: dataset construction took 0.180 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.031 s
# Loading dataset from disk.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../test.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.130 s
# TIMING: dataset construction took 0.150 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.023 s
# Loading dataset from disk.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../etc.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.335 s
# TIMING: dataset construction took 0.391 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.078 s
# Loading dataset from disk.

# %%
# Fit trained model use best parameters
n_atom_feat = 75
n_pair_feat = 14

# Batch size of models
batch_size = 64
patience = 30

lr = 1e-5

model = dc.models.MPNNModel(
                            len(tasks),
                            n_atom_feat=n_atom_feat,
                            n_pair_feat=n_pair_feat,
                            T=3,
                            M=5,
                            batch_size=batch_size,
                            learning_rate=lr,
                            use_queue=False,
                            mode="regression")



def count_params(model):
    trainable_paras = 0
    for layer in model.layers.values():
        x = model.get_layer_variable_values(layer)
        for  i in x:
            if type(i) == np.ndarray:
                if len(i.shape) == 1:
                    trainable_paras += i.shape[0]
                else:
                    a, b = i.shape
                    trainable_paras += a*b
    return trainable_paras

# %%
#count_params(model)

# %%
## perform an early stopping strategy
best_rmse = np.inf
patience = 30
epochs = 500
model_performace = {}
wait = 0

for i in range(epochs):
    
    train_dataset.shuffle_each_shard()
    
    model.fit(train_dataset, nb_epoch=1, verbos = 0)
    valid_scores = model.evaluate(valid_dataset, [metric], transformers)
    valid_rmse = valid_scores.get('mean-rms_score')
    model_performace[i] = valid_rmse
    
    
    if  valid_rmse < best_rmse:
        best_rmse = valid_rmse
        print(best_rmse)
        wait = 0        
        best_train_rmse = model.evaluate(train_dataset, [metric], transformers).get('mean-rms_score')
        best_valid_rmse = model.evaluate(valid_dataset, [metric], transformers).get('mean-rms_score')        
        best_test_rmse = model.evaluate(test_dataset, [metric], transformers).get('mean-rms_score')
        best_etc_rmse = model.evaluate(etc_dataset, [metric], transformers).get('mean-rms_score')

        best_train_pred_y = list(model.predict(train_dataset, transformers).reshape(-1,))
        best_valid_pred_y = list(model.predict(valid_dataset, transformers).reshape(-1,))           
        best_test_pred_y = list(model.predict(test_dataset, transformers).reshape(-1,))                 
        best_etc_pred_y = list(model.predict(etc_dataset, transformers).reshape(-1,))             
        
        
        best_epoch = i
    else:
        wait += 1
        if wait >= patience:
            print('early stopping at best_rmse : %s...' % best_rmse)
            break
# Out:
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:715: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:715: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:Entity <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f03b5fcc320>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f03b5fcc320>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f03b5fcc320>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f03b5fcc320>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f03b5fcc320>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MessagePassing.call of <deepchem.models.layers.MessagePassing object at 0x7f03b5fcc320>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/model_ops.py:261: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/model_ops.py:261: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/model_ops.py:450: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/model_ops.py:450: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/autograph/converters/directives.py:117: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/autograph/converters/directives.py:117: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/autograph/converters/directives.py:117: The name tf.segment_sum is deprecated. Please use tf.math.segment_sum instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/autograph/converters/directives.py:117: The name tf.segment_sum is deprecated. Please use tf.math.segment_sum instead.
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method EdgeNetwork.call of <deepchem.models.layers.EdgeNetwork object at 0x7f04499c8128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method GatedRecurrentUnit.call of <deepchem.models.layers.GatedRecurrentUnit object at 0x7f04499c8748>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f0449a5e630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f0449a5e630>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f0449a5e630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f0449a5e630>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f0449a5e630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method SetGather.call of <deepchem.models.layers.SetGather object at 0x7f0449a5e630>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:728: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:728: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/optimizers.py:76: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/optimizers.py:76: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:1013: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:1013: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:1013: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:1013: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:749: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
# WARNING:tensorflow:From /home/sxh/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/deepchem/models/tensorgraph/tensor_graph.py:749: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
# computed_metrics: [2.052050322784845]
# 2.052050322784845
# computed_metrics: [2.030105729927619]
# computed_metrics: [2.0520503214064085]
# computed_metrics: [2.0384362016107063]
# computed_metrics: [2.177830568515518]
# computed_metrics: [2.0113017392691215]
# 2.0113017392691215
# computed_metrics: [1.9657113316710049]
# computed_metrics: [2.011301740019117]
# computed_metrics: [1.9799491285323032]
# computed_metrics: [2.3822621481669617]
# computed_metrics: [1.980050856246327]
# 1.980050856246327
# computed_metrics: [1.9099340349027525]
# computed_metrics: [1.9800508458162656]
# computed_metrics: [1.9300919226924316]
# computed_metrics: [2.6666016293521437]
# computed_metrics: [1.9404120514956298]
# 1.9404120514956298
# computed_metrics: [1.855252488097508]
# computed_metrics: [1.9404120429197236]
# computed_metrics: [1.8906670086778208]
# computed_metrics: [2.8349470884345975]
# computed_metrics: [1.9046259126768819]
# 1.9046259126768819
# computed_metrics: [1.7978632605349978]
# computed_metrics: [1.904625901764878]
# computed_metrics: [1.8485946656323269]
# computed_metrics: [3.0847121210803063]
# computed_metrics: [1.8572934491073583]
# 1.8572934491073583
# computed_metrics: [1.7364074537855227]
# computed_metrics: [1.857293435175042]
# computed_metrics: [1.8168328798894697]
# computed_metrics: [3.281317144614033]
# computed_metrics: [1.806859310808918]
# 1.806859310808918
# computed_metrics: [1.6753284595822908]
# computed_metrics: [1.8068593093799585]
# computed_metrics: [1.7826102460471878]
# computed_metrics: [3.4657251868191605]
# computed_metrics: [1.7508403297733264]
# 1.7508403297733264
# computed_metrics: [1.6149265948180302]
# computed_metrics: [1.7508403403473622]
# computed_metrics: [1.7603789611174943]
# computed_metrics: [3.6455175447299633]
# computed_metrics: [1.7013435457331192]
# 1.7013435457331192
# computed_metrics: [1.557010227233161]
# computed_metrics: [1.7013435493773876]
# computed_metrics: [1.72267514632268]
# computed_metrics: [3.861259183425136]
# computed_metrics: [1.6454675682610522]
# 1.6454675682610522
# computed_metrics: [1.500365586628685]
# computed_metrics: [1.6454675508132766]
# computed_metrics: [1.6928929018892014]
# computed_metrics: [3.9515886047296047]
# computed_metrics: [1.575286218911164]
# 1.575286218911164
# computed_metrics: [1.4456450064687008]
# computed_metrics: [1.5752862333507287]
# computed_metrics: [1.6627822516928148]
# computed_metrics: [3.94402658819582]
# computed_metrics: [1.5298657267662517]
# 1.5298657267662517
# computed_metrics: [1.396729481132502]
# computed_metrics: [1.529865749983652]
# computed_metrics: [1.612180510991805]
# computed_metrics: [3.96706443737322]
# computed_metrics: [1.4463338856425147]
# 1.4463338856425147
# computed_metrics: [1.3584314282423968]
# computed_metrics: [1.4463338754612804]
# computed_metrics: [1.6070764970164926]
# computed_metrics: [3.6300412311181622]
# computed_metrics: [1.3955536748852984]
# 1.3955536748852984
# computed_metrics: [1.3308519308298474]
# computed_metrics: [1.3955536739714915]
# computed_metrics: [1.5994903435421275]
# computed_metrics: [3.4283594280799554]
# computed_metrics: [1.3554221119456045]
# 1.3554221119456045
# computed_metrics: [1.3001009229047433]
# computed_metrics: [1.3554221275715264]
# computed_metrics: [1.5694179906972225]
# computed_metrics: [3.4219048549269298]
# computed_metrics: [1.3344795681735984]
# 1.3344795681735984
# computed_metrics: [1.2662510859232268]
# computed_metrics: [1.3344795684108746]
# computed_metrics: [1.5303880882072531]
# computed_metrics: [3.357765270969788]
# computed_metrics: [1.3483576238172503]
# computed_metrics: [1.2853779728000119]
# 1.2853779728000119
# computed_metrics: [1.2195065562250635]
# computed_metrics: [1.2853779648857788]
# computed_metrics: [1.4809219050126463]
# computed_metrics: [3.3269482502536123]
# computed_metrics: [1.279288562791596]
# 1.279288562791596
# computed_metrics: [1.1974517118105195]
# computed_metrics: [1.2792885671053664]
# computed_metrics: [1.4418021528513294]
# computed_metrics: [3.412566103678673]
# computed_metrics: [1.2915233569551314]
# computed_metrics: [1.2740073753030974]
# 1.2740073753030974
# computed_metrics: [1.1670012321559255]
# computed_metrics: [1.2740073637033145]
# computed_metrics: [1.381152071610233]
# computed_metrics: [3.433971779786146]
# computed_metrics: [1.3341120211130497]
# computed_metrics: [1.2917518521161861]
# computed_metrics: [1.1878516363972973]
# 1.1878516363972973
# computed_metrics: [1.1230479641173672]
# computed_metrics: [1.1878516303798343]
# computed_metrics: [1.3644153577536278]
# computed_metrics: [3.213656020749]
# computed_metrics: [1.2694370094306138]
# computed_metrics: [1.2855175929688685]
# computed_metrics: [1.1861277810556623]
# 1.1861277810556623
# computed_metrics: [1.0927581097395456]
# computed_metrics: [1.1861277882652086]
# computed_metrics: [1.2924383242620032]
# computed_metrics: [3.420763589450189]
# computed_metrics: [1.144746793461632]
# 1.144746793461632
# computed_metrics: [1.0784587878115195]
# computed_metrics: [1.1447467949107226]
# computed_metrics: [1.3011485813582049]
# computed_metrics: [3.2098746869649886]
# computed_metrics: [1.1620096983298915]
# computed_metrics: [1.107151081819205]
# 1.107151081819205
# computed_metrics: [1.0610097085383667]
# computed_metrics: [1.1071510681498669]
# computed_metrics: [1.2938875499455298]
# computed_metrics: [3.103027170380961]
# computed_metrics: [1.1308470906680035]
# computed_metrics: [1.1156477813789913]
# computed_metrics: [1.094497141552546]
# 1.094497141552546
# computed_metrics: [1.0331372606783003]
# computed_metrics: [1.0944971394617764]
# computed_metrics: [1.246436647167649]
# computed_metrics: [3.1733501590554014]
# computed_metrics: [1.0641682782664834]
# 1.0641682782664834
# computed_metrics: [1.0279170232409736]
# computed_metrics: [1.0641682607023089]
# computed_metrics: [1.2634951519741475]
# computed_metrics: [3.040025668150059]
# computed_metrics: [1.070490393797397]
# computed_metrics: [1.129609075963879]
# computed_metrics: [1.1485567667826009]
# computed_metrics: [1.091061489067022]
# computed_metrics: [1.109818566471914]
# computed_metrics: [1.0831702821477331]
# computed_metrics: [1.0497456703550734]
# 1.0497456703550734
# computed_metrics: [0.9803391341888559]
# computed_metrics: [1.049745664351548]
# computed_metrics: [1.1700992302245967]
# computed_metrics: [3.0667400344588325]
# computed_metrics: [1.099047476192478]
# computed_metrics: [1.065889037941398]
# computed_metrics: [1.009499326010432]
# 1.009499326010432
# computed_metrics: [0.9614472964717593]
# computed_metrics: [1.0094993366833136]
# computed_metrics: [1.1715793610628167]
# computed_metrics: [2.9737065733522714]
# computed_metrics: [1.0112615261317128]
# computed_metrics: [1.0353821650755972]
# computed_metrics: [0.9835443668974877]
# 0.9835443668974877
# computed_metrics: [0.9460675161902888]
# computed_metrics: [0.9835443688232386]
# computed_metrics: [1.1648253520174794]
# computed_metrics: [2.8593837760446252]
# computed_metrics: [1.0211754209271897]
# computed_metrics: [1.0195560825526835]
# computed_metrics: [0.9873456628877841]
# computed_metrics: [0.9464672593540212]
# 0.9464672593540212
# computed_metrics: [0.945970544164345]
# computed_metrics: [0.9464672655579062]
# computed_metrics: [1.1939566642599777]
# computed_metrics: [2.6487380247684333]
# computed_metrics: [0.9624331423602133]
# computed_metrics: [0.9395411966136423]
# 0.9395411966136423
# computed_metrics: [0.9400934938796187]
# computed_metrics: [0.9395411990499051]
# computed_metrics: [1.19577781573004]
# computed_metrics: [2.5609598216281473]
# computed_metrics: [0.9332334201633483]
# 0.9332334201633483
# computed_metrics: [0.9403002231801374]
# computed_metrics: [0.9332334531525778]
# computed_metrics: [1.2003622504342868]
# computed_metrics: [2.507509148767758]
# computed_metrics: [0.9477818465091168]
# computed_metrics: [0.9356134177277775]
# computed_metrics: [0.9208176825811981]
# 0.9208176825811981
# computed_metrics: [0.9119462884172748]
# computed_metrics: [0.9208176818841487]
# computed_metrics: [1.1564121110257146]
# computed_metrics: [2.638391414514181]
# computed_metrics: [0.9280447916548891]
# computed_metrics: [0.9299661703523352]
# computed_metrics: [0.9442684404197824]
# computed_metrics: [0.9418463579492863]
# computed_metrics: [0.9421148839055556]
# computed_metrics: [0.8993061787045216]
# 0.8993061787045216
# computed_metrics: [0.8730614354886552]
# computed_metrics: [0.8993061833205451]
# computed_metrics: [1.1019081839804556]
# computed_metrics: [2.654035026616821]
# computed_metrics: [0.9084517976386793]
# computed_metrics: [0.9085857656865327]
# computed_metrics: [0.9095309121981923]
# computed_metrics: [0.8896434034669678]
# 0.8896434034669678
# computed_metrics: [0.8547330390689342]
# computed_metrics: [0.8896433886547969]
# computed_metrics: [1.0758169385108478]
# computed_metrics: [2.6379750288129347]
# computed_metrics: [0.8832750563971385]
# 0.8832750563971385
# computed_metrics: [0.8489777195609616]
# computed_metrics: [0.8832750589700165]
# computed_metrics: [1.0691718507094554]
# computed_metrics: [2.693402509538897]
# computed_metrics: [0.8771686891173504]
# 0.8771686891173504
# computed_metrics: [0.8479058679182079]
# computed_metrics: [0.8771687006776735]
# computed_metrics: [1.081097303361573]
# computed_metrics: [2.5776996454476397]
# computed_metrics: [0.8670793186491199]
# 0.8670793186491199
# computed_metrics: [0.873313172187936]
# computed_metrics: [0.8670793114229934]
# computed_metrics: [1.1300111993399515]
# computed_metrics: [2.4329240227386215]
# computed_metrics: [0.8718927918874264]
# computed_metrics: [0.8848060380923809]
# computed_metrics: [0.8865176284075772]
# computed_metrics: [0.8979908494592993]
# computed_metrics: [0.8915258735557181]
# computed_metrics: [0.8640518893137376]
# 0.8640518893137376
# computed_metrics: [0.8155190030932848]
# computed_metrics: [0.8640519041914002]
# computed_metrics: [1.0278358136051196]
# computed_metrics: [2.613375712597249]
# computed_metrics: [0.913794920420786]
# computed_metrics: [0.8854387556063625]
# computed_metrics: [0.845020325649111]
# 0.845020325649111
# computed_metrics: [0.8096082836325957]
# computed_metrics: [0.8450203510704551]
# computed_metrics: [1.0395832819289832]
# computed_metrics: [2.504324929840427]
# computed_metrics: [0.8450698005215153]
# computed_metrics: [0.8279034492789343]
# 0.8279034492789343
# computed_metrics: [0.8162129682051785]
# computed_metrics: [0.827903454193063]
# computed_metrics: [1.0703236528864812]
# computed_metrics: [2.4389717890910583]
# computed_metrics: [0.8809861520164293]
# computed_metrics: [0.8636052528375746]
# computed_metrics: [0.8467207035394216]
# computed_metrics: [0.8274121313549535]
# 0.8274121313549535
# computed_metrics: [0.7874327052905838]
# computed_metrics: [0.8274121256976562]
# computed_metrics: [1.0201177661198562]
# computed_metrics: [2.5041742108856737]
# computed_metrics: [0.9086669511087783]
# computed_metrics: [0.8301308756804621]
# computed_metrics: [0.8488362837797302]
# computed_metrics: [0.8287388460548406]
# computed_metrics: [0.8228727705807242]
# 0.8228727705807242
# computed_metrics: [0.7680468249013985]
# computed_metrics: [0.8228727706797224]
# computed_metrics: [0.9866138205492176]
# computed_metrics: [2.541076088023598]
# computed_metrics: [0.8538802648635839]
# computed_metrics: [0.8194876768947079]
# 0.8194876768947079
# computed_metrics: [0.7622080286318236]
# computed_metrics: [0.8194876861797786]
# computed_metrics: [0.9827181109262682]
# computed_metrics: [2.5005286187684366]
# computed_metrics: [0.7962102778170992]
# 0.7962102778170992
# computed_metrics: [0.7694526281451631]
# computed_metrics: [0.7962102885690284]
# computed_metrics: [1.0268730914367188]
# computed_metrics: [2.428335370408931]
# computed_metrics: [0.8560011737495933]
# computed_metrics: [0.8111723664346966]
# computed_metrics: [0.7906117582597121]
# 0.7906117582597121
# computed_metrics: [0.7663033301730723]
# computed_metrics: [0.790611760293881]
# computed_metrics: [1.0346341993825727]
# computed_metrics: [2.3560390460693816]
# computed_metrics: [0.8508809151918278]
# computed_metrics: [0.8809400756578392]
# computed_metrics: [0.8435223813099932]
# computed_metrics: [0.7975513432459456]
# computed_metrics: [0.8408839038076075]
# computed_metrics: [0.8374688788870246]
# computed_metrics: [0.9173883830905388]
# computed_metrics: [0.8364044060330126]
# computed_metrics: [0.7982090075289842]
# computed_metrics: [0.8220822989773333]
# computed_metrics: [0.7856084842369909]
# 0.7856084842369909
# computed_metrics: [0.7213746894269932]
# computed_metrics: [0.7856084615974607]
# computed_metrics: [0.9664667790815986]
# computed_metrics: [2.449090931445474]
# computed_metrics: [0.8524656630113722]
# computed_metrics: [0.8581150020467522]
# computed_metrics: [0.7844947609780921]
# 0.7844947609780921
# computed_metrics: [0.7143741079714223]
# computed_metrics: [0.784494777409831]
# computed_metrics: [0.9611687452515117]
# computed_metrics: [2.416467891383698]
# computed_metrics: [0.8256331261274039]
# computed_metrics: [0.7851039753866482]
# computed_metrics: [0.7913331757990977]
# computed_metrics: [0.7957760955099967]
# computed_metrics: [0.8123361795015268]
# computed_metrics: [0.7934025618345304]
# computed_metrics: [0.7614048105787053]
# 0.7614048105787053
# computed_metrics: [0.7388889938930006]
# computed_metrics: [0.7614048195182016]
# computed_metrics: [1.0396278292434813]
# computed_metrics: [2.214771252506799]
# computed_metrics: [0.7715980730731291]
# computed_metrics: [0.8052834517785552]
# computed_metrics: [0.8011663367980049]
# computed_metrics: [0.8168447147505087]
# computed_metrics: [0.802837960049256]
# computed_metrics: [0.7586931459925449]
# 0.7586931459925449
# computed_metrics: [0.6823902815614409]
# computed_metrics: [0.7586931565594301]
# computed_metrics: [0.9558516573302999]
# computed_metrics: [2.401799090884077]
# computed_metrics: [0.795549959969525]
# computed_metrics: [0.7553904785269673]
# 0.7553904785269673
# computed_metrics: [0.6768480059678376]
# computed_metrics: [0.7553904940539032]
# computed_metrics: [0.9499588697539132]
# computed_metrics: [2.395605059264934]
# computed_metrics: [0.7615819541815345]
# computed_metrics: [0.7538327674614931]
# 0.7538327674614931
# computed_metrics: [0.6746468296079312]
# computed_metrics: [0.7538327637854032]
# computed_metrics: [0.9553945316925908]
# computed_metrics: [2.3269676128090375]
# computed_metrics: [0.7669269991502731]
# computed_metrics: [0.8092633542126273]
# computed_metrics: [0.7769690389891218]
# computed_metrics: [0.7565058112049632]
# computed_metrics: [0.7479563239268568]
# 0.7479563239268568
# computed_metrics: [0.6636260551846461]
# computed_metrics: [0.7479563112353997]
# computed_metrics: [0.9573529741656365]
# computed_metrics: [2.2803758974354906]
# computed_metrics: [0.7990820139002314]
# computed_metrics: [0.7593734068097864]
# computed_metrics: [0.7655950770787838]
# computed_metrics: [0.7409480356577446]
# 0.7409480356577446
# computed_metrics: [0.6532244088820061]
# computed_metrics: [0.7409480459272493]
# computed_metrics: [0.9499246986524119]
# computed_metrics: [2.3033907093416537]
# computed_metrics: [0.7538846908935996]
# computed_metrics: [0.7818527600013044]
# computed_metrics: [0.749536252587632]
# computed_metrics: [0.7450829904387668]
# computed_metrics: [0.7460535404455823]
# computed_metrics: [0.8735729515432802]
# computed_metrics: [0.7599121004976048]
# computed_metrics: [0.7936600548741266]
# computed_metrics: [0.779021648821648]
# computed_metrics: [0.7616562773987546]
# computed_metrics: [0.7728967572767884]
# computed_metrics: [0.736324236184342]
# 0.736324236184342
# computed_metrics: [0.6255421293702671]
# computed_metrics: [0.7363242770718599]
# computed_metrics: [0.9314398472835249]
# computed_metrics: [2.269601271153539]
# computed_metrics: [0.7408817976869357]
# computed_metrics: [0.7746091923856266]
# computed_metrics: [0.7359850986615389]
# 0.7359850986615389
# computed_metrics: [0.6171272171667422]
# computed_metrics: [0.7359851218347732]
# computed_metrics: [0.9213392856276484]
# computed_metrics: [2.2810947708412233]
# computed_metrics: [0.758307849796008]
# computed_metrics: [0.7227477259813039]
# 0.7227477259813039
# computed_metrics: [0.6186853264285442]
# computed_metrics: [0.7227477746373938]
# computed_metrics: [0.949845767409573]
# computed_metrics: [2.2898851030489142]
# computed_metrics: [0.8034608591762891]
# computed_metrics: [0.7347982201323465]
# computed_metrics: [0.7353806013459019]
# computed_metrics: [0.7750855386284772]
# computed_metrics: [0.7521191294909011]
# computed_metrics: [0.7182901183201208]
# 0.7182901183201208
# computed_metrics: [0.6206114062136207]
# computed_metrics: [0.7182901405724867]
# computed_metrics: [0.9575183139346413]
# computed_metrics: [2.173425388963748]
# computed_metrics: [0.7437144767874291]
# computed_metrics: [0.7361339598620116]
# computed_metrics: [0.857610415394888]
# computed_metrics: [0.7315817123282583]
# computed_metrics: [0.7130908335834486]
# 0.7130908335834486
# computed_metrics: [0.6000359594918779]
# computed_metrics: [0.7130908407419311]
# computed_metrics: [0.9524607858072812]
# computed_metrics: [2.2298296580098564]
# computed_metrics: [0.7743192586995266]
# computed_metrics: [0.7742113886364496]
# computed_metrics: [0.7544331909853653]
# computed_metrics: [0.7415097403590877]
# computed_metrics: [0.6952732973335476]
# 0.6952732973335476
# computed_metrics: [0.6363292335336369]
# computed_metrics: [0.6952733232745766]
# computed_metrics: [1.043899474699863]
# computed_metrics: [2.07809278602929]
# computed_metrics: [0.816549136788182]
# computed_metrics: [0.7131780128572929]
# computed_metrics: [0.7206863811766901]
# computed_metrics: [0.7352563009082976]
# computed_metrics: [0.7190051953898198]
# computed_metrics: [0.7459495626227234]
# computed_metrics: [0.7366599498139298]
# computed_metrics: [0.7207481694524536]
# computed_metrics: [0.700985813320263]
# computed_metrics: [0.8190648476669286]
# computed_metrics: [0.7890388197378784]
# computed_metrics: [0.7243501007805205]
# computed_metrics: [0.7395835305965451]
# computed_metrics: [0.7832532505417499]
# computed_metrics: [0.6882805153453211]
# 0.6882805153453211
# computed_metrics: [0.5779150264034677]
# computed_metrics: [0.6882805089650926]
# computed_metrics: [0.9714230098551541]
# computed_metrics: [2.134959178485129]
# computed_metrics: [0.717490538599623]
# computed_metrics: [0.7457130576222707]
# computed_metrics: [0.748727822070007]
# computed_metrics: [0.7350026896093418]
# computed_metrics: [0.6883603493446887]
# computed_metrics: [0.7690350575170277]
# computed_metrics: [0.6818052033011347]
# 0.6818052033011347
# computed_metrics: [0.5805745620410112]
# computed_metrics: [0.6818052318279584]
# computed_metrics: [0.9897452567505367]
# computed_metrics: [2.100837940454128]
# computed_metrics: [0.779112445290457]
# computed_metrics: [0.6970026868835755]
# computed_metrics: [0.7560741557043394]
# computed_metrics: [0.6757402686903301]
# 0.6757402686903301
# computed_metrics: [0.5784649492069188]
# computed_metrics: [0.6757402855921472]
# computed_metrics: [0.9805339922071458]
# computed_metrics: [2.1064044023021533]
# computed_metrics: [0.7050140688442519]
# computed_metrics: [0.7011365299231973]
# computed_metrics: [0.7027980557281897]
# computed_metrics: [0.7179400851298058]
# computed_metrics: [0.6789404922680495]
# computed_metrics: [0.7748906102007889]
# computed_metrics: [0.6874481812294998]
# computed_metrics: [0.7237546302106469]
# computed_metrics: [0.6969238847237388]
# computed_metrics: [0.7304709917454755]
# computed_metrics: [0.675525617873371]
# 0.675525617873371
# computed_metrics: [0.5631914464311227]
# computed_metrics: [0.6755256065887991]
# computed_metrics: [0.9990130639883589]
# computed_metrics: [2.0621647485837444]
# computed_metrics: [0.7979533250683842]
# computed_metrics: [0.7437513708701339]
# computed_metrics: [0.7534414013990482]
# computed_metrics: [0.674889128204017]
# 0.674889128204017
# computed_metrics: [0.5222427172407133]
# computed_metrics: [0.674889148533971]
# computed_metrics: [0.9200980605222718]
# computed_metrics: [2.1505024399927524]
# computed_metrics: [0.7526284755730219]
# computed_metrics: [0.6943148026690565]
# computed_metrics: [0.6939715432183655]
# computed_metrics: [0.7026963474514393]
# computed_metrics: [0.7156259551480856]
# computed_metrics: [0.704168122032351]
# computed_metrics: [0.6671458964426333]
# 0.6671458964426333
# computed_metrics: [0.5193198947548883]
# computed_metrics: [0.6671458632814536]
# computed_metrics: [0.9349324570423896]
# computed_metrics: [2.169141614468708]
# computed_metrics: [0.7079234482554877]
# computed_metrics: [0.6791206603552977]
# computed_metrics: [0.679342089866796]
# computed_metrics: [0.759608613975525]
# computed_metrics: [0.6625973441826869]
# 0.6625973441826869
# computed_metrics: [0.555792505469621]
# computed_metrics: [0.662597364921807]
# computed_metrics: [0.9811654587170521]
# computed_metrics: [2.0556441070881566]
# computed_metrics: [0.8352585668670172]
# computed_metrics: [0.6755597505854916]
# computed_metrics: [0.6715235428109139]
# computed_metrics: [0.6901054326662088]
# computed_metrics: [0.6639199862817253]
# computed_metrics: [0.7890202309473279]
# computed_metrics: [0.6639694712072701]
# computed_metrics: [0.6965476236640599]
# computed_metrics: [0.6837686178429642]
# computed_metrics: [0.6686532185689691]
# computed_metrics: [0.7143381029592504]
# computed_metrics: [0.7053526364647842]
# computed_metrics: [0.6631400695640002]
# computed_metrics: [0.7869449332100404]
# computed_metrics: [0.6824667812134549]
# computed_metrics: [0.6853509450931827]
# computed_metrics: [0.6865061703773294]
# computed_metrics: [0.6748582223155231]
# computed_metrics: [0.6623536298876762]
# 0.6623536298876762
# computed_metrics: [0.4835331742777218]
# computed_metrics: [0.6623536402042647]
# computed_metrics: [0.8881679781224134]
# computed_metrics: [2.1238735690969603]
# computed_metrics: [0.6569647503964725]
# 0.6569647503964725
# computed_metrics: [0.48503204518563947]
# computed_metrics: [0.6569647081132051]
# computed_metrics: [0.9093420278467941]
# computed_metrics: [2.0875559599896274]
# computed_metrics: [0.7161728029936407]
# computed_metrics: [0.6738283802938508]
# computed_metrics: [0.723225532693469]
# computed_metrics: [0.6558852902991285]
# 0.6558852902991285
# computed_metrics: [0.4778876040888318]
# computed_metrics: [0.6558852401464985]
# computed_metrics: [0.8959659909046241]
# computed_metrics: [2.109522547033705]
# computed_metrics: [0.6573354003282554]
# computed_metrics: [0.6631664224035353]
# computed_metrics: [0.7276420861484564]
# computed_metrics: [0.6865013291985032]
# computed_metrics: [0.6777305701698119]
# computed_metrics: [0.6627179814593879]
# computed_metrics: [0.6778322175149394]
# computed_metrics: [0.7013116053816042]
# computed_metrics: [0.6731442717853757]
# computed_metrics: [0.6491319600108741]
# 0.6491319600108741
# computed_metrics: [0.47907896965463515]
# computed_metrics: [0.6491319341882003]
# computed_metrics: [0.9119371074384612]
# computed_metrics: [2.065953634724158]
# computed_metrics: [0.646479903159871]
# 0.646479903159871
# computed_metrics: [0.49846992920305105]
# computed_metrics: [0.6464799111791681]
# computed_metrics: [0.9461303416430289]
# computed_metrics: [2.043331732886916]
# computed_metrics: [0.7236124062740542]
# computed_metrics: [0.676188892892799]
# computed_metrics: [0.6867737027328973]
# computed_metrics: [0.7203509711679758]
# computed_metrics: [0.656975043967092]
# computed_metrics: [0.6648989222919953]
# computed_metrics: [0.7020613232439535]
# computed_metrics: [0.6683134462180166]
# computed_metrics: [0.6810189262917488]
# computed_metrics: [0.6420936397553535]
# 0.6420936397553535
# computed_metrics: [0.4569022017964452]
# computed_metrics: [0.6420936114214917]
# computed_metrics: [0.8874101632163408]
# computed_metrics: [2.138776253282198]
# computed_metrics: [0.675123719755261]
# computed_metrics: [0.7172703198276167]
# computed_metrics: [0.6474997324594413]
# computed_metrics: [0.7066249529469424]
# computed_metrics: [0.6539973622511529]
# computed_metrics: [0.7274906060802251]
# computed_metrics: [0.6711265694980527]
# computed_metrics: [0.6915040217146424]
# computed_metrics: [0.630719256968009]
# 0.630719256968009
# computed_metrics: [0.4702369411303229]
# computed_metrics: [0.6307192248683415]
# computed_metrics: [0.9420670344997861]
# computed_metrics: [2.04748537658449]
# computed_metrics: [0.635394531851212]
# computed_metrics: [0.6645306616269743]
# computed_metrics: [0.6492332420011768]
# computed_metrics: [0.7003391504927975]
# computed_metrics: [0.6931033070435776]
# computed_metrics: [0.6596005110405891]
# computed_metrics: [0.6577882764112449]
# computed_metrics: [0.6573767643402816]
# computed_metrics: [0.6483683893811163]
# computed_metrics: [0.6806641712905245]
# computed_metrics: [0.6407051380205986]
# computed_metrics: [0.6476751667939193]
# computed_metrics: [0.6718194575637997]
# computed_metrics: [0.6736731238728995]
# computed_metrics: [0.6519545385607943]
# computed_metrics: [0.6773894533555367]
# computed_metrics: [0.6377246910387685]
# computed_metrics: [0.7039277477256867]
# computed_metrics: [0.6633424949826677]
# computed_metrics: [0.6420358810161195]
# computed_metrics: [0.7563477906599235]
# computed_metrics: [0.6328240774547704]
# computed_metrics: [0.6562272842255327]
# computed_metrics: [0.6593524006031392]
# computed_metrics: [0.653839567109367]
# computed_metrics: [0.6567640397325902]
# computed_metrics: [0.6272491365253032]
# 0.6272491365253032
# computed_metrics: [0.4365081188852779]
# computed_metrics: [0.6272490391997988]
# computed_metrics: [0.9056757339157967]
# computed_metrics: [2.042591340701873]
# computed_metrics: [0.6806406729851573]
# computed_metrics: [0.6359813539367463]
# computed_metrics: [0.625415097161412]
# 0.625415097161412
# computed_metrics: [0.47149739227814]
# computed_metrics: [0.6254151333971688]
# computed_metrics: [0.9761042580465653]
# computed_metrics: [2.004487316247019]
# computed_metrics: [0.668860796941254]
# computed_metrics: [0.7269526817067942]
# computed_metrics: [0.636805915851137]
# computed_metrics: [0.6433684411202969]
# computed_metrics: [0.6834793128612345]
# computed_metrics: [0.6334871316465349]
# computed_metrics: [0.6357502781992299]
# computed_metrics: [0.6259555040722212]
# computed_metrics: [0.7093940920010212]
# computed_metrics: [0.6255044190534909]
# computed_metrics: [0.7369717470213978]
# computed_metrics: [0.6152421051192772]
# 0.6152421051192772
# computed_metrics: [0.44797071380385106]
# computed_metrics: [0.6152421091582427]
# computed_metrics: [0.9421368761031621]
# computed_metrics: [2.0169942242790886]
# computed_metrics: [0.6448900273996339]
# computed_metrics: [0.624100251306713]
# computed_metrics: [0.7188161810366465]
# computed_metrics: [0.614937866961608]
# 0.614937866961608
# computed_metrics: [0.4550990090669583]
# computed_metrics: [0.6149379197147694]
# computed_metrics: [0.9676491517260938]
# computed_metrics: [2.014730447234607]
# computed_metrics: [0.7178798266945794]
# computed_metrics: [0.6247755423249466]
# computed_metrics: [0.7117999212192762]
# computed_metrics: [0.6138006169648228]
# 0.6138006169648228
# computed_metrics: [0.4493643307354079]
# computed_metrics: [0.6138006144629655]
# computed_metrics: [0.9569519241108041]
# computed_metrics: [2.0062531104930907]
# computed_metrics: [0.7116362567053661]
# computed_metrics: [0.619312058802241]
# computed_metrics: [0.7910189566420281]
# computed_metrics: [0.6225891660019961]
# computed_metrics: [0.6785526283807267]
# computed_metrics: [0.6571655899593297]
# computed_metrics: [0.6149839884767295]
# computed_metrics: [0.7181824970239712]
# computed_metrics: [0.6235565125848359]
# computed_metrics: [0.6327904933621035]
# computed_metrics: [0.6543646419184707]
# computed_metrics: [0.6130228907366047]
# 0.6130228907366047
# computed_metrics: [0.4223731628673605]
# computed_metrics: [0.6130228948690479]
# computed_metrics: [0.9000945056783715]
# computed_metrics: [2.0314317985168846]
# computed_metrics: [0.6534423660025457]
# computed_metrics: [0.7004992929332198]
# computed_metrics: [0.6126997733958051]
# 0.6126997733958051
# computed_metrics: [0.42477489004398106]
# computed_metrics: [0.6126998256743351]
# computed_metrics: [0.9127532927862759]
# computed_metrics: [2.0132228492218687]
# computed_metrics: [0.6691540625134532]
# computed_metrics: [0.6263403701606888]
# computed_metrics: [0.6410503522508259]
# computed_metrics: [0.744584212600621]
# computed_metrics: [0.6269888230419931]
# computed_metrics: [0.6878919714402238]
# computed_metrics: [0.6352469454237365]
# computed_metrics: [0.6587082402896409]
# computed_metrics: [0.6090944050067819]
# 0.6090944050067819
# computed_metrics: [0.44165765308616123]
# computed_metrics: [0.6090944223743325]
# computed_metrics: [0.9656354900851127]
# computed_metrics: [1.9944190161277051]
# computed_metrics: [0.6920522633162502]
# computed_metrics: [0.6336535796990117]
# computed_metrics: [0.6475660484102629]
# computed_metrics: [0.6554456411433195]
# computed_metrics: [0.6701789368608272]
# computed_metrics: [0.6099102589849058]
# computed_metrics: [0.7050079891958914]
# computed_metrics: [0.6200488352744385]
# computed_metrics: [0.6448575067710726]
# computed_metrics: [0.6666859148331983]
# computed_metrics: [0.6632298809441208]
# computed_metrics: [0.6157388928576587]
# computed_metrics: [0.7669133785637698]
# computed_metrics: [0.6168216847775756]
# computed_metrics: [0.6955463517053722]
# computed_metrics: [0.6282200784870065]
# computed_metrics: [0.6389489278322541]
# computed_metrics: [0.615409467825423]
# computed_metrics: [0.6394518754253578]
# computed_metrics: [0.6431885971107586]
# computed_metrics: [0.6582578276134611]
# computed_metrics: [0.5979304848577895]
# 0.5979304848577895
# computed_metrics: [0.4075678623775436]
# computed_metrics: [0.5979305099794955]
# computed_metrics: [0.9164608024586882]
# computed_metrics: [2.0082936798504902]
# computed_metrics: [0.7067161120936702]
# computed_metrics: [0.6003803257497826]
# computed_metrics: [0.6783852638813623]
# computed_metrics: [0.610406566652758]
# computed_metrics: [0.6826708656677509]
# computed_metrics: [0.6100141620818189]
# computed_metrics: [0.7341858333883724]
# computed_metrics: [0.60092107382145]
# computed_metrics: [0.6834177116853696]
# computed_metrics: [0.6172716590741221]
# computed_metrics: [0.725676393010498]
# computed_metrics: [0.6053414176083716]
# computed_metrics: [0.6605726539545791]
# computed_metrics: [0.6150633486671585]
# computed_metrics: [0.6115026260442393]
# computed_metrics: [0.6543074505969418]
# computed_metrics: [0.6468430141210249]
# computed_metrics: [0.6240005583792618]
# computed_metrics: [0.6233394105542986]
# computed_metrics: [0.7118021752408535]
# computed_metrics: [0.6125562685068644]
# computed_metrics: [0.7410539572219003]
# computed_metrics: [0.6201769333923868]
# computed_metrics: [0.6614031623960913]
# computed_metrics: [0.66734997998676]
# computed_metrics: [0.6014271092915725]
# computed_metrics: [0.6651980937954335]
# computed_metrics: [0.6033504206448742]
# computed_metrics: [0.6845999233856072]
# computed_metrics: [0.624210972685469]
# early stopping at best_rmse : 0.5979304848577895...

# %%
pd.Series(model_performace).plot()

# %%
final_res = {'train_rmse':best_train_rmse, 
             'valid_rmse':best_valid_rmse, 
             'test_rmse':best_test_rmse,              
             'etc_rmse':best_etc_rmse,

#              'train_pred_y':best_train_pred_y,
#              'test_pred_y':best_test_pred_y,
             'etc_pred_y':best_etc_pred_y, 


             '# trainable params': count_params(model),
             'random_seed':seed, 
             'best_epoch': best_epoch,

             'batch_size':batch_size,
             #'lr': lr,

            }

final_res
# Out:
# {'train_rmse': 0.4075678623775436,
#  'valid_rmse': 0.5979305099794955,
#  'test_rmse': 0.9164608024586882,
#  'etc_rmse': 2.0082936798504902,
#  'etc_pred_y': [-3.8002589453092637,
#   -3.5250247155452814,
#   -3.4418943016309034,
#   -3.5460848940607947,
#   -4.1600954587152845,
#   -3.2815245747352693,
#   -4.298845807948406,
#   -4.623653852699347,
#   -4.117678570341932,
#   -3.692259218935889,
#   -3.298390435406101,
#   -3.7453514254332902,
#   -3.5007460616337474,
#   -3.699454611744531,
#   -3.435146552840318,
#   -3.496105286022912,
#   -3.628803093347281,
#   -3.3144020523566584,
#   -3.552327647507995,
#   -3.718782799215128,
#   -3.639531175955968,
#   -3.4457898579796815,
#   -3.6775698774396988,
#   -3.534017896837717,
#   -3.459094574621492,
#   -3.5723328842979654,
#   -3.444918516415315,
#   -3.520072920502213,
#   -3.50673441940621,
#   -3.8074357376880688,
#   -3.749657045339843,
#   -3.0669145620370832,
#   -3.035842236558175,
#   -3.151539021669903,
#   -3.9394760767578068,
#   -3.085213834148886,
#   -3.6983793930197955,
#   -3.815022182390655,
#   -3.2808461651803804,
#   -3.3352236202560883,
#   -4.554930452328283,
#   -3.549108349643988,
#   -2.680374831260546,
#   -3.3371807777288556,
#   -3.5139497412468197,
#   -3.4214904842015783,
#   -3.6256486122872458,
#   -3.445702233505792,
#   -3.471294621857992,
#   -3.7317532458874094,
#   -3.6636054465729884,
#   -3.838635870935532,
#   -3.3347767354392497,
#   -3.9479754609248197,
#   -3.6325942911619933,
#   -3.4848811603185332,
#   -3.694229093029055,
#   -1.991945465232455,
#   -2.48347884242392,
#   -2.4406248439494083,
#   -3.6060793784299916,
#   -4.397562717764748,
#   -3.572516516092525,
#   -3.1274093293639815,
#   -3.6190490659010552,
#   -2.4325384652448885,
#   -5.156938045729065,
#   -2.9112464031966754,
#   -3.470702476541478,
#   -3.350811982527712,
#   -3.5052891533545565,
#   -3.7116205581929975,
#   -3.475111126379965,
#   -3.550771632978692,
#   -2.5030931854868665,
#   -3.4985380197918747,
#   -3.2200951209809356,
#   -3.8064268858031243,
#   -4.279915378649178,
#   -3.267375452355633,
#   -2.487110354915818,
#   -3.1320643083642667,
#   -3.642693881695863,
#   -3.266218587866598,
#   -3.445210081316341,
#   -4.1586010976515455,
#   -3.5306207877218205,
#   -3.761346846091201,
#   -3.325512756562434,
#   -3.8218305091117455,
#   -3.897799409571827,
#   -3.058273420767681,
#   -3.1823145400029174,
#   -3.423355904860526,
#   -3.3226654831118503,
#   -3.308912015283541,
#   -3.5290698661673536,
#   -4.3980645497697255,
#   -4.125922926166526,
#   -3.4788448463358117,
#   -3.249305735803722,
#   -3.710168142996543,
#   -3.6208348969656683,
#   -3.466735270577768,
#   -4.435911742746262,
#   -3.5087814156897528,
#   -3.57066998056387,
#   -3.1054891103105624,
#   -2.8913153941424383,
#   -2.9828531153511304,
#   -3.3760095862466466,
#   -3.7056262849777126,
#   -3.473215495839225,
#   -3.198305294736677,
#   -3.5005271902493273,
#   -3.7882253529397696,
#   -2.6712096908922747,
#   -3.66525784802357,
#   -3.6317779600525344,
#   -3.7285620701018463],
#  '# trainable params': 341201,
#  'random_seed': 777,
#  'best_epoch': 371,
#  'batch_size': 64}
