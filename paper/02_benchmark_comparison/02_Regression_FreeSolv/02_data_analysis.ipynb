# %%
import pandas as pd

# %%
df = pd.read_csv('./result.csv', index_col = 0)

def _apply_statics(g):
    
    res = {'trainable_paras': int(g.trainable_paras.mean()), 
            'best_epoch': g.best_epoch.tolist(),
            'lr': g.lr.mean(),
            'batch_size': int(g.batch_size.mean()),
            'random_seed': g.random_seed.tolist(),
            'train_samples': int(g.train_samples.mean()),
            'valid_samples': int(g.valid_samples.mean()),
            'test_samples': int(g.test_samples.mean()),
            'train_rmse': '%.3f ± %.3f' % (g.train_rmse.mean(), g.train_rmse.std()),     
            'valid_rmse': '%.3f ± %.3f' % (g.valid_rmse.mean(), g.valid_rmse.std()),     
            'test_rmse':  '%.3f ± %.3f' % (g.test_rmse.mean(), g.test_rmse.std()),            
             }

    return pd.Series(res)

# %%
df1 = df.groupby(['dataset', 'model']).apply(_apply_statics)

# %%
df1.to_csv('./result.anlysis.csv')

# %%
df1
# Out:
#                                     trainable_paras       best_epoch      lr  \
# dataset     model
# attentiveFP DoublePath_both                  803681  [385, 486, 367]  0.0001
#             SinglePath_descriptor            407617  [475, 499, 490]  0.0001
#             SinglePath_fingerprint           326497  [499, 485, 484]  0.0001
# deepchem    DoublePath_both                  803681  [366, 426, 270]  0.0001
#             SinglePath_descriptor            407617  [430, 380, 390]  0.0001
#             SinglePath_fingerprint           326497  [350, 395, 377]  0.0001
#
#                                     batch_size   random_seed  train_samples  \
# dataset     model
# attentiveFP DoublePath_both                128  [7, 77, 777]            511
#             SinglePath_descriptor          128  [7, 77, 777]            511
#             SinglePath_fingerprint         128  [7, 77, 777]            511
# deepchem    DoublePath_both                128  [7, 77, 777]            513
#             SinglePath_descriptor          128  [7, 77, 777]            513
#             SinglePath_fingerprint         128  [7, 77, 777]            513
#
#                                     valid_samples  test_samples  \
# dataset     model
# attentiveFP DoublePath_both                    64            64
#             SinglePath_descriptor              64            64
#             SinglePath_fingerprint             64            64
# deepchem    DoublePath_both                    64            65
#             SinglePath_descriptor              64            65
#             SinglePath_fingerprint             64            65
#
#                                        train_rmse     valid_rmse  \
# dataset     model
# attentiveFP DoublePath_both         0.093 ± 0.024  0.786 ± 0.019
#             SinglePath_descriptor   0.509 ± 0.045  1.284 ± 0.038
#             SinglePath_fingerprint  0.093 ± 0.014  0.854 ± 0.039
# deepchem    DoublePath_both         0.430 ± 0.049  0.789 ± 0.026
#             SinglePath_descriptor   1.380 ± 0.074  1.233 ± 0.058
#             SinglePath_fingerprint  0.424 ± 0.020  0.811 ± 0.028
#
#                                         test_rmse
# dataset     model
# attentiveFP DoublePath_both         0.708 ± 0.024
#             SinglePath_descriptor   0.735 ± 0.020
#             SinglePath_fingerprint  0.750 ± 0.026
# deepchem    DoublePath_both         1.164 ± 0.068
#             SinglePath_descriptor   1.568 ± 0.062
#             SinglePath_fingerprint  1.255 ± 0.011
