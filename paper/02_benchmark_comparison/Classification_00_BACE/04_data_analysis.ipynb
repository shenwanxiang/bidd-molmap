# %%
import pandas as pd

# %%
df = pd.read_csv('./result.csv', index_col = 0)

def _apply_statics(g):
    
    res = {'trainable_paras': int(g.trainable_paras.mean()), 
            'best_epoch': g.best_epoch.tolist(),
            'lr': g.lr.mean(),
            'batch_size': int(g.batch_size.mean()),
            'random_seed': g.random_seed.tolist(),
            'train_samples': int(g.train_samples.mean()),
            'valid_samples': int(g.valid_samples.mean()),
            'test_samples': int(g.test_samples.mean()),
            'train_roc_auc': '%.5f ± %.5f' % (g.train_roc_auc.mean(), g.train_roc_auc.std()),     
            'valid_roc_auc': '%.5f ± %.5f' % (g.valid_roc_auc.mean(), g.valid_roc_auc.std()),     
            'test_roc_auc':  '%.5f ± %.5f' % (g.test_roc_auc.mean(), g.test_roc_auc.std()),            
             }

    return pd.Series(res)

# %%
df1 = df.groupby(['dataset', 'model']).apply(_apply_statics)

# %%
df1.to_csv('./result.anlysis.csv')

# %%
df1
# Out:
#                                     trainable_paras       best_epoch      lr  \
# dataset     model
# attentiveFP DoublePath_both                  803681     [28, 36, 28]  0.0001
#             SinglePath_descriptor            403457  [148, 218, 175]  0.0001
#             SinglePath_fingerprint           322337     [34, 45, 41]  0.0001
# deepchem    DoublePath_both                  803681     [29, 25, 28]  0.0001
#             SinglePath_descriptor            403457     [47, 39, 75]  0.0001
#             SinglePath_fingerprint           322337     [26, 23, 31]  0.0001
#
#                                     batch_size   random_seed  train_samples  \
# dataset     model
# attentiveFP DoublePath_both                128  [7, 77, 777]           1211
#             SinglePath_descriptor          128  [7, 77, 777]           1211
#             SinglePath_fingerprint         128  [7, 77, 777]           1211
# deepchem    DoublePath_both                128  [7, 77, 777]           1210
#             SinglePath_descriptor          128  [7, 77, 777]           1210
#             SinglePath_fingerprint         128  [7, 77, 777]           1210
#
#                                     valid_samples  test_samples  \
# dataset     model
# attentiveFP DoublePath_both                   151           151
#             SinglePath_descriptor             151           151
#             SinglePath_fingerprint            151           151
# deepchem    DoublePath_both                   151           152
#             SinglePath_descriptor             151           152
#             SinglePath_fingerprint            151           152
#
#                                         train_roc_auc      valid_roc_auc  \
# dataset     model
# attentiveFP DoublePath_both         0.96501 ± 0.00709  0.85458 ± 0.00368
#             SinglePath_descriptor   0.93457 ± 0.00785  0.86473 ± 0.01048
#             SinglePath_fingerprint  0.96521 ± 0.00671  0.85760 ± 0.00499
# deepchem    DoublePath_both         0.96238 ± 0.00492  0.74402 ± 0.01150
#             SinglePath_descriptor   0.88825 ± 0.01261  0.70457 ± 0.00930
#             SinglePath_fingerprint  0.94666 ± 0.00484  0.73656 ± 0.00446
#
#                                          test_roc_auc
# dataset     model
# attentiveFP DoublePath_both         0.87060 ± 0.00216
#             SinglePath_descriptor   0.87680 ± 0.00271
#             SinglePath_fingerprint  0.87227 ± 0.00318
# deepchem    DoublePath_both         0.84752 ± 0.01086
#             SinglePath_descriptor   0.82150 ± 0.00116
#             SinglePath_fingerprint  0.84191 ± 0.00312
