# %%
import pandas as pd

# %%
df = pd.read_csv('./result.csv', index_col = 0)

def _apply_statics(g):
    
    res = {'trainable_paras': int(g.trainable_paras.mean()), 
            'best_epoch': g.best_epoch.tolist(),
            'lr': g.lr.mean(),
            'batch_size': int(g.batch_size.mean()),
            'random_seed': g.random_seed.tolist(),
            'train_samples': int(g.train_samples.mean()),
            'valid_samples': int(g.valid_samples.mean()),
            'test_samples': int(g.test_samples.mean()),
            'train_roc_auc': '%.3f ± %.3f' % (g.train_roc_auc.mean(), g.train_roc_auc.std()),     
            'valid_roc_auc': '%.3f ± %.3f' % (g.valid_roc_auc.mean(), g.valid_roc_auc.std()),     
            'test_roc_auc':  '%.3f ± %.3f' % (g.test_roc_auc.mean(), g.test_roc_auc.std()),            
             }

    return pd.Series(res)

# %%
df1 = df.groupby(['dataset', 'model']).apply(_apply_statics)

# %%
df1.to_csv('./result.anlysis.csv')

# %%
df1
# Out:
#                                     trainable_paras       best_epoch      lr  \
# dataset     model
# attentiveFP DoublePath_both                  803681     [30, 27, 26]  0.0001
#             SinglePath_descriptor            403457   [109, 91, 122]  0.0001
#             SinglePath_fingerprint           322337     [32, 34, 30]  0.0001
# deepchem    DoublePath_both                  803681     [21, 18, 29]  0.0001
#             SinglePath_descriptor            403457  [105, 119, 103]  0.0001
#             SinglePath_fingerprint           322337     [25, 33, 29]  0.0001
#
#                                     batch_size   random_seed  train_samples  \
# dataset     model
# attentiveFP DoublePath_both                128  [7, 77, 777]           1628
#             SinglePath_descriptor          128  [7, 77, 777]           1628
#             SinglePath_fingerprint         128  [7, 77, 777]           1628
# deepchem    DoublePath_both                128  [7, 77, 777]           1631
#             SinglePath_descriptor          128  [7, 77, 777]           1631
#             SinglePath_fingerprint         128  [7, 77, 777]           1631
#
#                                     valid_samples  test_samples  \
# dataset     model
# attentiveFP DoublePath_both                   204           204
#             SinglePath_descriptor             204           204
#             SinglePath_fingerprint            204           204
# deepchem    DoublePath_both                   204           204
#             SinglePath_descriptor             204           204
#             SinglePath_fingerprint            204           204
#
#                                     train_roc_auc  valid_roc_auc  \
# dataset     model
# attentiveFP DoublePath_both         0.982 ± 0.004  0.942 ± 0.003
#             SinglePath_descriptor   0.957 ± 0.005  0.927 ± 0.002
#             SinglePath_fingerprint  0.978 ± 0.005  0.931 ± 0.006
# deepchem    DoublePath_both         0.978 ± 0.010  0.963 ± 0.002
#             SinglePath_descriptor   0.965 ± 0.003  0.965 ± 0.003
#             SinglePath_fingerprint  0.975 ± 0.008  0.962 ± 0.001
#
#                                      test_roc_auc
# dataset     model
# attentiveFP DoublePath_both         0.950 ± 0.002
#             SinglePath_descriptor   0.933 ± 0.004
#             SinglePath_fingerprint  0.949 ± 0.002
# deepchem    DoublePath_both         0.735 ± 0.005
#             SinglePath_descriptor   0.754 ± 0.002
#             SinglePath_fingerprint  0.733 ± 0.010
