# %%
import pandas as pd

# %%
df = pd.read_csv('./result.csv', index_col = 0)

def _apply_statics(g):
    
    res = {'trainable_paras': int(g.trainable_paras.mean()), 
            'best_epoch': g.best_epoch.tolist(),
            'lr': g.lr.mean(),
            'batch_size': int(g.batch_size.mean()),
            'random_seed': g.random_seed.tolist(),
            'train_samples': int(g.train_samples.mean()),
            'valid_samples': int(g.valid_samples.mean()),
            'test_samples': int(g.test_samples.mean()),
            'train_roc_auc': '%.3f ± %.3f' % (g.train_roc_auc.mean(), g.train_roc_auc.std()),     
            'valid_roc_auc': '%.3f ± %.3f' % (g.valid_roc_auc.mean(), g.valid_roc_auc.std()),     
            'test_roc_auc':  '%.3f ± %.3f' % (g.test_roc_auc.mean(), g.test_roc_auc.std()),            
             }

    return pd.Series(res)

# %%
df1 = df.groupby(['dataset', 'model']).apply(_apply_statics)

# %%
df1.to_csv('./result.anlysis.csv')

# %%
df1
# Out:
#                                     trainable_paras       best_epoch      lr  \
# dataset     model
# attentiveFP DoublePath_both                  769708     [42, 54, 51]  0.0001
#             SinglePath_descriptor            400844  [168, 138, 137]  0.0001
#             SinglePath_fingerprint           319724     [59, 67, 47]  0.0001
# deepchem    DoublePath_both                  769708     [41, 37, 39]  0.0001
#             SinglePath_descriptor            400844   [95, 105, 103]  0.0001
#             SinglePath_fingerprint           319724     [41, 48, 45]  0.0001
#
#                                     batch_size   random_seed  train_samples  \
# dataset     model
# attentiveFP DoublePath_both                128  [7, 77, 777]           6249
#             SinglePath_descriptor          128  [7, 77, 777]           6249
#             SinglePath_fingerprint         128  [7, 77, 777]           6249
# deepchem    DoublePath_both                128  [7, 77, 777]           6264
#             SinglePath_descriptor          128  [7, 77, 777]           6264
#             SinglePath_fingerprint         128  [7, 77, 777]           6264
#
#                                     valid_samples  test_samples  \
# dataset     model
# attentiveFP DoublePath_both                   781           781
#             SinglePath_descriptor             781           781
#             SinglePath_fingerprint            781           781
# deepchem    DoublePath_both                   783           784
#             SinglePath_descriptor             783           784
#             SinglePath_fingerprint            783           784
#
#                                     train_roc_auc  valid_roc_auc  \
# dataset     model
# attentiveFP DoublePath_both         0.936 ± 0.008  0.850 ± 0.003
#             SinglePath_descriptor   0.902 ± 0.008  0.850 ± 0.002
#             SinglePath_fingerprint  0.939 ± 0.009  0.832 ± 0.009
# deepchem    DoublePath_both         0.919 ± 0.001  0.851 ± 0.003
#             SinglePath_descriptor   0.882 ± 0.007  0.843 ± 0.003
#             SinglePath_fingerprint  0.918 ± 0.004  0.843 ± 0.002
#
#                                      test_roc_auc
# dataset     model
# attentiveFP DoublePath_both         0.844 ± 0.003
#             SinglePath_descriptor   0.847 ± 0.001
#             SinglePath_fingerprint  0.833 ± 0.008
# deepchem    DoublePath_both         0.853 ± 0.002
#             SinglePath_descriptor   0.823 ± 0.003
#             SinglePath_fingerprint  0.847 ± 0.004
