# %%
import pandas as pd

# %%
df = pd.read_csv('./result.csv', index_col = 0)

def _apply_statics(g):
    
    res = {'trainable_paras': int(g.trainable_paras.mean()), 
            'best_epoch': g.best_epoch.tolist(),
            'lr': g.lr.mean(),
            'batch_size': int(g.batch_size.mean()),
            'random_seed': g.random_seed.tolist(),
            'train_samples': int(g.train_samples.mean()),
            'valid_samples': int(g.valid_samples.mean()),
            'test_samples': int(g.test_samples.mean()),
            'train_roc_auc': '%.3f ± %.3f' % (g.train_roc_auc.mean(), g.train_roc_auc.std()),     
            'valid_roc_auc': '%.3f ± %.3f' % (g.valid_roc_auc.mean(), g.valid_roc_auc.std()),     
            'test_roc_auc':  '%.3f ± %.3f' % (g.test_roc_auc.mean(), g.test_roc_auc.std()),            
             }

    return pd.Series(res)

# %%
df1 = df.groupby(['dataset', 'model']).apply(_apply_statics)

# %%
df1.to_csv('./result.anlysis.csv')

# %%
df1
# Out:
#                                     trainable_paras       best_epoch      lr  \
# dataset     model
# attentiveFP DoublePath_both                  784827  [104, 166, 108]  0.0001
#             SinglePath_descriptor            409307     [4, 12, 123]  0.0001
#             SinglePath_fingerprint           328187   [142, 123, 12]  0.0001
# deepchem    DoublePath_both                  784827    [39, 104, 62]  0.0001
#             SinglePath_descriptor            409307     [98, 76, 45]  0.0001
#             SinglePath_fingerprint           328187    [103, 24, 97]  0.0001
#
#                                     batch_size   random_seed  train_samples  \
# dataset     model
# attentiveFP DoublePath_both                128  [7, 77, 777]           1092
#             SinglePath_descriptor          128  [7, 77, 777]           1092
#             SinglePath_fingerprint         128  [7, 77, 777]           1092
# deepchem    DoublePath_both                128  [7, 77, 777]           1141
#             SinglePath_descriptor          128  [7, 77, 777]           1141
#             SinglePath_fingerprint         128  [7, 77, 777]           1141
#
#                                     valid_samples  test_samples  \
# dataset     model
# attentiveFP DoublePath_both                   137           137
#             SinglePath_descriptor             137           137
#             SinglePath_fingerprint            137           137
# deepchem    DoublePath_both                   143           143
#             SinglePath_descriptor             143           143
#             SinglePath_fingerprint            143           143
#
#                                     train_roc_auc  valid_roc_auc  \
# dataset     model
# attentiveFP DoublePath_both         0.871 ± 0.022  0.638 ± 0.014
#             SinglePath_descriptor   0.631 ± 0.056  0.582 ± 0.021
#             SinglePath_fingerprint  0.806 ± 0.141  0.617 ± 0.048
# deepchem    DoublePath_both         0.762 ± 0.079  0.666 ± 0.011
#             SinglePath_descriptor   0.657 ± 0.019  0.654 ± 0.010
#             SinglePath_fingerprint  0.772 ± 0.089  0.654 ± 0.039
#
#                                      test_roc_auc
# dataset     model
# attentiveFP DoublePath_both         0.674 ± 0.014
#             SinglePath_descriptor   0.584 ± 0.049
#             SinglePath_fingerprint  0.650 ± 0.047
# deepchem    DoublePath_both         0.636 ± 0.010
#             SinglePath_descriptor   0.602 ± 0.007
#             SinglePath_fingerprint  0.637 ± 0.031
