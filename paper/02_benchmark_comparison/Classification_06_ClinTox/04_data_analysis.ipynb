# %%
import pandas as pd

# %%
df = pd.read_csv('./result.csv', index_col = 0)

def _apply_statics(g):
    
    res = {'trainable_paras': int(g.trainable_paras.mean()), 
            'best_epoch': g.best_epoch.tolist(),
            'lr': g.lr.mean(),
            'batch_size': int(g.batch_size.mean()),
            'random_seed': g.random_seed.tolist(),
            'train_samples': int(g.train_samples.mean()),
            'valid_samples': int(g.valid_samples.mean()),
            'test_samples': int(g.test_samples.mean()),
            'train_roc_auc': '%.3f ± %.3f' % (g.train_roc_auc.mean(), g.train_roc_auc.std()),     
            'valid_roc_auc': '%.3f ± %.3f' % (g.valid_roc_auc.mean(), g.valid_roc_auc.std()),     
            'test_roc_auc':  '%.3f ± %.3f' % (g.test_roc_auc.mean(), g.test_roc_auc.std()),            
             }

    return pd.Series(res)

# %%
df1 = df.groupby(['dataset', 'model']).apply(_apply_statics)

# %%
df1.to_csv('./result.anlysis.csv')

# %%
df1
# Out:
#                                     trainable_paras    best_epoch      lr  \
# dataset     model
# attentiveFP DoublePath_both                  803714    [9, 17, 9]  0.0001
#             SinglePath_descriptor            403490  [75, 71, 98]  0.0001
#             SinglePath_fingerprint           322370  [28, 26, 11]  0.0001
# deepchem    DoublePath_both                  803714  [22, 25, 15]  0.0001
#             SinglePath_descriptor            403490  [92, 73, 65]  0.0001
#             SinglePath_fingerprint           322370   [14, 14, 9]  0.0001
#
#                                     batch_size   random_seed  train_samples  \
# dataset     model
# attentiveFP DoublePath_both                128  [7, 77, 777]           1180
#             SinglePath_descriptor          128  [7, 77, 777]           1180
#             SinglePath_fingerprint         128  [7, 77, 777]           1180
# deepchem    DoublePath_both                128  [7, 77, 777]           1182
#             SinglePath_descriptor          128  [7, 77, 777]           1182
#             SinglePath_fingerprint         128  [7, 77, 777]           1182
#
#                                     valid_samples  test_samples  \
# dataset     model
# attentiveFP DoublePath_both                   148           148
#             SinglePath_descriptor             148           148
#             SinglePath_fingerprint            148           148
# deepchem    DoublePath_both                   148           148
#             SinglePath_descriptor             148           148
#             SinglePath_fingerprint            148           148
#
#                                     train_roc_auc  valid_roc_auc  \
# dataset     model
# attentiveFP DoublePath_both         0.873 ± 0.052  0.737 ± 0.016
#             SinglePath_descriptor   0.933 ± 0.013  0.837 ± 0.021
#             SinglePath_fingerprint  0.910 ± 0.034  0.735 ± 0.021
# deepchem    DoublePath_both         0.950 ± 0.032  0.717 ± 0.031
#             SinglePath_descriptor   0.950 ± 0.010  0.770 ± 0.015
#             SinglePath_fingerprint  0.780 ± 0.030  0.662 ± 0.021
#
#                                      test_roc_auc
# dataset     model
# attentiveFP DoublePath_both         0.957 ± 0.029
#             SinglePath_descriptor   0.984 ± 0.001
#             SinglePath_fingerprint  0.948 ± 0.007
# deepchem    DoublePath_both         0.828 ± 0.038
#             SinglePath_descriptor   0.874 ± 0.009
#             SinglePath_fingerprint  0.719 ± 0.070
