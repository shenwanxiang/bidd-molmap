# %%
from joblib import load

# %%
data = load('./ESOL_attentiveFP.data')

# %%
len(data)
# Out:
# 3

# %%
data[0]
# Out:
#         Compound ID  ESOL predicted log solubility in mols per litre  \
# 0          Fenfuram                                           -2.885
# 1            citral                                           -2.579
# 2            Picene                                           -6.618
# 3         Thiophene                                           -2.232
# 4     benzothiazole                                           -2.733
# ..              ...                                              ...
# 896       halothane                                           -2.608
# 897          Oxamyl                                           -0.908
# 898       Thiometon                                           -3.323
# 899  2-Methylbutane                                           -2.245
# 900        Stirofos                                           -4.320
#
#      Exp_LogS  Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# ...

# %%
data[1]
# Out:
#              Compound ID  ESOL predicted log solubility in mols per litre  \
# 0          Pentylbenzene                                           -3.899
# 1         Propyl formate                                           -0.757
# 2                osthole                                           -4.076
# 3         3-Chlorophenol                                           -2.761
# 4               Terbufos                                           -4.367
# ..                   ...                                              ...
# 108            Prometryn                                           -3.693
# 109            Digitoxin                                           -6.114
# 110  3-Methyl-3-pentanol                                           -1.308
# 111      2-Butoxyethanol                                           -0.775
# 112              Eugenol                                           -2.675
#
#      Exp_LogS  Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# ...
